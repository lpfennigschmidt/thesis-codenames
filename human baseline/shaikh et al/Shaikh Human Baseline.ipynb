# %% [markdown]
# # Extracting Gameflow Information from Shaikh et al.
#
# (Shaikh et al)[https://arxiv.org/abs/2306.02475] published [data](https://github.com/SALT-NLP/codenames/tree/main/data) for training machine learning models on predicting clues and guesses based on demographic information of the players for Codenames Duet games. I downloaded data for the 'clue generation task' and the 'generate_guess_task' to try and extract game metrics. Beforehand, I removed all demographic information from the data that is not relevant to recreating the games.

# %%
import pandas

# %%
# data downloaded from the 'clue generation task'
cluegiver_data = pandas.read_csv('./baseline_data/cluegiver_shaikh.csv', index_col = 0, delimiter=';')

expanded_cluegiver = cluegiver_data.loc[:, 'base_text'].str.split('black: ', expand=True)[1].str.split(', tan: ', expand=True)
cluegiver_data.insert(1, 'assassins', expanded_cluegiver[0])
expanded_cluegiver = expanded_cluegiver[1].str.split(', targets: ', expand=True)
cluegiver_data.insert(2, 'innocent', expanded_cluegiver[0])
cluegiver_data.insert(3, 'targets', expanded_cluegiver[1])
cluegiver_data = cluegiver_data.drop('base_text', axis=1)
cluegiver_data.rename(columns={'output':'clue'}, inplace = True)
cluegiver_data.insert(3, 'num_targets', cluegiver_data['targets'].str.count(',')+1)
cluegiver_data
# Out:
#                            assassins  \
# 0     ['switch', 'charge', 'strike']
# 1     ['switch', 'charge', 'strike']
# 2     ['switch', 'charge', 'strike']
# 3     ['switch', 'charge', 'strike']
# 4     ['switch', 'charge', 'strike']
# ...                              ...
# 7698   ['novel', 'racket', 'spring']
# 7699   ['novel', 'racket', 'spring']
# 7700   ['novel', 'racket', 'spring']
# 7701   ['novel', 'racket', 'spring']
# 7702   ['novel', 'racket', 'spring']
#
#                                                innocent       targets  \
# 0     ['fall', 'march', 'scientist', 'link', 'drop',...       ['sub']
# 1     ['fall', 'march', 'scientist', 'link', 'drop',...   ['disease']
# 2     ['fall', 'march', 'scientist', 'link', 'drop',...     ['sound']
# 3     ['fall', 'march', 'scientist', 'link', 'drop',...     ['field']
# 4     ['fall', 'march', 'scientist', 'link', 'drop',...  ['roulette']
# ...                                                 ...           ...
# 7698  ['march', 'embassy', 'contract', 'fall', 'row'...    ['switch']
# 7699  ['march', 'embassy', 'contract', 'fall', 'row'...       ['day']
# 7700  ['march', 'embassy', 'contract', 'fall', 'row'...     ['crash']
# 7701  ['march', 'embassy', 'contract', 'fall', 'row'...      ['plot']
# 7702  ['march', 'embassy', 'contract', 'fall', 'row'...       ['spy']
#
#       num_targets      clue
# 0               1  sandwich
# 1               1     virus
# 2               1      hear
# 3               1  football
# 4               1   russian
# ...           ...       ...
# 7698            1     board
# 7699            1       sun
# 7700            1       air
# 7701            1       map
# 7702            1    police
#
# [7703 rows x 5 columns]

# %%
# data downloaded from the 'generate guess task'
import numpy as np
guesser_data = pandas.read_csv('./baseline_data/guesser_shaikh.csv', index_col = 0, delimiter=';')

expanded_guesser = guesser_data.loc[:, 'base_text'].str.split('remaining: ', expand=True)[1].str.split(', hint: ', expand=True)
guesser_data.insert(1, 'board', expanded_guesser[0])
guesser_data.insert(2, 'hint', expanded_guesser[1])
guesser_data = guesser_data.drop('base_text', axis=1)

guesser_data.rename(columns={'output':'guesses'}, inplace = True)
guesser_data.insert(1, 'num_board', guesser_data['board'].str.count(',')+1)
guesser_data.insert(3, 'num_guesses', guesser_data['guesses'].str.count(',')+1)
guesser_data
# Out:
#                                                   board  num_board      hint  \
# 0     ['spot', 'charge', 'novel', 'sound', 'march', ...         25  sandwich
# 1     ['spot', 'charge', 'novel', 'sound', 'march', ...         24     virus
# 2     ['spot', 'charge', 'novel', 'sound', 'march', ...         23      hear
# 3     ['spot', 'charge', 'novel', 'march', 'scientis...         22  football
# 4     ['spot', 'charge', 'novel', 'march', 'scientis...         21   russian
# ...                                                 ...        ...       ...
# 7698  ['crash', 'novel', 'comic', 'march', 'racket',...         22     board
# 7699  ['crash', 'novel', 'comic', 'march', 'racket',...         21       sun
# 7700  ['crash', 'novel', 'comic', 'march', 'racket',...         20       air
# 7701  ['plot', 'draft', 'link', 'spring', 'wake', 'n...         19       map
# 7702  ['draft', 'link', 'contract', 'row', 'witch', ...         18    police
#
#       num_guesses  guesses
# 0             1.0    green
# 1             1.0  disease
# 2             1.0    sound
# 3             1.0    field
# 4             1.0    novel
# ...           ...      ...
# 7698          1.0   switch
# 7699          1.0      day
# 7700          1.0    crash
# 7701          1.0     plot
# 7702          1.0      spy
#
# [7703 rows x 5 columns]

# %% [markdown]
# I assume that both dataframes are sorted in the same way and that I can recreate the game interactions. To check whether this assumption is true, I compare the 'clue' column from the clue-generation-task with the 'hint' column in the generate-guess-task:

# %%
import math
full_data = cluegiver_data.join(guesser_data)

full_data.dropna(inplace = True)
full_data['num_guesses'] = full_data['num_guesses'].astype(int)
assert (full_data['clue'] == full_data['hint']).all(), 'Columns clue and hint do not match!'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 6
#       4 full_data.dropna(inplace = True)
#       5 full_data['num_guesses'] = full_data['num_guesses'].astype(int)
# ----> 6 assert (full_data['clue'] == full_data['hint']).all(), 'Columns clue and hint do not match!'
#
# AssertionError: Columns clue and hint do not match!

# %% [markdown]
# The colums do not match, let's see where they do not:

# %%
full_data[full_data['clue'] != full_data['hint']]
# Out:
#                               assassins  \
# 1299   ['cycle', 'scientist', 'strike']
# 1500      ['centaur', 'pass', 'charge']
# 1800       ['check', 'spring', 'field']
# 1801       ['check', 'spring', 'field']
# 1916         ['light', 'part', 'check']
# 1918         ['light', 'part', 'check']
# 1954         ['time', 'figure', 'fall']
# 2937     ['cast', 'capital', 'unicorn']
# 3108       ['poison', 'state', 'cover']
# 4816        ['vacuum', 'state', 'wind']
# 4881          ['racket', 'day', 'lead']
# 5326   ['genius', 'superhero', 'death']
# 5605  ['leprechaun', 'switch', 'cover']
# 5953       ['point', 'date', 'unicorn']
# 6060            ['beat', 'day', 'time']
# 6630      ['compound', 'cycle', 'code']
# 6885         ['change', 'trip', 'part']
# 7166         ['time', 'opera', 'round']
# 7253      ['contract', 'club', 'cycle']
#
#                                                innocent  \
# 1299  ['conductor', 'genius', 'charge', 'spot', 'cod...
# 1500  ['leprechaun', 'mass', 'capital', 'light', 'so...
# 1800  ['plot', 'mount', 'degree', 'day', 'boom', 'da...
# 1801  ['plot', 'mount', 'degree', 'day', 'boom', 'da...
# 1916  ['cycle', 'comic', 'scientist', 'luck', 'centa...
# 1918  ['cycle', 'comic', 'scientist', 'luck', 'centa...
# 1954  ['air', 'spot', 'strike', 'boom', 'trip', 'mam...
# 2937  ['contract', 'compound', 'field', 'millionaire...
# 3108  ['club', 'plot', 'pass', 'opera', 'light', 'so...
# 4816  ['force', 'boom', 'space', 'ray', 'check', 'la...
# 4881  ['force', 'wind', 'code', 'capital', 'match', ...
# 5326  ['compound', 'conductor', 'part', 'spell', 'gr...
# 5605  ['change', 'figure', 'crash', 'play', 'trip', ...
# 5953  ['well', 'leprechaun', 'strike', 'scientist', ...
# 6060  ['undertaker', 'ray', 'stock', 'capital', 'tri...
# 6630  ['wake', 'fair', 'slip', 'racket', 'luck', 'le...
# 6885  ['figure', 'centaur', 'club', 'wake', 'luck', ...
# 7166  ['draft', 'conductor', 'scientist', 'force', '...
# 7253  ['plot', 'boom', 'wind', 'march', 'witch', 'em...
#
#                         targets  num_targets  clue  \
# 1299                  ['agent']            1     7
# 1500                    ['spy']            1     7
# 1800  ['spy', 'agent', 'novel']            3     7
# 1801  ['agent', 'spy', 'novel']            3     7
# 1916                   ['bond']            1     7
# 1918                   ['bond']            1     7
# 1954                    ['spy']            1     7
# 2937                   ['fair']            1  TRUE
# 3108                    ['spy']            1     7
# 4816           ['spy', 'agent']            2     7
# 4881                   ['soul']            1  TRUE
# 5326                    ['spy']            1     7
# 5605                  ['agent']            1     7
# 5953                  ['agent']            1     7
# 6060            ['bond', 'spy']            2     7
# 6630                    ['spy']            1     7
# 6885                  ['agent']            1     7
# 7166                  ['agent']            1     7
# 7253                   ['well']            1  TRUE
#
#                                                   board  num_board  hint  \
# 1299  ['force', 'death', 'spot', 'charge', 'code', '...         24   007
# 1500  ['death', 'center', 'row', 'centaur', 'spy', '...         17   007
# 1800  ['crash', 'death', 'match', 'novel', 'comic', ...         25   007
# 1801  ['crash', 'death', 'match', 'novel', 'comic', ...         24   007
# 1916  ['trip', 'slip', 'match', 'code', 'comic', 'sc...         23   007
# 1918  ['slip', 'match', 'code', 'comic', 'scientist'...         21   007
# 1954  ['trip', 'war', 'spot', 'slip', 'center', 'mat...         25   007
# 2937  ['war', 'sound', 'millionaire', 'strike', 'clu...         19  true
# 3108  ['lead', 'spot', 'light', 'soul', 'state', 'po...         25   007
# 4816  ['force', 'wind', 'charge', 'novel', 'drop', '...         25   007
# 4881  ['force', 'lead', 'wind', 'cast', 'match', 'ta...         21  true
# 5326  ['fair', 'death', 'lead', 'conductor', 'fighte...         25   007
# 5605  ['trip', 'crash', 'cast', 'beat', 'air', 'ligh...         23   007
# 5953  ['force', 'crash', 'spot', 'center', 'cast', '...         23   007
# 6060  ['trip', 'death', 'stock', 'tag', 'spy', 'unde...         18   007
# 6630  ['fair', 'slip', 'wind', 'cast', 'code', 'king...         20   007
# 6885  ['trip', 'wind', 'match', 'code', 'comic', 'so...         24   007
# 7166  ['force', 'spot', 'slip', 'charge', 'novel', '...         22   007
# 7253  ['spot', 'slip', 'wind', 'march', 'ninja', 'pr...         22  true
#
#       num_guesses                  guesses
# 1299            1                    agent
# 1500            2              spy, charge
# 1800            1                     bond
# 1801            2               spy, agent
# 1916            1                    agent
# 1918            3  state, revolution, bond
# 1954            1                      spy
# 2937            1                     fair
# 3108            1                      spy
# 4816            1                    agent
# 4881            1                     soul
# 5326            1                      spy
# 5605            1                    agent
# 5953            1                    agent
# 6060            2                spy, bond
# 6630            1                      spy
# 6885            1                    agent
# 7166            1                    agent
# 7253            1                     well

# %% [markdown]
# The mismatch only occurs for numbers ('007' was converted to 7) and booleans (true is capitalised). I believe this to be an issue on my side, because I deleted the demographic information by hand and my program probably changed those values based on assumptions that 007 should be an integer that does not have leading zeros. But as this dataframe is exhaustive, this is not an issue. Assuming that the 'hint' column retains the original information, I will drop the 'clue' column instead.
#
# Assumptions:
# - Sequential rows seem to occur in blocks of having the same assassins. I assume that these rows all belong to the same game and the same player and that they were not sorted by anything, but where actually played in this order.
# - Two of these sequential blocks with the same assassins seem to have the same overall board. I assume that these two blocks form the two player sides in a game. I would have assumed that they play in an alternating fashion, but this cannot be proven by the data. For that, the remaining board for the guesser should have been updated with the guesses from the other player as well, but the data only suggests that the board is updated with the guessers own guesses for him, which does not abide by the games rules. Assuming, they made a mistake by writing the remaining board down, I will continue to assume that the players played alternatingly.
#
#
# The following code introduces these assumptions in form of writing down game and turn numbers for each row. For each game, there is also counted how many team words, innocent words, target words (that were targeted by the cluegiver), and assassins were uncovered. Note that I do not accumulate this information by alternating between the players but by only going through them in one by one, the same as they are ordered in the dataset. This way, only the last row actually contains the complete game state.

# %%
full_data.drop('clue', axis =1, inplace = True)
full_data.insert(0, 'game', 0)
full_data.insert(1, 'turn', 0)
game = 0
turn = 0
game_col = []
turn_col = []
game_ass = ""
game_inno = ""
assassins_revealed_col = []
inno_revealed_col = []
targets_revealed_col = []
team_revealed_col = []
for index, row in full_data.iterrows():
    if row['num_board'] == 25 and game_ass != row['assassins'] and game_inno != row['innocent']:
        # new game
        game += 0.5
        turn = 1 if int(game) != float(game) else 2
        game_ass = row['assassins']
        game_inno = row['innocent']
        if int(game) != float(game):
            assassins_revealed = 0
            inno_revealed = 0
            targets_revealed = 0
            team_revealed = 0
        
    guesses = row['guesses'].split(', ')
    for guess in guesses:
        if guess in eval(row['assassins']):
            assassins_revealed += 1
        elif guess in eval(row['innocent']):
            inno_revealed += 1
        elif guess in eval(row['targets']):
            targets_revealed += 1
        else:
            team_revealed += 1
    game_col.append(math.floor(game + 0.5))
    turn_col.append(turn)
    turn += 2
    assassins_revealed_col.append(assassins_revealed)
    inno_revealed_col.append(inno_revealed)
    targets_revealed_col.append(targets_revealed)
    team_revealed_col.append(team_revealed)

full_data['game'] = game_col
full_data['turn'] = turn_col
full_data['assassins revealed'] = assassins_revealed_col
full_data['innocents revealed'] = inno_revealed_col
full_data['targets revealed'] = targets_revealed_col
full_data['team revealed'] = team_revealed_col
full_data[0:20]
# Out:
#     game  turn                       assassins  \
# 0      1     1  ['switch', 'charge', 'strike']
# 1      1     3  ['switch', 'charge', 'strike']
# 2      1     5  ['switch', 'charge', 'strike']
# 3      1     7  ['switch', 'charge', 'strike']
# 4      1     9  ['switch', 'charge', 'strike']
# 5      1    11  ['switch', 'charge', 'strike']
# 6      1    13  ['switch', 'charge', 'strike']
# 7      1     2  ['fall', 'switch', 'roulette']
# 8      1     4  ['fall', 'switch', 'roulette']
# 9      1     6  ['fall', 'switch', 'roulette']
# 10     1     8  ['fall', 'switch', 'roulette']
# 11     1    10  ['fall', 'switch', 'roulette']
# 12     1    12  ['fall', 'switch', 'roulette']
# 13     1    14  ['fall', 'switch', 'roulette']
# 14     2     1    ['roulette', 'match', 'day']
# 15     2     3    ['roulette', 'match', 'day']
# 16     2     5    ['roulette', 'match', 'day']
# 17     2     7    ['roulette', 'match', 'day']
# 18     2     9    ['roulette', 'match', 'day']
# 19     2    11    ['roulette', 'match', 'day']
#
#                                              innocent                targets  \
# 0   ['fall', 'march', 'scientist', 'link', 'drop',...                ['sub']
# 1   ['fall', 'march', 'scientist', 'link', 'drop',...            ['disease']
# 2   ['fall', 'march', 'scientist', 'link', 'drop',...              ['sound']
# 3   ['fall', 'march', 'scientist', 'link', 'drop',...              ['field']
# 4   ['fall', 'march', 'scientist', 'link', 'drop',...           ['roulette']
# 5   ['fall', 'march', 'scientist', 'link', 'drop',...                ['sub']
# 6   ['fall', 'march', 'scientist', 'link', 'drop',...           ['roulette']
# 7   ['march', 'link', 'sub', 'drop', 'disease', 'c...               ['boom']
# 8   ['march', 'link', 'sub', 'drop', 'disease', 'c...                ['tag']
# 9   ['march', 'link', 'sub', 'drop', 'disease', 'c...             ['charge']
# 10  ['march', 'link', 'sub', 'drop', 'disease', 'c...         ['revolution']
# 11  ['march', 'link', 'sub', 'drop', 'disease', 'c...               ['soul']
# 12  ['march', 'link', 'sub', 'drop', 'disease', 'c...                ['row']
# 13  ['march', 'link', 'sub', 'drop', 'disease', 'c...          ['scientist']
# 14  ['opera', 'code', 'death', 'scientist', 'lap',...    ['king', 'unicorn']
# 15  ['opera', 'code', 'death', 'scientist', 'lap',...     ['pitch', 'field']
# 16  ['opera', 'code', 'death', 'scientist', 'agent...              ['stock']
# 17  ['opera', 'code', 'death', 'scientist', 'agent...     ['cast', 'poison']
# 18  ['opera', 'code', 'death', 'scientist', 'agent...              ['field']
# 19  ['opera', 'code', 'death', 'scientist', 'agent...  ['fighter', 'poison']
#
#     num_targets                                              board  num_board  \
# 0             1  ['spot', 'charge', 'novel', 'sound', 'march', ...         25
# 1             1  ['spot', 'charge', 'novel', 'sound', 'march', ...         24
# 2             1  ['spot', 'charge', 'novel', 'sound', 'march', ...         23
# 3             1  ['spot', 'charge', 'novel', 'march', 'scientis...         22
# 4             1  ['spot', 'charge', 'novel', 'march', 'scientis...         21
# 5             1  ['spot', 'charge', 'march', 'scientist', 'drop...         20
# 6             1  ['soul', 'check', 'strike', 'link', 'roulette'...         19
# 7             1  ['spot', 'charge', 'novel', 'sound', 'march', ...         25
# 8             1  ['spot', 'charge', 'novel', 'sound', 'march', ...         24
# 9             1  ['spot', 'charge', 'novel', 'sound', 'march', ...         23
# 10            1  ['spot', 'novel', 'sound', 'march', 'scientist...         22
# 11            1  ['spot', 'novel', 'sound', 'march', 'scientist...         21
# 12            1  ['spot', 'novel', 'sound', 'march', 'scientist...         20
# 13            1  ['sound', 'green', 'check', 'strike', 'link', ...         19
# 14            2  ['death', 'tag', 'cast', 'match', 'code', 'fig...         25
# 15            2  ['death', 'tag', 'cast', 'match', 'code', 'fig...         23
# 16            1  ['death', 'tag', 'cast', 'match', 'code', 'fig...         21
# 17            2  ['death', 'tag', 'cast', 'match', 'code', 'fig...         20
# 18            1  ['match', 'code', 'soul', 'poison', 'luck', 'w...         19
# 19            2  ['luck', 'well', 'death', 'roulette', 'tag', '...         18
#
#            hint  num_guesses          guesses  assassins revealed  \
# 0      sandwich            1            green                   0
# 1         virus            1          disease                   0
# 2          hear            1            sound                   0
# 3      football            1            field                   0
# 4       russian            1            novel                   0
# 5      sandwich            1             spot                   0
# 6          game            1           strike                   1
# 7          bomb            1             boom                   1
# 8          name            1              tag                   1
# 9   electricity            1           charge                   1
# 10      history            1       revolution                   1
# 11        human            1             soul                   1
# 12      arrange            1              row                   1
# 13    invention            1        scientist                   1
# 14    fairytale            2    king, unicorn                   0
# 15     baseball            2       pitch, lap                   0
# 16   investment            1            stock                   0
# 17     hospital            1             cast                   0
# 18        crops            1              row                   0
# 19         pain            2  poison, fighter                   0
#
#     innocents revealed  targets revealed  team revealed
# 0                    0                 0              1
# 1                    0                 1              1
# 2                    0                 2              1
# 3                    0                 3              1
# 4                    1                 3              1
# 5                    2                 3              1
# 6                    2                 3              1
# 7                    2                 4              1
# 8                    2                 5              1
# 9                    2                 6              1
# 10                   2                 7              1
# 11                   2                 8              1
# 12                   2                 9              1
# 13                   2                10              1
# 14                   0                 2              0
# 15                   1                 3              0
# 16                   1                 4              0
# 17                   1                 5              0
# 18                   2                 5              0
# 19                   2                 7              0

# %% [markdown]
# Next, I will try to find out how many turns each game took:

# %%
full_data['num_board'].value_counts()
# Out:
# 25    1588
# 23    1285
# 21    1155
# 22    1142
# 24    1065
# 20     549
# 19     404
# 18     256
# 17     114
# 16      41
# 15      13
# 14       9
# 13       4
# Name: num_board, dtype: int64

# %%
list(full_data['turn'].value_counts())
# Out:
# [794,
#  794,
#  764,
#  753,
#  716,
#  713,
#  663,
#  660,
#  588,
#  583,
#  143,
#  131,
#  87,
#  85,
#  54,
#  40,
#  18,
#  16,
#  7,
#  6,
#  3,
#  2,
#  2,
#  2,
#  1]

# %%
end_turn = list(full_data['turn'].value_counts())
for i in range(0, len(end_turn) - 1):
    end_turn[i] -= end_turn[i+1]
end_turn
# Out:
# [0,
#  30,
#  11,
#  37,
#  3,
#  50,
#  3,
#  72,
#  5,
#  440,
#  12,
#  44,
#  2,
#  31,
#  14,
#  22,
#  2,
#  9,
#  1,
#  3,
#  1,
#  0,
#  0,
#  1,
#  1]

# %%
avg = 0
for i in range(len(end_turn)):
    avg += end_turn[i] * (i+1)
avg/sum(end_turn)
# Out:
# 9.603274559193954

# %%
sum(end_turn)
# Out:
# 794

# %%
len(full_data)/sum(end_turn)
# Out:
# 9.603274559193954

# %% [markdown]
# My average number of turns comes out at 9.6 instead of the reported 9.7, but I did exclude some turns where after merging cluegiver and guesser, there was only the clue but no guess, which is not a completed turn.

# %%
sum(end_turn[0:8]), sum(end_turn[8:])
# Out:
# (206, 588)

# %% [markdown]
# Going by the original Codenames Duet rules, only games that took 9 turns or less could have been won (if also all team cards and no assassins were revealed), so 588 games are definitely lost by this rule.

# %%
full_data
# Out:
#       game  turn                       assassins  \
# 0        1     1  ['switch', 'charge', 'strike']
# 1        1     3  ['switch', 'charge', 'strike']
# 2        1     5  ['switch', 'charge', 'strike']
# 3        1     7  ['switch', 'charge', 'strike']
# 4        1     9  ['switch', 'charge', 'strike']
# ...    ...   ...                             ...
# 7698   794     8   ['novel', 'racket', 'spring']
# 7699   794    10   ['novel', 'racket', 'spring']
# 7700   794    12   ['novel', 'racket', 'spring']
# 7701   794    14   ['novel', 'racket', 'spring']
# 7702   794    16   ['novel', 'racket', 'spring']
#
#                                                innocent       targets  \
# 0     ['fall', 'march', 'scientist', 'link', 'drop',...       ['sub']
# 1     ['fall', 'march', 'scientist', 'link', 'drop',...   ['disease']
# 2     ['fall', 'march', 'scientist', 'link', 'drop',...     ['sound']
# 3     ['fall', 'march', 'scientist', 'link', 'drop',...     ['field']
# 4     ['fall', 'march', 'scientist', 'link', 'drop',...  ['roulette']
# ...                                                 ...           ...
# 7698  ['march', 'embassy', 'contract', 'fall', 'row'...    ['switch']
# 7699  ['march', 'embassy', 'contract', 'fall', 'row'...       ['day']
# 7700  ['march', 'embassy', 'contract', 'fall', 'row'...     ['crash']
# 7701  ['march', 'embassy', 'contract', 'fall', 'row'...      ['plot']
# 7702  ['march', 'embassy', 'contract', 'fall', 'row'...       ['spy']
#
#       num_targets                                              board  \
# 0               1  ['spot', 'charge', 'novel', 'sound', 'march', ...
# 1               1  ['spot', 'charge', 'novel', 'sound', 'march', ...
# 2               1  ['spot', 'charge', 'novel', 'sound', 'march', ...
# 3               1  ['spot', 'charge', 'novel', 'march', 'scientis...
# 4               1  ['spot', 'charge', 'novel', 'march', 'scientis...
# ...           ...                                                ...
# 7698            1  ['crash', 'novel', 'comic', 'march', 'racket',...
# 7699            1  ['crash', 'novel', 'comic', 'march', 'racket',...
# 7700            1  ['crash', 'novel', 'comic', 'march', 'racket',...
# 7701            1  ['plot', 'draft', 'link', 'spring', 'wake', 'n...
# 7702            1  ['draft', 'link', 'contract', 'row', 'witch', ...
#
#       num_board      hint  num_guesses  guesses  assassins revealed  \
# 0            25  sandwich            1    green                   0
# 1            24     virus            1  disease                   0
# 2            23      hear            1    sound                   0
# 3            22  football            1    field                   0
# 4            21   russian            1    novel                   0
# ...         ...       ...          ...      ...                 ...
# 7698         22     board            1   switch                   0
# 7699         21       sun            1      day                   0
# 7700         20       air            1    crash                   0
# 7701         19       map            1     plot                   0
# 7702         18    police            1      spy                   0
#
#       innocents revealed  targets revealed  team revealed
# 0                      0                 0              1
# 1                      0                 1              1
# 2                      0                 2              1
# 3                      0                 3              1
# 4                      1                 3              1
# ...                  ...               ...            ...
# 7698                   0                11              0
# 7699                   0                12              0
# 7700                   0                13              0
# 7701                   0                14              0
# 7702                   0                15              0
#
# [7625 rows x 15 columns]

# %% [markdown]
# Aggregating statistics for only the games, taking the accumulated result of which cards were revealed during the game to calculate which games are won.

# %%
game_statistics = full_data.groupby('game').agg({'turn': 'max', 
                                                 'num_board':'min', 
                                                 'assassins revealed': 'last', 
                                                 'innocents revealed': 'last', 
                                                 'targets revealed': 'last', 
                                                 'team revealed': 'last'})

game_statistics
# Out:
#       turn  num_board  assassins revealed  innocents revealed  \
# game
# 1       14         19                   1                   2
# 2       16         15                   0                   4
# 3       15         18                   0                   0
# 4       15         18                   0                   0
# 5       15         18                   0                   0
# ...    ...        ...                 ...                 ...
# 790     13         18                   0                   0
# 791     21         15                   2                  12
# 792      4         22                   1                   1
# 793     14         18                   0                   0
# 794     16         18                   0                   0
#
#       targets revealed  team revealed
# game
# 1                   10              1
# 2                   15              0
# 3                   15              0
# 4                   15              0
# 5                   15              0
# ...                ...            ...
# 790                 15              0
# 791                  5              9
# 792                  4              0
# 793                 15              0
# 794                 15              0
#
# [794 rows x 6 columns]

# %% [markdown]
# Introducing 'win' and 'lose' columns to all games, for now ignoring the above information with the maximum number of turns:

# %%
game_statistics['revealed all targets'] = game_statistics['targets revealed'] >= 15
game_statistics['revealed all team'] = game_statistics['targets revealed'] + game_statistics['team revealed'] >= 15
game_statistics['lost through assassin'] = game_statistics['assassins revealed'] >= 1
game_statistics
# Out:
#       turn  num_board  assassins revealed  innocents revealed  \
# game
# 1       14         19                   1                   2
# 2       16         15                   0                   4
# 3       15         18                   0                   0
# 4       15         18                   0                   0
# 5       15         18                   0                   0
# ...    ...        ...                 ...                 ...
# 790     13         18                   0                   0
# 791     21         15                   2                  12
# 792      4         22                   1                   1
# 793     14         18                   0                   0
# 794     16         18                   0                   0
#
#       targets revealed  team revealed  revealed all targets  \
# game
# 1                   10              1                 False
# 2                   15              0                  True
# 3                   15              0                  True
# 4                   15              0                  True
# 5                   15              0                  True
# ...                ...            ...                   ...
# 790                 15              0                  True
# 791                  5              9                 False
# 792                  4              0                 False
# 793                 15              0                  True
# 794                 15              0                  True
#
#       revealed all team  lost through assassin
# game
# 1                 False                   True
# 2                  True                  False
# 3                  True                  False
# 4                  True                  False
# 5                  True                  False
# ...                 ...                    ...
# 790                True                  False
# 791               False                   True
# 792               False                   True
# 793                True                  False
# 794                True                  False
#
# [794 rows x 9 columns]

# %%
# How many games revealed all targeted words (not as important as actually winning the game, but a good precision metric)
game_statistics['revealed all targets'].value_counts()
# Out:
# False    736
# True      58
# Name: revealed all targets, dtype: int64

# %%
# games lost through the assassin
game_statistics['lost through assassin'].value_counts()
# Out:
# False    582
# True     212
# Name: lost through assassin, dtype: int64

# %%
# games won (if ignoring number of turns)
game_statistics['revealed all team'].value_counts()
# Out:
# False    638
# True     156
# Name: revealed all team, dtype: int64

# %% [markdown]
# So far, I cannot reproduce numbers that are stated in the paper (199 wins, 595 losses), but with the additional rule of only having maximum of 9 turns, this win number will get even smaller.

# %% [markdown]
# Looking at games that were not lost through the assassin and not won by revealing all team cards:

# %%
# seemingly unfinished games (if ignoring max 9 turns)
game_statistics[game_statistics['revealed all team'] == game_statistics['lost through assassin']]
# Out:
#       turn  num_board  assassins revealed  innocents revealed  \
# game
# 61      11         20                   0                   0
# 66       7         22                   0                   0
# 81      12         20                   0                   0
# 82      10         20                   0                   2
# 83      10         21                   0                   0
# ...    ...        ...                 ...                 ...
# 783     10         21                   0                   0
# 784     10         21                   0                   0
# 786     10         21                   0                   0
# 787     10         21                   0                   0
# 788     10         21                   0                   0
#
#       targets revealed  team revealed  revealed all targets  \
# game
# 61                  11              0                 False
# 66                   8              0                 False
# 81                  11              0                 False
# 82                   8              1                 False
# 83                  10              0                 False
# ...                ...            ...                   ...
# 783                 10              0                 False
# 784                 10              0                 False
# 786                 10              0                 False
# 787                 10              0                 False
# 788                 10              0                 False
#
#       revealed all team  lost through assassin
# game
# 61                False                  False
# 66                False                  False
# 81                False                  False
# 82                False                  False
# 83                False                  False
# ...                 ...                    ...
# 783               False                  False
# 784               False                  False
# 786               False                  False
# 787               False                  False
# 788               False                  False
#
# [426 rows x 9 columns]

# %%
# How many target cards were revealed in these unfinished games
game_statistics[game_statistics['revealed all team'] == game_statistics['lost through assassin']]['targets revealed'].value_counts()
# Out:
# 10    234
# 11     62
# 9      40
# 8      27
# 12     20
# 13     14
# 7      14
# 14      6
# 5       3
# 4       3
# 6       3
# Name: targets revealed, dtype: int64

# %%
# How many team cards were revealed in these unfinished games
game_statistics[game_statistics['revealed all team'] == game_statistics['lost through assassin']]['team revealed'].value_counts()
# Out:
# 0    315
# 1     64
# 2     22
# 3     21
# 4      3
# 5      1
# Name: team revealed, dtype: int64

# %%
# looking at an example game that was neither won nor lost
full_data[full_data['game'] == 82]
# Out:
#      game  turn                 assassins  \
# 948    82     1  ['wind', 'life', 'trip']
# 949    82     3  ['wind', 'life', 'trip']
# 950    82     5  ['wind', 'life', 'trip']
# 951    82     7  ['wind', 'life', 'trip']
# 952    82     9  ['wind', 'life', 'trip']
# 953    82     2  ['comic', 'ray', 'trip']
# 954    82     4  ['comic', 'ray', 'trip']
# 955    82     6  ['comic', 'ray', 'trip']
# 956    82     8  ['comic', 'ray', 'trip']
# 957    82    10  ['comic', 'ray', 'trip']
#
#                                               innocent             targets  \
# 948  ['war', 'force', 'sub', 'degree', 'embassy', '...           ['field']
# 949  ['war', 'force', 'sub', 'degree', 'embassy', '...          ['charge']
# 950  ['war', 'force', 'sub', 'degree', 'embassy', '...         ['capital']
# 951  ['war', 'force', 'sub', 'degree', 'embassy', '...            ['mass']
# 952  ['war', 'force', 'sub', 'degree', 'embassy', '...           ['comic']
# 953  ['force', 'sub', 'point', 'degree', 'embassy',...  ['ghost', 'witch']
# 954  ['force', 'sub', 'point', 'degree', 'embassy',...   ['center', 'row']
# 955  ['force', 'sub', 'point', 'degree', 'embassy',...   ['wind', 'light']
# 956  ['force', 'sub', 'point', 'degree', 'embassy',...   ['wind', 'light']
# 957  ['sub', 'point', 'degree', 'embassy', 'charge'...   ['wind', 'light']
#
#      num_targets                                              board  \
# 948            1  ['force', 'trip', 'war', 'center', 'wind', 'ch...
# 949            1  ['force', 'trip', 'war', 'center', 'wind', 'ch...
# 950            1  ['force', 'trip', 'war', 'center', 'wind', 'co...
# 951            1  ['force', 'trip', 'war', 'center', 'wind', 'co...
# 952            1  ['force', 'trip', 'war', 'center', 'wind', 'co...
# 953            2  ['force', 'trip', 'war', 'center', 'wind', 'ch...
# 954            2  ['force', 'trip', 'war', 'center', 'wind', 'ch...
# 955            2  ['force', 'trip', 'war', 'wind', 'charge', 'co...
# 956            2  ['force', 'trip', 'war', 'wind', 'charge', 'co...
# 957            2  ['trip', 'war', 'wind', 'charge', 'comic', 'li...
#
#      num_board       hint  num_guesses       guesses  assassins revealed  \
# 948         25   baseball            1         field                   0
# 949         24    battery            1        charge                   0
# 950         23     letter            1       capital                   0
# 951         22     priest            1          mass                   0
# 952         21      funny            1         comic                   0
# 953         25  halloween            2  ghost, witch                   0
# 954         23     middle            1        center                   0
# 955         22   elements            1          mass                   0
# 956         21    element            1         force                   0
# 957         20    element            1          part                   0
#
#      innocents revealed  targets revealed  team revealed
# 948                   0                 1              0
# 949                   0                 2              0
# 950                   0                 3              0
# 951                   0                 4              0
# 952                   0                 5              0
# 953                   0                 7              0
# 954                   0                 8              0
# 955                   1                 8              0
# 956                   2                 8              0
# 957                   2                 8              1

# %%
game_statistics[game_statistics['revealed all team'] == True]['turn'].value_counts().sort_index()
# Out:
# 4      1
# 5      1
# 6      2
# 7      4
# 8     14
# 9     13
# 10    25
# 11     6
# 12    10
# 13     8
# 14    14
# 15    12
# 16    27
# 17     4
# 18     8
# 19     1
# 20     4
# 21     1
# 26     1
# Name: turn, dtype: int64

# %% [markdown]
# # Analysis

# %%
# Average number of targets, slightly lower than original 1.24, but rounded up it fits
full_data['num_targets'].mean()
# Out:
# 1.2375081967213115

# %%
# Average number of guesses
full_data['num_guesses'].mean()
# Out:
# 1.2304262295081967

# %%
# 212 games were lost through uncovering an assassin
game_statistics['lost through assassin'].value_counts()
# Out:
# False    582
# True     212
# Name: lost through assassin, dtype: int64

# %%
# 156 games were 'won' by revealing all team words
game_statistics['revealed all team'].value_counts()
# Out:
# False    638
# True     156
# Name: revealed all team, dtype: int64

# %%
game_statistics[game_statistics['revealed all team'] == True]['turn'].value_counts().sort_index()
# Out:
# 4      1
# 5      1
# 6      2
# 7      4
# 8     14
# 9     13
# 10    25
# 11     6
# 12    10
# 13     8
# 14    14
# 15    12
# 16    27
# 17     4
# 18     8
# 19     1
# 20     4
# 21     1
# 26     1
# Name: turn, dtype: int64

# %%
# now looking again at the maximum number of turns
valid_games = game_statistics[game_statistics['turn'] <= 9]
valid_games
# Out:
#       turn  num_board  assassins revealed  innocents revealed  \
# game
# 8        4         24                   1                   1
# 9        6         21                   1                   2
# 17       4         23                   1                   2
# 21       5         20                   1                   0
# 23       6         21                   1                   2
# ...    ...        ...                 ...                 ...
# 749      8         18                   0                   0
# 768      7         19                   0                   0
# 770      2         25                   1                   1
# 779      7         19                   0                   1
# 792      4         22                   1                   1
#
#       targets revealed  team revealed  revealed all targets  \
# game
# 8                    2              1                 False
# 9                    6              0                 False
# 17                   5              0                 False
# 21                   8              1                 False
# 23                  10              0                 False
# ...                ...            ...                   ...
# 749                 15              0                  True
# 768                  7              8                 False
# 770                  1              0                 False
# 779                  7              8                 False
# 792                  4              0                 False
#
#       revealed all team  lost through assassin
# game
# 8                 False                   True
# 9                 False                   True
# 17                False                   True
# 21                False                   True
# 23                False                   True
# ...                 ...                    ...
# 749                True                  False
# 768                True                  False
# 770               False                   True
# 779                True                  False
# 792               False                   True
#
# [202 rows x 9 columns]

# %%
# valid games (that are not lost by taking over 9 turns) that are lost through uncovering an assassin
valid_games['lost through assassin'].value_counts()
# Out:
# True     166
# False     36
# Name: lost through assassin, dtype: int64

# %%
# valid games that are actually won within 9 turns
valid_games['revealed all team'].value_counts()
# Out:
# False    167
# True      35
# Name: revealed all team, dtype: int64

# %%
valid_games[valid_games['lost through assassin'] == valid_games['revealed all team']]
# Out:
#       turn  num_board  assassins revealed  innocents revealed  \
# game
# 66       7         22                   0                   0
#
#       targets revealed  team revealed  revealed all targets  \
# game
# 66                   8              0                 False
#
#       revealed all team  lost through assassin
# game
# 66                False                  False

# %% [markdown]
# One game of the valid 202 games still is unfinished within 9 turns, only 35 are actually won and the remaining 166 are lost through the assassin. This means for all recorded 794 games:
# - 35 wins
# - 166 losses through assassins
# - 592 losses through exceeding 9 turns
# - 1 unfinished game
#
# This leaves us with 793 usable games, of which only 35 were won, resulting in a 4.4% success rate for humans. I would strongly argue that this is a very bad baseline, from my own experience, people have less difficulties playing the game and should win more often. I would assume that either the experimenters or participants did not understand the 9-turn rule, as it is not mentioned in the paper and apparently not upheld in the data as well, but even ignoring this rule, I cannot reproduce the data reported in the paper. I sent a clarification request to Omar Shaikh.
