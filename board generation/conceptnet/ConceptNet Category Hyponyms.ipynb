# %% [markdown]
# # ConceptNet Category Hyponyms
# ## Extract English Terms from ConceptNet
#
# ConceptNet contains many different associations between words of a wide range of languages. For the wordlist generation, I am currently only interested in English nouns, that are connected via a "is-a" relation, so that I can extract exemplars/hyponyms for a category.
#
# Later on, other relations might be interesting for a thorough analysis of game-play, human and machine.
#
# To re-run this notebook, download the original data (assertions file, version 5.7.0 of ConceptNet from here: https://github.com/commonsense/conceptnet5/wiki/Downloads
#
# and put it into a data-folder:
# - `data/`
#     - `conceptnet-assertions-5.7.0.csv`

# %%
with open("data/conceptnet-assertions-5.7.0.csv") as conceptnet:
    for line in conceptnet:
        print(line)
        break
# Out:
# /a/[/r/Antonym/,/c/ab/агыруа/n/,/c/ab/аҧсуа/]	/r/Antonym	/c/ab/агыруа/n	/c/ab/аҧсуа	{"dataset": "/d/wiktionary/en", "license": "cc:by-sa/4.0", "sources": [{"contributor": "/s/resource/wiktionary/en", "process": "/s/process/wikiparsec/2"}], "weight": 1.0}

# %% [markdown]
# What the format looks like in ConceptNet (see also https://github.com/commonsense/conceptnet5/wiki/URI-hierarchy):
#
# first characters: type
# - /a/ - assertion or edge
# - /c/ - concept
#
# second characters: language code
# - en - English
#
# third: the word
#
# fourth: part of speech
# - n - noun

# %%
def extract_noun_from_conceptnet(cn_word, require_POS = True):
    word_parts = cn_word.split('/')
    
    # check if word denotes a concept and is an english word
    if word_parts[1] != 'c' or word_parts[2] != 'en':
        return None
    
    if require_POS:
        # check if word has a part of speech tag that is a noun
        if len(word_parts) <= 4:
            return None
        if len(word_parts) > 4 and word_parts[4] != 'n':
            return None
    else:
        # POS-tag is not required, but if exists, should still be a noun
        if len(word_parts) > 4 and word_parts[4] != 'n':
            return None
    
    return word_parts[3]

with open("data/conceptnet-assertions-5.7.0.csv") as conceptnet:
    with open("data/conceptnet-nouns-en.csv", 'w+') as en_conceptnet:
        count = 0
        for line in conceptnet:
            uri, relationship, first_word_id, second_word_id, _ = line.split('\t')
            relationship = relationship.removeprefix('/r/')
            
            first_word = extract_noun_from_conceptnet(first_word_id)
            second_word = extract_noun_from_conceptnet(second_word_id, require_POS=False)
            if first_word and second_word:
                count += 1
                en_conceptnet.write(f"{relationship}; {first_word}; {second_word}\n")
            
print(count)
# Out:
# 1850333

# %% [markdown]
# When developing this function above, I recorded the following amounts of words:
# - all english words:`6356320`
# - all english nouns and concepts without part of speech: `2735738`
# - all english nouns:`1850333`

# %% [markdown]
# The extracted English nouns are related with the following relations:
# - Antonym
# - AtLocation
# - DistinctFrom
# - FormOf
# - HasContext
# - InstanceOf
# - IsA (probably the only one relevant for Board Generation)
# - PartOf
# - RelatedTo
# - SimilarTo
# - Synonym
# - UsedFor
# - dbpedia/captial
# - dbpedia/field
#     - /genre
#     - /genus
#     - /influencedBy
#     - /knownFor
#     - /language
#     - /leade
#     - /occupation
#     - /product

# %%
with open("data/conceptnet-nouns-en.csv") as conceptnet_nouns:
    with open("data/conceptnet-isa-relations.csv", 'w+') as conceptnet_isa_relations:
        count = 0
        for line in conceptnet_nouns:
            line = line.strip()
            relationship, first_word, second_word = line.split(';')
            
            if relationship == "IsA":
                count += 1
                conceptnet_isa_relations.write(f"{relationship}; {first_word}; {second_word}\n")
            
print(count)
# Out:
# 173668

# %% [markdown]
# All English nouns related with an "is-a" relationship: `173668`

# %% [markdown]
# ## Getting Hyponyms for Categories

# %%
def get_hyponyms_for_categories(categories):
    hyponyms = {}
    with open("data/conceptnet-isa-relations.csv") as conceptnet_isa_relations:
        count = 0
        for line in conceptnet_isa_relations:
            line = line.strip()
            relationship, first_word, second_word = line.split(';  ')

            if second_word in categories:
                if second_word not in hyponyms:
                    hyponyms[second_word] = set()
                hyponyms[second_word].add(first_word)
                count += 1

    print(count)
    return hyponyms

# %%
import json
with open('../category lists/schroeder et al.json') as file:
    categories_schroeder = json.load(file)["categories"]
    print(categories_schroeder)
# Out:
# ['animal', 'bird', 'fruit', 'vegetable', 'clothing', 'furniture', 'vehicle', 'tool', 'musical_instrument', 'profession', 'sport']

# %%
get_hyponyms_for_categories(categories_schroeder) # 1019
# Out:
# 1019
# {'animal': {'1_sex',
#   'aardvark',
#   'aardwolf',
#   'acrodont',
#   'adult',
#   'albatross',
#   'allosaurus',
#   'american_goldfinch',
#   'animal',
#   'animal_human_food_source',
#   'apatosaurus',
#   'ape',
#   'arapaima',
#   'archimedes',
#   'arctotherium',
#   'armadillidiidae',
#   'arthropod',
#   'asexual_organism',
#   'asian_giant_hornet',
#   'athletic_physique',
#   'auk',
#   'australian_magpie',
#   'average_physical_build',
#   'awake_thing',
#   'axis',
#   'aye_aye',
#   'baboon',
#   'badger',
#   'barreleye',
#   'bat',
#   'bear',
#   'bee_eater',
#   'bigfin_reef_squid',
#   'biped',
#   'bird',
#   'black_mamba',
#   'blobfish',
#   'bonobo',
#   'brazilian_wandering_spider',
#   'bull_shark',
#   'bullock',
#   'calf',
#   'camel',
#   'cancer',
#   'canine',
#   'cannibal',
#   'captive',
#   'captive_animal',
#   'caribou',
#   'castoroides',
#   'cephalopod',
#   'channichthyidae',
#   'child',
#   'chimpanzee',
#   'choerodon_fasciatus',
#   'chordate',
#   'cicada',
#   'coelomate',
#   'cold_blooded_animal',
#   'coon',
#   'coypu',
#   'crawling_posture',
#   'creepy_crawly',
#   'crepuscular_animal',
#   'critter',
#   'crouch',
#   'crow',
#   'curvaceous_physique',
#   'cyclocosmia',
#   'cymothoa_exigua',
#   'dam',
#   'darter',
#   'denisova_hominin',
#   'deuterostome',
#   'dicrocoelium_dendriticum',
#   'dik_dik',
#   'dingo',
#   'dire_wolf',
#   'diurnal_animal',
#   'domestic_animal',
#   'dove',
#   'draco_volans',
#   'drug_addict',
#   'dunkleosteus',
#   'eagle',
#   'eagle_ray',
#   'earthworm',
#   'eastern_cicada_killer',
#   'echinacea',
#   'echinoderm',
#   'edentata',
#   'eel',
#   'egyptian_cobra',
#   'elephant',
#   'embryo',
#   'emu',
#   'equine',
#   'eulachon',
#   'eumetazoa',
#   'eurypterid',
#   'fat_animal',
#   'feeder',
#   'female',
#   'female_animal',
#   'fictional_animal',
#   'firefly',
#   'fish',
#   'forward_flying_posture',
#   'fowl',
#   'frilled_shark',
#   'full_thing',
#   'fully_clothed',
#   'gambian_pouched_rat',
#   'game',
#   'gauntness',
#   'gazelle',
#   'gerfalcon',
#   'giant',
#   'giant_weta',
#   'glaucus_atlanticus',
#   'globitermes_sulphureus',
#   'gnu',
#   'goliathus',
#   'gorilla',
#   'grandparent',
#   'great_ape',
#   'great_auk',
#   'greenland_shark',
#   'griffin',
#   'hamster',
#   'handstand_posture',
#   'hanging_from_arms_posture',
#   'hare',
#   'hawk',
#   'herbivore',
#   'hermaphrodite',
#   'herring',
#   'heteropteryx_dilatata',
#   'hexapod',
#   'hoatzin',
#   'homoiotherm',
#   'honey_badger',
#   'honey_buzzard',
#   'horned_lizard',
#   'horse',
#   'house_sparrow',
#   'huia',
#   'human',
#   'hummingbird',
#   'hungry_thing',
#   'hydra',
#   'hydractinian',
#   'ibis',
#   'ice_worm',
#   'insectivore',
#   'invertebrate',
#   'javan_rhinoceros',
#   'javelina',
#   'king_cobra',
#   'king_of_herrings',
#   'kingfisher',
#   'kitten',
#   'kittiwake',
#   'kneeling_posture',
#   'kookaburra',
#   'lagomorpha',
#   'lamprey',
#   'larva',
#   'latrodectus',
#   'leaning_on_knuckles_posture',
#   'legs_straddling_posture',
#   'leopard',
#   'lesser_ape',
#   'limax_maximus',
#   'lingula',
#   'lion',
#   'lizard',
#   'lophophorate',
#   'loris',
#   'lovebug',
#   'male',
#   'male_animal',
#   'mammal',
#   'man_eater',
#   'man_of_war',
#   'mare',
#   'marine_animal',
#   'mate',
#   'megalodon',
#   'metazoan',
#   'migrator',
#   'migratory_animal',
#   'mink',
#   'mole',
#   'mollusc',
#   'mollusk',
#   'molter',
#   'monkey',
#   'mouse',
#   'mule',
#   'mutant',
#   'narwhal',
#   'nightjar',
#   'nocturnal_animal',
#   'non_person_animal',
#   'northern_bald_ibis',
#   'not_hungry_thing',
#   'notostraca',
#   'oarfish',
#   'octopus',
#   'omnivore',
#   'oncopoda',
#   'orangutan',
#   'orb_weaver_spider',
#   'orphan',
#   'out_sick_attendance_status',
#   'oviparous_animal',
#   'owl',
#   'pachyderm',
#   'palaeochiropteryx',
#   'panda_bear',
#   'parent',
#   'parent_of',
#   'patient',
#   'pectinariidae',
#   'peeper',
#   'pelican_eel',
#   'periclimenes_imperator',
#   'pest',
#   'pet',
#   'philodota',
#   'pig',
#   'plesiosaur',
#   'pleurodont',
#   'poikilotherm',
#   'polar_bear',
#   'poriferan',
#   'pouched_mammal',
#   'predator',
#   'prey',
#   'prone_thing',
#   'puppy',
#   'quadruped',
#   'queasy_thing',
#   'raccoon',
#   'racer',
#   'radiata',
#   'range_animal',
#   'raptor',
#   'reclining_posture',
#   'red_bellied_black_snake',
#   'reduviidae',
#   'reptile',
#   'robin',
#   'rodent',
#   'ruminant',
#   'sahelanthropus',
#   'saola',
#   'scaly_thing',
#   'scavenger',
#   'scutigera_coleoptrata',
#   'sea_mammal',
#   'seabird',
#   'segmented_worm',
#   'semi_conscious_thing',
#   'sentient_animal',
#   'sexually_experienced',
#   'sheep',
#   'shepherd',
#   'short_animal',
#   'sibling',
#   'silky_shark',
#   'sitting_and_slouching_posture',
#   'sitting_posture',
#   'skylark',
#   'slight_thing',
#   'slippery_dick',
#   'snail',
#   'speartooth_shark',
#   'sphinx',
#   'spinner_shark',
#   'squirrel',
#   'starfish',
#   'starving_event',
#   'stayer',
#   'steinbock',
#   'stocky_physique',
#   'stork',
#   'stuffed_thing',
#   'stunt',
#   'stylophora',
#   'survivor',
#   'tall_animal',
#   'tall_thing',
#   'tame_animal',
#   'tarantula_hawk',
#   'tardigrade',
#   'tarsier',
#   'tawny_frogmouth',
#   'tent_caterpillar',
#   'thoroughbred',
#   'thylacine',
#   'thysania_agrippina',
#   'tiger_salamander',
#   'tiglon',
#   'tilapia',
#   'titanoboa',
#   'torosaurus',
#   'triceratops',
#   'unconscious_thing',
#   'upland_moa',
#   'upright_thing',
#   'varmint',
#   'vegetarian',
#   'venomous_animal',
#   'vermin',
#   'virgin',
#   'viviparous_animal',
#   'vulture',
#   'walleye',
#   'warm_blooded_animal',
#   'western_black_rhinoceros',
#   'weta',
#   'whale_shark',
#   'wolf',
#   'woolly_mammoth',
#   'work_animal',
#   'xenia',
#   'yak',
#   'yearling',
#   'young',
#   'young_animal',
#   'zonkey',
#   'zooplankton'},
#  'tool': {'abrader',
#   'bender',
#   'clincher',
#   'comb',
#   'cutting_implement',
#   'drill',
#   'drill_bit',
#   'eolith',
#   'fork',
#   'gang',
#   'garden_tool',
#   'gardening_tool',
#   'grapnel',
#   'hack',
#   'hand_tool',
#   'hardware_tool',
#   'hoe',
#   'hole_making_tool',
#   'iron',
#   'jack',
#   'ladder',
#   'machine_tool',
#   'manual_tool',
#   'neolith',
#   'paleolith',
#   'pestle',
#   'plow',
#   'plumbing_tool',
#   'power_tool',
#   'punch',
#   'rake',
#   'ram',
#   'rounder',
#   'rubber_stamp',
#   'saw_set',
#   'shaping_tool',
#   'stapler',
#   'stationary_tool',
#   'stencil',
#   'strickle',
#   'stylus',
#   'tamp',
#   'tap',
#   'upset'},
#  'furniture': {'accent_furniture',
#   'armchair',
#   'baby_bed',
#   'bed',
#   'bedroom_furniture',
#   'bedstead',
#   'bench',
#   'book_rack',
#   'bookcase',
#   'broyhill_furniture',
#   'buffet',
#   'bush_furniture',
#   'cabinet',
#   'chair',
#   'chaise_lounge',
#   'chest',
#   'chest_of_drawers',
#   'deckchair',
#   'desk',
#   'dining_room_furniture',
#   'dresser',
#   'electric_lamp',
#   'etagere',
#   'fitment',
#   'footstool',
#   'futon_sofa',
#   'hallstand',
#   'hammock',
#   'lamp',
#   'lawn_furniture',
#   'nest',
#   'object_supporting_furniture',
#   'office_furniture',
#   'organ',
#   'piano',
#   'piece_of_metal_furniture',
#   'piece_of_wooden_furniture',
#   'room_divider',
#   'seat',
#   'sectional',
#   'sheraton',
#   'sleeper',
#   'sofa',
#   'stand',
#   'stool',
#   'table',
#   'unfinished_wooden_furniture',
#   'wall_mirror',
#   'wall_unit',
#   'wardrobe',
#   'washstand'},
#  'clothing': {'accessory',
#   'apparel',
#   'array',
#   'attire',
#   'beachwear',
#   'black',
#   'blue',
#   'business_attire',
#   'change',
#   'civilian_clothing',
#   'clothing_ibo',
#   'clothing_item',
#   'clothing_made_of_cloth',
#   'clothing_made_of_leather',
#   'clothing_used_by_boys',
#   'clothing_used_by_girls',
#   'clothing_used_by_infants',
#   'clothing_used_by_toddlers',
#   'clothing_used_for_golf',
#   'cycling_apparel',
#   'drag',
#   'dress',
#   'exercise_clothes',
#   'fashionable_style',
#   'footwear',
#   'formal_wear',
#   'garment',
#   'gray',
#   'handwear',
#   'headdress',
#   'kids_clothing',
#   'knitwear',
#   'leisure_wear',
#   'loungewear',
#   "man's_clothing",
#   "men's_clothing",
#   'neckpiece',
#   'nightclothes',
#   'outerwear',
#   'protective_garment',
#   'rain_gear',
#   'ready_to_wear',
#   'slip_on',
#   'slops',
#   'sports_attire',
#   'street_clothes',
#   'swimwear',
#   'tailor_made',
#   'teen_apparel',
#   'togs',
#   'traditional_clothing',
#   'uniform',
#   'vestiture',
#   'vintage_clothing',
#   'warm_clothes',
#   "woman's_clothing",
#   "women's_clothing",
#   'work_clothing'},
#  'fruit': {'accessory_fruit',
#   'achene',
#   'acorn',
#   'adams_pearmain_apple',
#   'african_oil_palm_fruit',
#   'aggregate_fruit',
#   'alligator_pear',
#   'almond',
#   'ambrosia_apple',
#   'apple',
#   'apricot',
#   'aubergine',
#   'bean',
#   'berry',
#   'black_peppercorn',
#   'blackberry',
#   'blueberry',
#   'braeburn_apple',
#   'buckthorn_berry',
#   'buffalo_nut',
#   'cereal_grain',
#   'cherry',
#   'cherry_tomato',
#   'chestnut',
#   'chokecherry',
#   'cobnut',
#   'cocoa_pod',
#   'coconut',
#   'coffee_cherry',
#   'compound_fruit',
#   'cotton_boll',
#   'cranberry',
#   'cubeb',
#   'cucumber',
#   'drupe',
#   'ear',
#   'edible_fruit',
#   'eggplant',
#   'flax_fruit',
#   'fourth_of_july_tomato',
#   'fruitlet',
#   'gala_apple',
#   'golden_delicious_apple',
#   'gourd',
#   'granny_smith_apple',
#   'hagberry',
#   'hazelnut',
#   'hip',
#   'jazz_apple',
#   'jonathan',
#   'juniper_berry',
#   'kiwifruit',
#   'legume',
#   'lychee',
#   'macadamia_nut',
#   'mango',
#   'marasca',
#   'may_apple',
#   'mcintosh_apple',
#   'melon',
#   'nut',
#   'nutmeg_fruit',
#   'okra',
#   'olive',
#   'pear',
#   'pepper',
#   'pineapple',
#   'plum',
#   'plum_tomato',
#   'pod',
#   'pome',
#   'pomegranate',
#   'prairie_gourd',
#   'pumpkin',
#   'pyxidium',
#   'quandong',
#   'raspberry',
#   'red_delicious_apple',
#   'ripe_fruit',
#   'roma_tomato',
#   'rowanberry',
#   'schizocarp',
#   'seed',
#   'sesame_fruit',
#   'squash',
#   'strawberry',
#   'three_sisiters_tomato',
#   'tomato',
#   'vanilla_bean',
#   'walnut',
#   'watermelon',
#   'white_grape',
#   'wild_cherry'},
#  'musical_instrument': {'accordion',
#   'acoustic_instrument',
#   'banjo',
#   'barrel_organ',
#   'bass',
#   'bugle',
#   'bullroarer',
#   'calliope',
#   'cello',
#   'electric_instrument',
#   'electronic_instrument',
#   'harpsichord',
#   "jew's_harp",
#   'keyboard_instrument',
#   'music_box',
#   'music_keyboard',
#   'octobass',
#   'percussion_instrument',
#   'sousaphone',
#   'spinet',
#   'stringed_instrument',
#   'wind_instrument',
#   'xylophone'},
#  'bird': {'acrocephalus',
#   'aix',
#   'akiapola_au',
#   'albatross',
#   'american_coot',
#   'american_goldfinch',
#   'anser',
#   'apodiform_bird',
#   'apus',
#   'aquatic_bird',
#   'aquila',
#   'ara',
#   'archaeopteryx',
#   'archaeornis',
#   'archilochus',
#   'ardea',
#   'argus',
#   'arses',
#   'athene',
#   'attila',
#   "attwater's_greater_prairie_chicken",
#   "audubon's_crested_caracara",
#   'auk',
#   'bee_eater',
#   'bird_of_passage',
#   'bird_of_prey',
#   'blackbird',
#   'blue_jay',
#   'bridled_white_eye',
#   'brown_headed_cowbird',
#   'california_clapper_rail',
#   'california_condor',
#   'cape_sable_seaside_sparrow',
#   'caprimulgiform_bird',
#   'caracara',
#   'cardinal',
#   'carinate',
#   'cassowary',
#   'catamenia',
#   'chen',
#   'chickadee',
#   'chicken',
#   'coastal_california_gnatcatcher',
#   'cock',
#   'columba',
#   'colymbiformes',
#   'coot',
#   'coraciiform_bird',
#   'corvus',
#   'cotinga',
#   'crane',
#   'crested_honeycreeper',
#   'crow',
#   'cuckoo',
#   'cuculiform_bird',
#   'dickeybird',
#   'diving_bird',
#   'dodo',
#   'domestic_fowl',
#   'domestic_turkey',
#   'dove',
#   'eagle',
#   'electron',
#   'elvira',
#   'emu',
#   'eos',
#   'eskimo_curlew',
#   'everglade_snail_kite',
#   'female_bird',
#   'finch',
#   'flavescent_flycatcher',
#   'flightless_bird',
#   'florida_grasshopper_sparrow',
#   'florida_scrub_jay',
#   'flycatcher',
#   'galbuliformes',
#   'gallinaceous_bird',
#   'gerfalcon',
#   'goldeneye',
#   'goldfinch',
#   'grackle',
#   'great_auk',
#   'grus',
#   'guam_broadbill',
#   'guam_rail',
#   'halcyon',
#   'hawaii_akepa',
#   'hawaii_creeper',
#   'hawaiian_common_moorhen',
#   'hawaiian_dark_rumped_petrel',
#   'hawaiian_duck',
#   'hawaiian_stilt',
#   'hawk',
#   'hen',
#   'hermit',
#   'hoatzin',
#   'honey_buzzard',
#   'huia',
#   'hummingbird',
#   'ibero_mesornis',
#   'ibis',
#   'inyo_california_towhee',
#   'jackdaw',
#   'jacobin',
#   'kauai_akialoa',
#   'kauai_o_o',
#   'kingfisher',
#   'kite',
#   'kittiwake',
#   'kiwi',
#   'kookaburra',
#   'large_bird',
#   'laysan_duck',
#   'laysan_finch',
#   'least_tern',
#   'light_footed_clapper_rail',
#   'man_of_war',
#   'mao',
#   'marbled_murrelet',
#   'mariana_common_moorhen',
#   'mariana_gray_swiftlet',
#   'masked_bobwhite',
#   'maui_akepa',
#   'maui_parrotbill',
#   'medium_sized_bird',
#   'merlin',
#   'merops',
#   'micronesian_megapode',
#   'migratory_bird',
#   'mino',
#   'mockingbird',
#   'modern_bird',
#   'molokai_creeper',
#   'nene',
#   'nester',
#   'nestor',
#   'new_world_oriole',
#   "newell'stownsend's_shearwater",
#   'night_bird',
#   'nightingale',
#   'nightjar',
#   'nihoa_millerbird',
#   'nonpasserine_bird',
#   'northern_bald_ibis',
#   'nukupu_u',
#   'o_u',
#   'oahu_creeper',
#   'ortolan',
#   'ostrich',
#   'ovenbird',
#   'owl',
#   'palila',
#   'parrot',
#   'passerine',
#   'peacock',
#   'pelican',
#   'penguin',
#   'petrel',
#   'pheasant',
#   'phoebe',
#   'pica',
#   'piciform_bird',
#   'picumnus',
#   'picus',
#   'pigeon',
#   'piopio',
#   'plover',
#   'po_ouli',
#   'poultry',
#   'prion',
#   'protoavis',
#   'puerto_rican_nightjar',
#   'puffin',
#   'raptor',
#   'ratite',
#   'raven',
#   'redhead',
#   'rhea',
#   'rifleman',
#   'robin',
#   'rook',
#   'roseate_tern',
#   'saddleback',
#   'san_clemente_loggerhead_shrike',
#   'san_clemente_sage_sparrow',
#   'seabird',
#   'seiurus',
#   'shore_bird',
#   'sinornis',
#   'skylark',
#   'sora',
#   'southwestern_willow_flycatcher',
#   'sparrow',
#   'spectacled_eider',
#   'starling',
#   'stilt',
#   'stork',
#   'strix',
#   'swallow',
#   'talking_bird',
#   'tawny_frogmouth',
#   'tern',
#   'thrush',
#   'tinian_monarch',
#   'tit',
#   'titmouse',
#   'topaz',
#   'toucan',
#   'trogon',
#   'trumpeter',
#   'tui',
#   'turkey',
#   'twitterer',
#   'vireo',
#   'vulture',
#   'wagtail',
#   'warbler',
#   'waterfowl',
#   'well_bird_exam',
#   'whitehead',
#   'wildfowl',
#   'woodpecker',
#   'wren',
#   'yellow_shouldered_blackbird',
#   'yuma_clapper_rail'},
#  'sport': {'archery',
#   'athletic_game',
#   'blood_sport',
#   'board_sport',
#   'college_sport',
#   'contact_sport',
#   'cycling',
#   'gymnastics',
#   'judo',
#   'motor_sport',
#   'outdoor_sport',
#   'professional_baseball',
#   'professional_basketball',
#   'professional_boxing',
#   'professional_football',
#   'professional_golf',
#   'professional_sport',
#   'professional_tennis',
#   'professional_wrestling',
#   'racing',
#   'riding',
#   'rock_climbing',
#   'rowing',
#   'skating',
#   'skeleton',
#   'skiing',
#   'sledding',
#   'spectator_sport',
#   'sports_game',
#   'squash',
#   'sumo',
#   'team_sport',
#   'tightrope_walking',
#   'track_and_field',
#   'ultimate',
#   'water_sport',
#   'winter_sport'},
#  'profession': {'architecture',
#   'businessmen',
#   'community_of_scholars',
#   'economics_profession',
#   'education',
#   'health_profession',
#   'journalism',
#   'learned_profession',
#   'legal_profession',
#   'literature',
#   'politics',
#   'priesthood',
#   'technology'},
#  'vegetable': {'artichoke',
#   'artichoke_heart',
#   'asparagus',
#   'bamboo_shoot',
#   'bean',
#   'bean_pod',
#   'beet',
#   'broccoli_foodstuff',
#   'brussel_sprout',
#   'cabbage',
#   'cardoon',
#   'carrot',
#   'cassava',
#   'celery',
#   'cruciferous_vegetable',
#   'cucumber',
#   'edible_olive',
#   'fennel',
#   'greens',
#   'gumbo',
#   'julienne_vegetable',
#   'leek',
#   'legume',
#   'lettuce',
#   'mushroom',
#   'onion',
#   'pea',
#   'pepper',
#   'pieplant',
#   'plantain',
#   'potato',
#   'potherb',
#   'pumpkin',
#   'radish',
#   'raw_vegetable',
#   'root_vegetable',
#   'solanaceous_vegetable',
#   'soybean',
#   'spinach',
#   'squash',
#   'sweet_potato',
#   'tomato',
#   'truffle',
#   'turnip',
#   'turnip_green',
#   'yam',
#   'zucchini'},
#  'vehicle': {'bicycle',
#   'bmw',
#   'bumper_car',
#   'craft',
#   'lorry',
#   'military_vehicle',
#   'neighborhood_electric_vehicle',
#   'new_energy_vehicle',
#   'rocket',
#   'skibob',
#   'sled',
#   'steamroller',
#   'watercraft',
#   'wheeled_vehicle'}}

# %%
with open('../category lists/jaramillo et al cleaned.json') as file:
    categories_jaramillo = json.load(file)["categories"]
    print(categories_jaramillo)
# Out:
# ['animal', 'body', 'clothes', 'color', 'day', 'dessert', 'food', 'relative', 'room', 'shape', 'sound', 'toy', 'beverage', 'bird', 'building', 'coin', 'collectable', 'condiment', 'container', 'dinosaur', 'direction', 'emotion', 'flower', 'fruit', 'holiday', 'ingredient', 'insect', 'instrument', 'job', 'jungle animal', 'liquid', 'measure', 'month', 'movie', 'story', 'pattern', 'planet', 'plant', 'reptile', 'rhyming', 'season', 'sense', 'silverware', 'size', 'solid', 'sport', 'transportation', 'tool', 'vegetable', 'writing', 'ability', 'businesses', 'city', 'country', 'communication', 'continent', 'currency', 'exercise', 'habitat', 'hazard', 'mammal', 'material', 'metal', 'ocean', 'president', 'school subject', 'seasoning', 'state', 'symbol', 'texture', 'tree', 'weather', 'colony', 'ancient civilization', 'constellation', 'cuisine', 'element', 'landmark', 'government type', 'gas', 'gem', 'organ', 'language', 'mineral', 'mountain', 'music type', 'precipitation', 'book', 'religion', 'tradition']

# %%
get_hyponyms_for_categories(categories_jaramillo) # 5635
# Out:
# 5635
# {'movie': {'1_movie_genre',
#   'action_movie',
#   'adult_movie',
#   'adventure_movie',
#   'ai_gone_wrong_movie',
#   'animated_movie',
#   'batman_movie',
#   'biblical_movie',
#   'celebrity_sex_tape',
#   "children's_movie",
#   'cinema_verite',
#   'classic_movie',
#   'collage_film',
#   'comedy_movie',
#   'coming_attraction',
#   'crime_movie',
#   'cult_movie',
#   'documentary',
#   'documentary_film',
#   'drama_movie',
#   'educational_movie',
#   'experimental_movie',
#   'family_movie',
#   'fantasy_movie',
#   'feature',
#   'film_noir',
#   'final_cut',
#   'foreign_film',
#   'free_movie',
#   'g',
#   'history_movie',
#   'home_movie',
#   'horror_movie',
#   'imax',
#   'independent_film',
#   'musical',
#   'mystery_movie',
#   'nc_17',
#   'not_yet_rated_rating',
#   'pg',
#   'pg_13',
#   'r',
#   'romance_movie',
#   'rough_cut',
#   'satirical_movie',
#   'science_fiction_movie',
#   'shoot_em_up',
#   'short_subject',
#   'silent_movie',
#   'skin_flick',
#   'slow_motion',
#   'sports_movie',
#   'star_wars_movie',
#   'superman_movie',
#   'suspense_movie',
#   'talking_picture',
#   'teen_movie',
#   'telefilm',
#   'three_d',
#   'thriller_movie',
#   'war_movie',
#   'western_movie',
#   'x'},
#  'liquid': {'1_propanol',
#   '2_mercaptoethanol',
#   'acetic_acid',
#   'acetyl_chloride',
#   'aftershave_lotion',
#   'alcohol',
#   'ammonia_solution',
#   'ammonia_water',
#   'antifreeze',
#   'aqueous_humor',
#   'artificial_blood',
#   'automotive_fluid',
#   'baby_oil',
#   'bath_oil',
#   'beverage',
#   'bile',
#   'bioethanol',
#   'biological_membrane_stuff',
#   'blood',
#   'boron_chloride',
#   'bromine',
#   'butanol',
#   'cooked_cereal',
#   'cyclosarin',
#   'demineralized_water',
#   'deodorant_spray',
#   'distillate',
#   'distilled_water',
#   'drinking_water',
#   'egg_white',
#   'elixir',
#   'emulsion',
#   'enema',
#   'extravasation',
#   'foundation',
#   'fresh_water',
#   'gargle',
#   'glycerol',
#   'grume',
#   'hair_color',
#   'hair_conditioner',
#   'hair_spray',
#   'hexane',
#   'hn1',
#   'hn2',
#   'honey',
#   'ichor',
#   'injectable_liquid_medical',
#   'ink',
#   'instillation',
#   'juice',
#   'kerosene',
#   'liquid',
#   'liquid_acetone',
#   'liquid_adamsite',
#   'liquid_alcohol',
#   'liquid_ammonia',
#   'liquid_carbon_monoxide',
#   'liquid_chloroform',
#   'liquid_concrete',
#   'liquid_crystal',
#   'liquid_cyanide',
#   'liquid_cyclosarin',
#   'liquid_diphenylchloroarsine',
#   'liquid_diphenylcyanoarsine',
#   'liquid_diphosgene',
#   "liquid_elmer's_glue",
#   'liquid_ethyl_alcohol',
#   'liquid_ethyldichloroarsine',
#   'liquid_film',
#   'liquid_fuel',
#   'liquid_gas_light_hydrocarbon',
#   'liquid_ground',
#   'liquid_hexane',
#   'liquid_hydrocarbon',
#   'liquid_hydrogen_peroxide',
#   'liquid_laundry_detergent',
#   'liquid_lewisite',
#   'liquid_methane',
#   'liquid_methanol',
#   'liquid_methyldichloroarsine',
#   'liquid_mustard_gas',
#   'liquid_mustard_lewisite',
#   'liquid_nitrogen_mustard',
#   'liquid_paint',
#   'liquid_perfluoroisobutene',
#   'liquid_phenyldichloroarsine',
#   'liquid_phosgene',
#   'liquid_propane',
#   'liquid_propanol',
#   'liquid_propoxur',
#   'liquid_sarin',
#   'liquid_shoe_polish',
#   'liquid_solution',
#   'liquid_soman',
#   'liquid_substance_p',
#   'liquid_tabun',
#   'liquid_ve',
#   'liquid_vg',
#   'liquid_vk',
#   'liquid_vm',
#   'liquid_vr_55',
#   'liquid_vx',
#   'liquified_petroleum_gas',
#   'liquor',
#   'lymph',
#   'mash',
#   'medium',
#   'mercury',
#   'milk',
#   'mucus',
#   'n_butyl_acetate',
#   'nectar',
#   'nitric_acid',
#   'ocean_zone',
#   'octane',
#   'oil',
#   'perfume',
#   'phosphoric_acid',
#   'phosphorus_trichloride',
#   'plasma',
#   'pool_water',
#   'propanol',
#   'pus',
#   'pyroligneous_acid',
#   'pyruvic_acid',
#   'roll_on_deodorant',
#   'saline_solution',
#   'saliva',
#   'sarin',
#   'sauce',
#   'semen',
#   'sesquimustard',
#   'shampoo',
#   'sheep_dip',
#   'skunk_spray',
#   'slurry',
#   'snake_oil',
#   'sodium_pentothal',
#   'soman',
#   'soup',
#   'spill',
#   'spinal_fluid',
#   'stripping_compound',
#   'sulfuric_acid',
#   'supernatant',
#   'syrup',
#   'tgd',
#   'thickened_tabun',
#   'thickened_vx',
#   'toluene',
#   'tuberculin',
#   'urine',
#   'vaccine',
#   'vanilla_extract',
#   'venom',
#   'vinegar',
#   'vx',
#   'water',
#   'white_out',
#   'wort',
#   'yolk'},
#  'animal': {'1_sex',
#   'aardvark',
#   'aardwolf',
#   'acrodont',
#   'adult',
#   'albatross',
#   'allosaurus',
#   'american_goldfinch',
#   'animal',
#   'animal_human_food_source',
#   'apatosaurus',
#   'ape',
#   'arapaima',
#   'archimedes',
#   'arctotherium',
#   'armadillidiidae',
#   'arthropod',
#   'asexual_organism',
#   'asian_giant_hornet',
#   'athletic_physique',
#   'auk',
#   'australian_magpie',
#   'average_physical_build',
#   'awake_thing',
#   'axis',
#   'aye_aye',
#   'baboon',
#   'badger',
#   'barreleye',
#   'bat',
#   'bear',
#   'bee_eater',
#   'bigfin_reef_squid',
#   'biped',
#   'bird',
#   'black_mamba',
#   'blobfish',
#   'bonobo',
#   'brazilian_wandering_spider',
#   'bull_shark',
#   'bullock',
#   'calf',
#   'camel',
#   'cancer',
#   'canine',
#   'cannibal',
#   'captive',
#   'captive_animal',
#   'caribou',
#   'castoroides',
#   'cephalopod',
#   'channichthyidae',
#   'child',
#   'chimpanzee',
#   'choerodon_fasciatus',
#   'chordate',
#   'cicada',
#   'coelomate',
#   'cold_blooded_animal',
#   'coon',
#   'coypu',
#   'crawling_posture',
#   'creepy_crawly',
#   'crepuscular_animal',
#   'critter',
#   'crouch',
#   'crow',
#   'curvaceous_physique',
#   'cyclocosmia',
#   'cymothoa_exigua',
#   'dam',
#   'darter',
#   'denisova_hominin',
#   'deuterostome',
#   'dicrocoelium_dendriticum',
#   'dik_dik',
#   'dingo',
#   'dire_wolf',
#   'diurnal_animal',
#   'domestic_animal',
#   'dove',
#   'draco_volans',
#   'drug_addict',
#   'dunkleosteus',
#   'eagle',
#   'eagle_ray',
#   'earthworm',
#   'eastern_cicada_killer',
#   'echinacea',
#   'echinoderm',
#   'edentata',
#   'eel',
#   'egyptian_cobra',
#   'elephant',
#   'embryo',
#   'emu',
#   'equine',
#   'eulachon',
#   'eumetazoa',
#   'eurypterid',
#   'fat_animal',
#   'feeder',
#   'female',
#   'female_animal',
#   'fictional_animal',
#   'firefly',
#   'fish',
#   'forward_flying_posture',
#   'fowl',
#   'frilled_shark',
#   'full_thing',
#   'fully_clothed',
#   'gambian_pouched_rat',
#   'game',
#   'gauntness',
#   'gazelle',
#   'gerfalcon',
#   'giant',
#   'giant_weta',
#   'glaucus_atlanticus',
#   'globitermes_sulphureus',
#   'gnu',
#   'goliathus',
#   'gorilla',
#   'grandparent',
#   'great_ape',
#   'great_auk',
#   'greenland_shark',
#   'griffin',
#   'hamster',
#   'handstand_posture',
#   'hanging_from_arms_posture',
#   'hare',
#   'hawk',
#   'herbivore',
#   'hermaphrodite',
#   'herring',
#   'heteropteryx_dilatata',
#   'hexapod',
#   'hoatzin',
#   'homoiotherm',
#   'honey_badger',
#   'honey_buzzard',
#   'horned_lizard',
#   'horse',
#   'house_sparrow',
#   'huia',
#   'human',
#   'hummingbird',
#   'hungry_thing',
#   'hydra',
#   'hydractinian',
#   'ibis',
#   'ice_worm',
#   'insectivore',
#   'invertebrate',
#   'javan_rhinoceros',
#   'javelina',
#   'king_cobra',
#   'king_of_herrings',
#   'kingfisher',
#   'kitten',
#   'kittiwake',
#   'kneeling_posture',
#   'kookaburra',
#   'lagomorpha',
#   'lamprey',
#   'larva',
#   'latrodectus',
#   'leaning_on_knuckles_posture',
#   'legs_straddling_posture',
#   'leopard',
#   'lesser_ape',
#   'limax_maximus',
#   'lingula',
#   'lion',
#   'lizard',
#   'lophophorate',
#   'loris',
#   'lovebug',
#   'male',
#   'male_animal',
#   'mammal',
#   'man_eater',
#   'man_of_war',
#   'mare',
#   'marine_animal',
#   'mate',
#   'megalodon',
#   'metazoan',
#   'migrator',
#   'migratory_animal',
#   'mink',
#   'mole',
#   'mollusc',
#   'mollusk',
#   'molter',
#   'monkey',
#   'mouse',
#   'mule',
#   'mutant',
#   'narwhal',
#   'nightjar',
#   'nocturnal_animal',
#   'non_person_animal',
#   'northern_bald_ibis',
#   'not_hungry_thing',
#   'notostraca',
#   'oarfish',
#   'octopus',
#   'omnivore',
#   'oncopoda',
#   'orangutan',
#   'orb_weaver_spider',
#   'orphan',
#   'out_sick_attendance_status',
#   'oviparous_animal',
#   'owl',
#   'pachyderm',
#   'palaeochiropteryx',
#   'panda_bear',
#   'parent',
#   'parent_of',
#   'patient',
#   'pectinariidae',
#   'peeper',
#   'pelican_eel',
#   'periclimenes_imperator',
#   'pest',
#   'pet',
#   'philodota',
#   'pig',
#   'plesiosaur',
#   'pleurodont',
#   'poikilotherm',
#   'polar_bear',
#   'poriferan',
#   'pouched_mammal',
#   'predator',
#   'prey',
#   'prone_thing',
#   'puppy',
#   'quadruped',
#   'queasy_thing',
#   'raccoon',
#   'racer',
#   'radiata',
#   'range_animal',
#   'raptor',
#   'reclining_posture',
#   'red_bellied_black_snake',
#   'reduviidae',
#   'reptile',
#   'robin',
#   'rodent',
#   'ruminant',
#   'sahelanthropus',
#   'saola',
#   'scaly_thing',
#   'scavenger',
#   'scutigera_coleoptrata',
#   'sea_mammal',
#   'seabird',
#   'segmented_worm',
#   'semi_conscious_thing',
#   'sentient_animal',
#   'sexually_experienced',
#   'sheep',
#   'shepherd',
#   'short_animal',
#   'sibling',
#   'silky_shark',
#   'sitting_and_slouching_posture',
#   'sitting_posture',
#   'skylark',
#   'slight_thing',
#   'slippery_dick',
#   'snail',
#   'speartooth_shark',
#   'sphinx',
#   'spinner_shark',
#   'squirrel',
#   'starfish',
#   'starving_event',
#   'stayer',
#   'steinbock',
#   'stocky_physique',
#   'stork',
#   'stuffed_thing',
#   'stunt',
#   'stylophora',
#   'survivor',
#   'tall_animal',
#   'tall_thing',
#   'tame_animal',
#   'tarantula_hawk',
#   'tardigrade',
#   'tarsier',
#   'tawny_frogmouth',
#   'tent_caterpillar',
#   'thoroughbred',
#   'thylacine',
#   'thysania_agrippina',
#   'tiger_salamander',
#   'tiglon',
#   'tilapia',
#   'titanoboa',
#   'torosaurus',
#   'triceratops',
#   'unconscious_thing',
#   'upland_moa',
#   'upright_thing',
#   'varmint',
#   'vegetarian',
#   'venomous_animal',
#   'vermin',
#   'virgin',
#   'viviparous_animal',
#   'vulture',
#   'walleye',
#   'warm_blooded_animal',
#   'western_black_rhinoceros',
#   'weta',
#   'whale_shark',
#   'wolf',
#   'woolly_mammoth',
#   'work_animal',
#   'xenia',
#   'yak',
#   'yearling',
#   'young',
#   'young_animal',
#   'zonkey',
#   'zooplankton'},
#  'book': {'28',
#   'abyss',
#   'address_book',
#   'agnes',
#   'airframe',
#   'album',
#   'alchemist',
#   'aleph',
#   'amerika',
#   'amsterdam',
#   'anabasis',
#   'andromeda',
#   'animal_liberation',
#   'antichrist',
#   'appointment_book',
#   'archangel',
#   'armadillo',
#   'army_field_manual',
#   'arrowsmith',
#   'atonement',
#   'austerlitz',
#   'authority',
#   'ballet_shoes',
#   'banco',
#   'barabbas',
#   'bare_bones',
#   'beast',
#   'beloved',
#   'bestiary',
#   'betrothed',
#   'between_rock_and_hard_place',
#   'bible',
#   'big_bang',
#   'big_four',
#   'black_book',
#   'black_house',
#   'black_rain',
#   'black_swan',
#   'blaze',
#   'blinding',
#   'blindness',
#   'blindsight',
#   'bliss',
#   'blue_moon',
#   'bluebeard',
#   'book_of_dead',
#   'booklet',
#   'boot_camp',
#   'boyhood',
#   'breadwinner',
#   'brimstone',
#   'butcher_boy',
#   'carmen',
#   'carrie',
#   'castle',
#   'cat',
#   'catalog',
#   'catechism',
#   'cause_of_death',
#   'cell',
#   'chamber',
#   'chamber_music',
#   "children's_book",
#   'christine',
#   'city',
#   'city_of_god',
#   'client',
#   "cliff's_notes",
#   'clown',
#   'coffee_table_book',
#   'coma',
#   'common_sense',
#   'confederates',
#   'confessor',
#   'contact',
#   'contemplation',
#   'cookbook',
#   'copybook',
#   'correction',
#   'counterfeiters',
#   'couples',
#   'cranford',
#   'curiosa',
#   'curtain',
#   'damsel_in_distress',
#   'daniel',
#   'danse_macabre',
#   'dead_zone',
#   'deceiver',
#   'defector',
#   'demons',
#   'desperation',
#   'diamonds_are_forever',
#   'dictionary',
#   'diplomacy',
#   'divergent',
#   'dog_years',
#   'dreamcatcher',
#   'dressmaker',
#   'dune',
#   'dwarves',
#   'ecce_homo',
#   'ecclesiastes',
#   'eclipse',
#   'embers',
#   'emma',
#   'empire',
#   'end',
#   'enigma',
#   'epistle',
#   'eric',
#   'essays',
#   'extinct_birds',
#   'extinction',
#   'faithful',
#   'fall',
#   'fatherland',
#   'fathers_and_sons',
#   'fear',
#   'felidae',
#   'fiasco',
#   'fire',
#   'firefox',
#   'firestarter',
#   'firewall',
#   'folio',
#   'formulary',
#   'forrest_gump',
#   'fort',
#   'foundation',
#   'freedom',
#   'frost',
#   'frostbite',
#   'fury',
#   'gambler',
#   'gateway',
#   'germinal',
#   'godfather',
#   'golem',
#   'gomorrah',
#   'great_wall_of_china',
#   'guardian',
#   'guardians',
#   'guest_book',
#   'guoyu',
#   'hannibal',
#   'hardback',
#   'heliopolis',
#   'hell_house',
#   'high_fidelity',
#   'histories',
#   'hold_tight',
#   'holes',
#   'homeward_bound',
#   'hominid',
#   'host',
#   'hunger_games',
#   'imprimatur',
#   'independence_day',
#   'inheritance',
#   'insectivorous_plants',
#   'insomnia',
#   'inversions',
#   'ishmael',
#   'island',
#   'it',
#   'jerusalem',
#   'job',
#   'journal',
#   'killing_floor',
#   'kim',
#   'last_call',
#   'legend',
#   'leviathan',
#   'live_forever',
#   'longitude',
#   'lustrum',
#   'magician',
#   'march',
#   'master',
#   'matter',
#   'meltdown',
#   'messenger',
#   'method',
#   'misery',
#   'momo',
#   'moonraker',
#   'mother',
#   'mulligan_stew',
#   'naerg_guide_book',
#   'natural_history',
#   'nausea',
#   'necropolis',
#   'negotiator',
#   'new_moon',
#   'next',
#   'night',
#   'night_shift',
#   'night_watch',
#   'night_work',
#   'noli_me_tangere',
#   'northern_lights',
#   'notebook',
#   'novel',
#   'np',
#   'old_masters',
#   'one_day',
#   'order_book',
#   'outlander',
#   'over_my_dead_body',
#   'oxygen',
#   'pact',
#   'palestine',
#   'paperback',
#   'paperback_book',
#   'papillon',
#   'paula',
#   "people's_republic",
#   'perfume',
#   'persuasion',
#   'phrase_book',
#   'pic',
#   'picture_book',
#   'playbook',
#   'player_piano',
#   'pop_up_book',
#   'porno',
#   'ports_of_call',
#   'possession',
#   'post_captain',
#   'prayer_book',
#   'prey',
#   'professor',
#   'quid',
#   'quo_vadis',
#   'rage',
#   'ragtime',
#   'rat',
#   'rebellion',
#   'red_room',
#   'reference_book',
#   'relic',
#   'reliquary',
#   'republic',
#   'resurrection',
#   'review_copy',
#   'rihanna',
#   'ring_of_fire',
#   'riptide',
#   'rituals',
#   'rogue_planet',
#   'rose_madder',
#   'ruins',
#   'running_man',
#   'salmagundi',
#   'satori',
#   'scarlett',
#   'science_book',
#   'scrapbook',
#   'secret',
#   'seeker',
#   'seizure',
#   'sex',
#   'sexy',
#   'shame',
#   'shining',
#   'shirley',
#   'showdown',
#   'siddhartha',
#   'sidetracked',
#   'silence_of_lambs',
#   'silk',
#   'sketchbook',
#   'slowness',
#   'snakehead',
#   'snow_queen',
#   'solaris',
#   'songbook',
#   'soul_music',
#   'spangle',
#   'ssn',
#   'steve_jobs',
#   'storybook',
#   'stranger',
#   'survivor',
#   'swaraj',
#   'sweet_dreams',
#   'sweet_tooth',
#   'talisman',
#   'tamsin',
#   'textbook',
#   'therapy',
#   'thinner',
#   'timbuktu',
#   'timeline',
#   'titan',
#   'tome',
#   'trade_book',
#   'traveler',
#   'treasure',
#   'tropic_of_capricorn',
#   'u.s.a',
#   'ulysses',
#   'underground',
#   'undine',
#   'unnamable',
#   'utopia',
#   'vanity_fair',
#   'virals',
#   'warlock',
#   'watchers',
#   'waverley',
#   'way_station',
#   'we',
#   'will_o_wisp',
#   'winner',
#   'witches_brew',
#   'women',
#   'woodcutters',
#   'words',
#   'workbook',
#   'yearbook',
#   'zodiac'},
#  'holiday': {'420',
#   'anniversary_of_revolution',
#   "april_fool's_day",
#   'australia_day',
#   'bahrain_independence_day',
#   'birthday_of_emperor',
#   'black_friday',
#   'christmas_eve',
#   'dano',
#   'epiphany',
#   'family_holiday',
#   'feast_day',
#   'gregorian_calendar_holiday',
#   'half_holiday',
#   'id_al_ghadir',
#   'independence_day',
#   'independence_day_azerbaijan',
#   'independence_day_greece',
#   'islamic_calendar_holiday',
#   'islamic_republic_day',
#   'jewish_calendar_holiday',
#   'legal_holiday',
#   'memorial_day',
#   'mesasamkranti',
#   'muharram',
#   'national_day_china',
#   'national_holiday',
#   'pioneer_day',
#   "qatar's_independence_day",
#   'ramanavami',
#   'referendum_day',
#   'religious_holiday',
#   'remembrance_day',
#   'secular_holiday',
#   'songkran',
#   'victory_day',
#   'vulcan',
#   'yom_ha_atzmaut'},
#  'plant': {'aa',
#   'abronia',
#   'acanthus',
#   'acrogen',
#   'actaea',
#   'ada',
#   'adonis',
#   'air_plant',
#   'althaea',
#   'annual',
#   'apomict',
#   'aquatic',
#   'artemisia',
#   'aster',
#   'attalea',
#   'autophyte',
#   'batis',
#   'biennial',
#   'bottling_plant',
#   'brewery',
#   'burmannia',
#   'byblis',
#   'calamus',
#   'canna',
#   'capsella',
#   'cassia',
#   'chelone',
#   'cola',
#   'constantia',
#   'cosmos',
#   'crop',
#   'croton',
#   'cryptogam',
#   'daphne',
#   'dionysia',
#   'diplotaxis',
#   'disa',
#   'distichia',
#   'distillery',
#   'dolichos',
#   'dracula',
#   'dracunculus',
#   'dryas',
#   'egeria',
#   'embryo',
#   'endemic',
#   'escape',
#   'euterpe',
#   'fabiana',
#   'factory',
#   'felicia',
#   'gametophyte',
#   'garden_plant',
#   'glycine',
#   'harrisia',
#   'hebe',
#   'heracleum',
#   'holophyte',
#   'houseplant',
#   'hygrophyte',
#   'hyssopus',
#   'iliamna',
#   'iris',
#   'kali',
#   'kiekie',
#   'lens',
#   'liparis',
#   'marah',
#   'melissa',
#   'mercurialis',
#   'microflora',
#   'milium',
#   'mint',
#   'mirabilis',
#   'monocarp',
#   'morus',
#   'myrmecophyte',
#   'nasa',
#   'nasturtium',
#   'neophyte',
#   'non_flowering_plant',
#   'ornamental',
#   'packinghouse',
#   'paris',
#   'perennial',
#   'periploca',
#   'phalaris',
#   'phoebe',
#   'phoenix',
#   'phytoplankton',
#   'pieris',
#   'pimenta',
#   'piper',
#   'plantlet',
#   'pogonia',
#   'poisonous_plant',
#   'pot_plant',
#   'proboscidea',
#   'prunella',
#   'puya',
#   'recycling_plant',
#   'refinery',
#   'reseda',
#   'rhamnus',
#   'rock_plant',
#   'rondeletia',
#   'roselle',
#   'saltworks',
#   'schoenus',
#   'senna',
#   'sewage_disposal_plant',
#   'sida',
#   'silphium',
#   'smelter',
#   'solaria',
#   'spinifex',
#   'sporophyte',
#   'stevia',
#   'thalia',
#   'thymus',
#   'trachelium',
#   'tragus',
#   'tree',
#   'trema',
#   'umbilicus',
#   'valerian',
#   'vanilla',
#   'vascular_plant',
#   'victoria',
#   'viola',
#   'watsonia',
#   'wilding',
#   'winery',
#   'xerophyllum',
#   'zea'},
#  'tree': {'aalii',
#   'acacia',
#   'aextoxicon',
#   'african_walnut',
#   'ailanthus_altissima',
#   'ailanthus_vilmoriniana',
#   'alangiaceae',
#   'albizzia',
#   'alder',
#   'alder_tree',
#   'alstonia',
#   'alzatea',
#   'anadenanthera_peregrina',
#   'andira_inermis',
#   'angelim',
#   'angiospermous_tree',
#   'anise_tree',
#   'anogeissus',
#   'apple',
#   'apple_tree',
#   'araucaria',
#   'arbor',
#   'aroeira_blanca',
#   'ash',
#   'ash_tree',
#   'ashoka_tree',
#   'aspen',
#   'australian_nettle',
#   'avocado_tree',
#   'babaco',
#   'baccaurea_macrocarpa',
#   'balata',
#   'balsa_tree',
#   'banana_tree',
#   'baobab',
#   'bauhinia',
#   'bayberry',
#   'bead_tree',
#   'beam_tree',
#   'bean_tree',
#   'beech',
#   'beech_tree',
#   'beleric',
#   'betulaceae',
#   'big_tree',
#   'binary_tree',
#   'birch',
#   'birch_tree',
#   'bitterwood_tree',
#   'black_mangrove',
#   'blackwood',
#   'bloodwood_tree',
#   'bo_tree',
#   'bodhi_tree',
#   'bonduc',
#   'bonsai',
#   'boron_tree',
#   'bottle_tree',
#   'box',
#   'box_tree',
#   'brachychiton',
#   'brachystegia',
#   'brazilian_ironwood',
#   'brazilian_pepper_tree',
#   'brazilwood',
#   'breakax',
#   'bully_tree',
#   'bulnesia_sarmientoi',
#   'burma_padauk',
#   'burmese_grape',
#   'butter_tree',
#   'button_tree',
#   'cabbage_tree',
#   'caesalpinia',
#   'calaba',
#   'calabash',
#   'calamites',
#   'call_tree',
#   'camwood',
#   'caracolito',
#   'carib_wood',
#   'cassia',
#   'casuarina',
#   'cat_tree',
#   'catalpa',
#   'caterpillar_tree',
#   'cecropia',
#   'ceratonia',
#   'chaste_tree',
#   'chaulmoogra',
#   'chequer_tree',
#   'cherry_tree',
#   'chestnut',
#   'chestnut_tree',
#   'chinaberry',
#   'chinese_parasol_tree',
#   'chinese_tallow',
#   'chocolate_tree',
#   'christmas_bush',
#   'christmas_tree',
#   'cinchona',
#   'cinnamon_tree',
#   'cladogram',
#   'clothes_tree',
#   'clusia',
#   'coat_tree',
#   'cockspur',
#   'cocobolo',
#   'coffee',
#   'combretum',
#   'common_fig_tree',
#   'conacaste',
#   'conifer',
#   'coral_tree',
#   'coralwood',
#   'cordeauxia_edulis',
#   'cordyline',
#   'cork_tree',
#   'cottonwood',
#   'cotylelobium_melanoxylon',
#   'couratari',
#   'couroupita_guianensis',
#   'crab_tree',
#   'cumball_tree',
#   'cycad',
#   'cynometra',
#   'dacryodes_edulis',
#   'dagame',
#   'daroo_tree',
#   'date_tree',
#   'dead_tree',
#   'decision_tree',
#   'delonix',
#   'devilwood',
#   'dhak',
#   'dhawa',
#   'diplotropis',
#   'dipterocarp',
#   'dipteryx',
#   'dita',
#   'divi_divi',
#   'dogwood_tree',
#   'dragon_tree',
#   'drumstick_tree',
#   'drunken_trees',
#   'ebony',
#   'elephant_tree',
#   'elm',
#   'family_tree',
#   'fever_tree',
#   'fig_tree',
#   'filbert',
#   'fir_tree',
#   'flame_tree',
#   'foetidia',
#   'food_tree',
#   'fringe_tree',
#   'fruit_tree',
#   'gallow_tree',
#   'gallows_tree',
#   'garcinia_indica',
#   'garrya',
#   'garryaceae',
#   'gatten_tree',
#   'giant_chinkapin',
#   'ginkgo_biloba',
#   'gleditsia',
#   'gliricidia',
#   'gmelina_arborea',
#   'gnetum_gnemon',
#   'granadilla_tree',
#   'grass_tree',
#   'grias',
#   'grove_nature',
#   'grumichama',
#   'guama',
#   'guinea_pepper',
#   'gum_tree',
#   'gutta_percha_tree',
#   'gymnospermous_tree',
#   'hackberry',
#   'hanging_tree',
#   'hat_tree',
#   'hazel',
#   'heaven_tree',
#   'hedge_tree',
#   'hemp_tree',
#   'hickory_tree',
#   'hip_tree',
#   'holly',
#   'hop_hornbeam',
#   'hornbeam',
#   'horse_chestnut_tree',
#   'horseradish_tree',
#   'hydnocarpus_laurifolia',
#   'ice_cream_bean',
#   'idesia',
#   'illicium',
#   'incense_tree',
#   'indian_beech',
#   'inga',
#   'ivory_tree',
#   'jamaica_dogwood',
#   'jamaica_walnut',
#   'jamaican_cherry',
#   'japanese_pagoda_tree',
#   'jellyfish_tree',
#   'jesse_tree',
#   'joshua_tree',
#   'judas_tree',
#   'juniper',
#   'kapok_tree',
#   'kentucky_coffee_tree',
#   'ketembilla',
#   'keurboom',
#   'kingwood',
#   'kino',
#   'kowhai',
#   'kurepa_tree',
#   'lacebark',
#   'lancewood',
#   'lanseh_tree',
#   'larch_tree',
#   'large_tree',
#   'laurales',
#   'laurelwood',
#   'lead_tree',
#   'lemonwood',
#   'lepidobotrys',
#   'lepidodendron',
#   'leucaena',
#   'linden',
#   'linden_tree',
#   'lipstick_tree',
#   'locust_tree',
#   'luma_plant',
#   'lychee_tree',
#   'macadamia_tree',
#   'magnolia_tree',
#   'mahogany',
#   'mahogany_tree',
#   'mahwa_tree',
#   'maidenhair_tree',
#   'manchineel_tree',
#   'mango',
#   'mangosteen_tree',
#   'mangrove_tree',
#   'manila_tamarind',
#   'manilkara',
#   'manteltree',
#   'maple_tree',
#   'marblewood',
#   'maria',
#   'marmalade_tree',
#   'mayeng',
#   'mescal_bean',
#   'mexican_hand_tree',
#   'millettia',
#   'money_tree',
#   'montezuma',
#   'mora_plant',
#   'moringa',
#   'msasa',
#   'myrtle_leaved_orange',
#   'nakedwood',
#   'natural_christmas_tree',
#   'necklace_tree',
#   'neem',
#   'nicker_tree',
#   'nitta_tree',
#   'oak',
#   'oak_chestnut',
#   'oak_tree',
#   'obeche',
#   'ochna_integerrima',
#   'olea_capensis',
#   'olive',
#   'olive_tree',
#   'opepe',
#   'ople_tree',
#   'order_tree',
#   'padauk',
#   'palm',
#   'palm_tree',
#   'palo_verde',
#   'pandanus',
#   'parmentiera_cereifera',
#   'peanut_tree',
#   'pear_tree',
#   'pecan_tree',
#   'pencil_tree',
#   'pepper_tree',
#   'peruvian_balsam',
#   'phylogenetic_tree',
#   'pine_tree',
#   'plane_tree',
#   'planer_tree',
#   'plum_tree',
#   'pollard',
#   'pomegranate_tree',
#   'poon',
#   'poplar_tree',
#   'populus',
#   'pouteria',
#   'prickly_ash',
#   'pride_of_burma',
#   'princewood',
#   'prosopis_cineraria',
#   'prosopis_nigra',
#   'prunoideae',
#   'pterocarpus',
#   'pterospermum',
#   'puka',
#   'punic_tree',
#   'quandong',
#   'quillaja_saponaria',
#   'quira',
#   'radermachera_sinica',
#   'rain_tree',
#   'rauwolfia',
#   'red_black_tree',
#   'red_sandalwood',
#   'red_silk_cotton_tree',
#   'redbud',
#   'regression_tree',
#   'ribbon_tree',
#   'rood_tree',
#   'rose_chestnut',
#   'rosewood',
#   'rubber_tree',
#   'saddle_tree',
#   'sandalwood_tree',
#   'sapling',
#   'sappanwood',
#   'saraca',
#   'saraca_declinata',
#   'satinwood',
#   'scarlet_wisteria_tree',
#   'scrub_beefwood',
#   'search_tree',
#   'sequoioideae',
#   'service_tree',
#   'shade_tree',
#   'shaving_brush_tree',
#   'shingle_tree',
#   'shoe_tree',
#   'sigillaria',
#   'silver_ash',
#   'silver_tree',
#   'sissoo',
#   'skill_tree',
#   'snag',
#   'soapberry',
#   'souari',
#   'southern_beech',
#   'southern_live_oak',
#   'spanish_tamarind',
#   'spanning_tree',
#   'spondias_mombin',
#   'spruce_tree',
#   'stemma',
#   'strawberry_tree',
#   'strychnine_tree',
#   'suffix_tree',
#   'suicide_tree',
#   'sulfur_tree',
#   'sulphur_tree',
#   'tagasaste',
#   'tall_tree',
#   'tanbark_oak',
#   'tea_tree',
#   'teak',
#   'technology_tree',
#   'terminalia_australis',
#   'tetracentron',
#   'theobroma',
#   'timber_tree',
#   'tipu',
#   'tipuana',
#   'tolu_tree',
#   'tonka_bean',
#   'tree_of_knowledge',
#   'treelet',
#   'trema',
#   'trestle_tree',
#   'trifoliate_orange',
#   'trochodendron',
#   'tulipwood_tree',
#   'tung_tree',
#   'tupelo',
#   'turreae',
#   'ulmaceae',
#   'vann',
#   'virola',
#   'walnut_tree',
#   'wampee',
#   'warszewiczia',
#   'warszewiczia_coccinea',
#   'water_tupelo',
#   'wayfaring_tree',
#   'weeping_willow',
#   'wheel_tree',
#   'white_mangrove',
#   'wild_fig',
#   'wild_medlar',
#   'wild_tamarind',
#   'willow',
#   'willow_tree',
#   "winter's_bark",
#   'wrightia',
#   'yellowwood',
#   'zebrawood',
#   'zollernia'},
#  'mammal': {'aardvark',
#   'aardwolf',
#   'abominable_snowman',
#   'afroinsectiphilia',
#   'afrotheria',
#   'ape',
#   'archonta',
#   'arctotherium',
#   'atlantogenata',
#   'australosphenida',
#   'axis',
#   'aye_aye',
#   'baboon',
#   'badger',
#   'bear',
#   'beira',
#   'bongo',
#   'bonobo',
#   'bovini',
#   'camel',
#   'canine',
#   'capra',
#   'castoroides',
#   'condylarth',
#   'denisova_hominin',
#   'dik_dik',
#   'dingo',
#   'dire_wolf',
#   'dog',
#   'drill',
#   'eidolon',
#   'elephant',
#   'epitheria',
#   'equus',
#   'euarchonta',
#   'euarchontoglires',
#   'female_mammal',
#   'ferae',
#   'fin_whale',
#   'fisher',
#   'fossa',
#   'fossorial_mammal',
#   'gambian_pouched_rat',
#   'gazelle',
#   'genet',
#   'glires',
#   'gnawer',
#   'gnu',
#   'goa',
#   'great_ape',
#   'hippopotamus',
#   'horse',
#   'hystrix',
#   'javan_rhinoceros',
#   'jiangxia',
#   'kobus',
#   'lagomorpha',
#   'lama',
#   'lamia',
#   'laurasiatheria',
#   'leopard',
#   'mare',
#   'meriones',
#   'metatheria',
#   'metatherian',
#   'monotreme',
#   'mops',
#   'narwhal',
#   'northern_long_eared_bat',
#   'pachydermata',
#   'paenungulata',
#   'palaeochiropteryx',
#   'pegasoferae',
#   'placental',
#   'placental_mammal',
#   'polar_bear',
#   'pouched_mammal',
#   'proconsul',
#   'procyon',
#   'prototheria',
#   'prototherian',
#   'rhinoceros',
#   'sahelanthropus',
#   'sasquatch',
#   'sheep',
#   'shepherd',
#   'small_mammal',
#   'steinbock',
#   'tarsier',
#   'tethytheridae',
#   'theria',
#   'thylacine',
#   'tiglon',
#   'tupaia',
#   'tusker',
#   'ungulate',
#   'ursus',
#   'vampire',
#   'weasel',
#   'werewolf',
#   'western_black_rhinoceros',
#   'whale',
#   'woolly_mammoth',
#   'yak',
#   'young_mammal',
#   'zooamata'},
#  'building': {'abattoir',
#   'abraham_lincoln',
#   'air_force_recruitment_center',
#   'airport_terminal',
#   'annex',
#   'apartment_building',
#   'aqua',
#   'architecture',
#   'army_recruitment_center',
#   'astronomical_observatory_building',
#   'aura',
#   'aviary',
#   'bank_building',
#   'barn',
#   'bathhouse',
#   'bell_tower',
#   'belvoir',
#   'boathouse',
#   'bowling_alley',
#   'bowling_green',
#   'brothel',
#   'bungalow',
#   'bus_station',
#   'center',
#   'chapterhouse',
#   'clubhouse',
#   'commercial_building',
#   'control_tower',
#   'convent',
#   'detached_house',
#   'dormitory',
#   'farm_building',
#   'farmhouse',
#   'feedlot',
#   'fire_station',
#   'firetrap',
#   'fort_orange',
#   'foundry',
#   'french_quarter',
#   'gambling_house',
#   'gazebo',
#   'government_building',
#   'grain_elevator',
#   'greenhouse',
#   'hall',
#   'hall_of_fame',
#   'handicap_accessible_building',
#   'high_roller',
#   'historic_building',
#   'horseshoe_curve',
#   'hospital',
#   'hotel',
#   'hotel_casino',
#   'house',
#   'house_country',
#   'large_building',
#   'library',
#   'lighthouse',
#   'lodge',
#   'lookout_tower',
#   'marble_edifice',
#   'medical_building',
#   'military_building',
#   'ministry',
#   'montevideo',
#   'morgue',
#   'mount',
#   'multilevel_building',
#   'national_monument',
#   'navy_recruitment_center',
#   'observatory',
#   'office_building',
#   'omega',
#   'one_story_building',
#   'opium_den',
#   'organization_headquarters',
#   'outbuilding',
#   'packinghouse',
#   'pinnacle',
#   'place_of_worship',
#   'planetarium',
#   'plaza',
#   'police_recruitment_center',
#   'police_station',
#   'post_office_building',
#   'presbytery',
#   'pub',
#   'q1',
#   'radar_station',
#   'residential_building',
#   'rest_house',
#   'restaurant',
#   'rink',
#   'roman_building',
#   'rotunda',
#   'ruin',
#   'safe_house',
#   'school',
#   'school_building',
#   'shooting_gallery',
#   'signal_box',
#   'silo',
#   'skyscraper',
#   'small_building',
#   'stable',
#   'student_union',
#   'sunnyside',
#   'taliesin',
#   'tall_building',
#   'tavern',
#   'telecom_hotel',
#   'temple',
#   'thatched_roof_building',
#   'theater',
#   'train_station',
#   'trianon',
#   'trinity',
#   'two_story',
#   'united_states_post_office',
#   'villa',
#   'white_house',
#   'whorehouse',
#   'world_trade_center'},
#  'insect': {'abax',
#   'acerra',
#   'acropolis',
#   'adela',
#   'agdistis',
#   'alsophila',
#   'amphiesmenoptera',
#   'ant',
#   'anthrax',
#   'apollo',
#   'aporia',
#   'apterygota',
#   'archaeognatha',
#   'archduke',
#   'archon',
#   'ariadne',
#   'aristotelia',
#   'ash_meadows_naucorid',
#   'asian_giant_hornet',
#   'beetle',
#   'bird_louse',
#   'brick',
#   'bug',
#   'butterfly',
#   'cicada',
#   'coccus',
#   'cockroach',
#   'collembolan',
#   'corybantes',
#   'creon',
#   'danaus',
#   'daphnis',
#   'defoliator',
#   'dictyoptera',
#   'dictyopterous_insect',
#   'dipterous_insect',
#   'earwig',
#   'eastern_cicada_killer',
#   'embioptera',
#   'emperor',
#   'endopterygota',
#   'engrailed',
#   'enyo',
#   'ephemera',
#   'ephemerid',
#   'epiblema',
#   'epione',
#   'epiphora',
#   'epsilon',
#   'eudaemonia',
#   'exopterygota',
#   'firefly',
#   'flame',
#   'flea',
#   'fly',
#   'gallfly',
#   'giant_weta',
#   'globitermes_sulphureus',
#   'goliathus',
#   'gothic',
#   'grayling',
#   'hamadryas',
#   'harmonia',
#   'hemipterous_insect',
#   'herald',
#   'hesperia',
#   'heteropterous_insect',
#   'heteropteryx_dilatata',
#   'holometabola',
#   'homopterous_insect',
#   'hornet',
#   'hymenoptera',
#   'hymenopterous_insect',
#   'ice_crawler',
#   'imago',
#   'lamia',
#   'leaf_miner',
#   'lepidopteran',
#   'lepidopterous_insect',
#   'lethe',
#   'locust',
#   'louse',
#   'lucia',
#   'mantis',
#   'maybug',
#   'mayfly',
#   'mecoptera',
#   'mecopteran',
#   'melinda',
#   'mellininae',
#   'meru',
#   'mosquito',
#   'musca',
#   'myrmecia',
#   'neoptera',
#   'neuropteron',
#   'nutmeg',
#   'nymph',
#   'odonata',
#   'odonate',
#   'omicron',
#   'orthoptera',
#   'orthopterous_insect',
#   'palaeoptera',
#   'pawnee_montane_skipper',
#   'phasmatodea',
#   'phasmid',
#   'pieris',
#   'plecoptera',
#   'pollinator',
#   'praxis',
#   'praying_mantis',
#   'proboscis',
#   'proturan',
#   'psocoptera',
#   'psocopterous_insect',
#   'pterygota',
#   'pupa',
#   'pyrausta',
#   'queen',
#   'redonda',
#   'reduviidae',
#   'rhaphigaster_nebulosa',
#   'rhodesia',
#   'salamis',
#   'sandfly',
#   'sandgroper',
#   'shark',
#   'silverfish',
#   'skipper',
#   'small_heath',
#   'snakefly',
#   'social_insect',
#   'speckled_wood',
#   'sphinx',
#   'stonefly',
#   'strepsiptera',
#   'sycamore',
#   'tarantula_hawk',
#   'termite',
#   'thecla',
#   'thrips',
#   'thysania_agrippina',
#   'thysanopter',
#   'thysanura',
#   'thysanuran_insect',
#   'tmolus',
#   'trichoptera',
#   'trichopterous_insect',
#   'true_bug',
#   'usta',
#   'vanessa',
#   'viceroy',
#   'wasp',
#   'web_spinner',
#   'weta',
#   'white_ant',
#   'worker',
#   'zeta',
#   'zoraptera'},
#  'tool': {'abrader',
#   'bender',
#   'clincher',
#   'comb',
#   'cutting_implement',
#   'drill',
#   'drill_bit',
#   'eolith',
#   'fork',
#   'gang',
#   'garden_tool',
#   'gardening_tool',
#   'grapnel',
#   'hack',
#   'hand_tool',
#   'hardware_tool',
#   'hoe',
#   'hole_making_tool',
#   'iron',
#   'jack',
#   'ladder',
#   'machine_tool',
#   'manual_tool',
#   'neolith',
#   'paleolith',
#   'pestle',
#   'plow',
#   'plumbing_tool',
#   'power_tool',
#   'punch',
#   'rake',
#   'ram',
#   'rounder',
#   'rubber_stamp',
#   'saw_set',
#   'shaping_tool',
#   'stapler',
#   'stationary_tool',
#   'stencil',
#   'strickle',
#   'stylus',
#   'tamp',
#   'tap',
#   'upset'},
#  'material': {'abrasive',
#   'adhesive_material',
#   'aggregate',
#   'ammunition',
#   'animal_material',
#   'atom',
#   'ballast',
#   'bedding_material',
#   'bimetal',
#   'builder',
#   'chemical',
#   'coloring_material',
#   'composite_material',
#   'conductor',
#   'contaminant',
#   'copy',
#   'detritus',
#   'diamagnet',
#   'discharge',
#   'dust',
#   'earth',
#   'elastomer',
#   'fiber',
#   'filling',
#   'floccule',
#   'fluff',
#   'foam',
#   'hazmat',
#   'homogenate',
#   'humate',
#   'impregnation',
#   'insulator',
#   'mineral',
#   'packaging',
#   'packing_material',
#   'paper',
#   'particulate',
#   'plant_material',
#   'precursor',
#   'radioactive_material',
#   'railing',
#   'raw_material',
#   'recycling',
#   'rehash',
#   'rind',
#   'rock',
#   'roofing',
#   'sealing_material',
#   'sorbate',
#   'sorbent',
#   'thickening',
#   'toner',
#   'transparent_substance',
#   'undercut',
#   'vernix',
#   'wad',
#   'waste'},
#  'reptile': {'abronia',
#   'amphisbaena',
#   'anapsid',
#   'basiliscus',
#   'black_mamba',
#   'boa',
#   'cerastes',
#   'crocodilian',
#   'diapsid',
#   'diapsida',
#   'dracaena',
#   'draco_volans',
#   'dragon',
#   'egyptian_cobra',
#   'eureptilia',
#   'galtonia',
#   'horned_lizard',
#   'king_cobra',
#   'lachesis',
#   'large_reptile',
#   'male_reptile',
#   'neodiapsida',
#   'plesiosaur',
#   'python',
#   'pyxis',
#   'salvadora',
#   'squamata',
#   'synapsid',
#   'timon',
#   'titanoboa',
#   'virginia'},
#  'language': {'abstract_language',
#   'artificial_language',
#   'barrage',
#   'class_based_language',
#   'computer_language',
#   'curly_bracket_language',
#   'dead_language',
#   'demotic',
#   'domain_specific_language',
#   'dynamic_language',
#   'english',
#   'fictional_language',
#   'human_language',
#   'ido',
#   'indigenous_language',
#   'informal_language',
#   'ligurian',
#   'lingua_franca',
#   'metalanguage',
#   'mooring',
#   'native_language',
#   'natural_language',
#   'neo',
#   'object_language',
#   'sign_language',
#   'slanguage',
#   'source_language',
#   'static_language',
#   'statically_typed_language',
#   'string_of_words',
#   'style_sheet_language',
#   'superstratum',
#   'usage',
#   'words'},
#  'mountain': {'abu',
#   'alp',
#   'altenburg',
#   'alu',
#   'aroania',
#   'beacon_hill',
#   'ben',
#   'bernstein',
#   'billy_mitchell',
#   'blender',
#   'brand',
#   'bromberg',
#   'castor',
#   'cer',
#   'dallol',
#   'dom',
#   'first',
#   'fujiyama',
#   'helm',
#   'herzberg',
#   'ipf',
#   'jenner',
#   'loser',
#   'mont_blanc',
#   'montserrat',
#   'mount_adams',
#   'mount_olympus',
#   'peca',
#   'pollux',
#   'seamount',
#   'solfatara',
#   'speer',
#   'steinberg',
#   'stockhorn',
#   'stol',
#   'stratovolcano',
#   'totenkopf',
#   'vogel',
#   'volcano',
#   'vulcan',
#   'wank',
#   'yushan',
#   'zimba',
#   'zlatar'},
#  'mineral': {'acanthite',
#   'actinolite',
#   'adamite',
#   'ader_wax',
#   'aegirine',
#   'alabaster',
#   'allanite',
#   'amblygonite',
#   'amphibole',
#   'amphibole_group',
#   'anatase',
#   'andalusite',
#   'andesine',
#   'andorite',
#   'anglesite',
#   'anhydrite',
#   'annabergite',
#   'antimony',
#   'apatite',
#   'apophyllite',
#   'aragonite',
#   'argentite',
#   'argyrodite',
#   'arsenic',
#   'arsenopyrite',
#   'asphalt',
#   'astrophyllite',
#   'atacamite',
#   'augite',
#   'aurichalcite',
#   'austinite',
#   'autunite',
#   'axinite',
#   'azurite',
#   'babingtonite',
#   'baddeleyite',
#   'barite',
#   'bastnasite',
#   'bauxite',
#   'benitoite',
#   'berthierite',
#   'beryl',
#   'beudanite',
#   'biotite',
#   'bismuth',
#   'bismuthinite',
#   'bixbyite',
#   'boehmite',
#   'boleite',
#   'boracite',
#   'borax',
#   'bornite',
#   'boulangerite',
#   'bournonite',
#   'brochantite',
#   'brookite',
#   'brucite',
#   'bustamite',
#   'calamine',
#   'calaverite',
#   'calcite',
#   'caledonite',
#   'carnallite',
#   'carnotite',
#   'cassiterite',
#   'celestine',
#   'celestite',
#   'cerussite',
#   'chalcanthite',
#   'chalcedony',
#   'chalcocite',
#   'chalcopyrite',
#   'childrenite',
#   'chloanthite',
#   'chloragyrite',
#   'chlorapatite',
#   'chlorite',
#   'chondrodite',
#   'chromite',
#   'chrysoberyl',
#   'chrysocolla',
#   'cinnabar',
#   'clinoclase',
#   'clinozoisite',
#   'cobaltite',
#   'coesite',
#   'colemanite',
#   'columbite',
#   'columbite_tantalite',
#   'conichalcite',
#   'copper',
#   'cordierite',
#   'cornetite',
#   'corundom',
#   'corundum',
#   'covellite',
#   'cristobalite',
#   'crocoite',
#   'crocolite',
#   'cryolite',
#   'cubanite',
#   'cuprite',
#   'cyanotrichite',
#   'danburite',
#   'datolite',
#   'descloizite',
#   'diamond',
#   'diopside',
#   'dioptase',
#   'dolomite',
#   'dumortierite',
#   'dyscrasite',
#   'earth_color',
#   'emery',
#   'enargite',
#   'enstatite',
#   'epidote',
#   'epsomite',
#   'erythrite',
#   'ettringite',
#   'euclase',
#   'feldspar',
#   'ferberite',
#   'fergusonite',
#   'fluorite',
#   'franklinite',
#   'gadolinite',
#   'galena',
#   'garnet',
#   'garnierite',
#   'gaspeite',
#   'gem',
#   'germanite',
#   'gibbsite',
#   'glauberite',
#   'glauconite',
#   'goethite',
#   'goosecreekite',
#   'graphite',
#   'greenockite',
#   'gummite',
#   'gypsum',
#   'gyrolite',
#   'hafnon',
#   'halite',
#   'hausmannite',
#   'heavy_spar',
#   'hedenbergite',
#   'heliotrope',
#   'helvite',
#   'hematite',
#   'hemimorphite',
#   'hornblende',
#   'howlite',
#   'huebnerite',
#   'hureaulite',
#   'hydroboracite',
#   'hydrozincite',
#   'hypersthene',
#   'ilmenite',
#   'ilvaite',
#   'inesite',
#   'iron',
#   'iron_nickel',
#   'jadeite',
#   'jamesonite',
#   'jarosite',
#   'johannsenite',
#   'kainite',
#   'kaolinite',
#   'kermesite',
#   'kernite',
#   'kieserite',
#   'koettigite',
#   'kyanite',
#   'langbeinite',
#   'larderellite',
#   'lazulite',
#   'lazurite',
#   'lead',
#   'legrandite',
#   'lepidocrocite',
#   'lepidolite',
#   'leucite',
#   'libethenite',
#   'limonite',
#   'linarite',
#   'liroconite',
#   'lithiophilite',
#   'loellingite',
#   'ludlamite',
#   'magnesiochromite',
#   'magnesite',
#   'magnetite',
#   'malachite',
#   'maltha',
#   'manganite',
#   'marcasite',
#   'meerschaum',
#   'melanophlogite',
#   'melanterite',
#   'mesolite',
#   'miargyrite',
#   'mica',
#   'millerite',
#   'mimetite',
#   'minium',
#   'molybdenite',
#   'monazite',
#   'moonstone',
#   'muscovite',
#   'nagyagite',
#   'natrojarosite',
#   'nepheline',
#   'nephelinite',
#   'neptunite',
#   'nickelite',
#   'niobite',
#   'nitrocalcite',
#   'olivenite',
#   'olivine',
#   'omphacite',
#   'opal',
#   'ore',
#   'orpiment',
#   'osmiridium',
#   'otavite',
#   'paradamite',
#   'pargasite',
#   'pectolite',
#   'pentlandite',
#   'periclase',
#   'perthite',
#   'phenakite',
#   'phologopite',
#   'phosgenite',
#   'pinite',
#   'plagioclase_feldspar',
#   'pollucite',
#   'polybasite',
#   'potash',
#   'prehnite',
#   'proustite',
#   'pseudobrookite',
#   'pseudomalachite',
#   'psilomelane',
#   'pumpellyite',
#   'pyrargyrite',
#   'pyrite',
#   'pyrolusite',
#   'pyromorphite',
#   'pyrophyllite',
#   'pyroxene',
#   'pyroxmangite',
#   'pyrrhotite',
#   'quartz',
#   'rammelsbergite',
#   'realgar',
#   'red_clay',
#   'rhodochrosite',
#   'rhodonite',
#   'riebeckite',
#   'rockbridgeite',
#   'romanechite',
#   'roselite',
#   'rutile',
#   'safflorite',
#   'sal_ammoniac',
#   'samarskite',
#   'samsonite',
#   'sapphirine',
#   'scapolite',
#   'scheelite',
#   'scorodite',
#   'selenite',
#   'senarmontite',
#   'serandite',
#   'serpentine',
#   'siderite',
#   'sillimanite',
#   'skutterudite',
#   'smaltite',
#   'smithsonite',
#   'sodalite',
#   'solid_adamsite',
#   'solid_mercury',
#   'solid_sodium_chloride',
#   'spangolite',
#   'spar',
#   'sphaerocobaltite',
#   'sphalerite',
#   'spinel',
#   'spodumene',
#   'stannite',
#   'staurolite',
#   'stephanite',
#   'stibarsen',
#   'stibnite',
#   'stishovite',
#   'strengite',
#   'strontianite',
#   'sulfur',
#   'sylvanite',
#   'sylvite',
#   'talc',
#   'tantalite',
#   'tellurium',
#   'tephroite',
#   'tetrahedrite',
#   'thenardite',
#   'thorianite',
#   'thorite',
#   'thorogummite',
#   'thortveitite',
#   'tincalconite',
#   'topaz',
#   'torbernite',
#   'tourmaline',
#   'tremolite',
#   'tridymite',
#   'triphlite',
#   'turquoise',
#   'tyrolite',
#   'ulexite',
#   'ullmannite',
#   'uraninite',
#   'uranocircite',
#   'uranophane',
#   'valentinite',
#   'vanadinite',
#   'vermiculite',
#   'vesuvianite',
#   'vivianite',
#   'wavellite',
#   'weloganite',
#   'willemite',
#   'witherite',
#   'wolframite',
#   'wollastonite',
#   'wulfenite',
#   'wurtzite',
#   'xenotime',
#   'yugawaralite',
#   'zeolite',
#   'zeolite_mineral',
#   'zeunerite',
#   'zinc_blende',
#   'zincite',
#   'zinkenite',
#   'zinnwaldite',
#   'zircon',
#   'zoisite'},
#  'fruit': {'accessory_fruit',
#   'achene',
#   'acorn',
#   'adams_pearmain_apple',
#   'african_oil_palm_fruit',
#   'aggregate_fruit',
#   'alligator_pear',
#   'almond',
#   'ambrosia_apple',
#   'apple',
#   'apricot',
#   'aubergine',
#   'bean',
#   'berry',
#   'black_peppercorn',
#   'blackberry',
#   'blueberry',
#   'braeburn_apple',
#   'buckthorn_berry',
#   'buffalo_nut',
#   'cereal_grain',
#   'cherry',
#   'cherry_tomato',
#   'chestnut',
#   'chokecherry',
#   'cobnut',
#   'cocoa_pod',
#   'coconut',
#   'coffee_cherry',
#   'compound_fruit',
#   'cotton_boll',
#   'cranberry',
#   'cubeb',
#   'cucumber',
#   'drupe',
#   'ear',
#   'edible_fruit',
#   'eggplant',
#   'flax_fruit',
#   'fourth_of_july_tomato',
#   'fruitlet',
#   'gala_apple',
#   'golden_delicious_apple',
#   'gourd',
#   'granny_smith_apple',
#   'hagberry',
#   'hazelnut',
#   'hip',
#   'jazz_apple',
#   'jonathan',
#   'juniper_berry',
#   'kiwifruit',
#   'legume',
#   'lychee',
#   'macadamia_nut',
#   'mango',
#   'marasca',
#   'may_apple',
#   'mcintosh_apple',
#   'melon',
#   'nut',
#   'nutmeg_fruit',
#   'okra',
#   'olive',
#   'pear',
#   'pepper',
#   'pineapple',
#   'plum',
#   'plum_tomato',
#   'pod',
#   'pome',
#   'pomegranate',
#   'prairie_gourd',
#   'pumpkin',
#   'pyxidium',
#   'quandong',
#   'raspberry',
#   'red_delicious_apple',
#   'ripe_fruit',
#   'roma_tomato',
#   'rowanberry',
#   'schizocarp',
#   'seed',
#   'sesame_fruit',
#   'squash',
#   'strawberry',
#   'three_sisiters_tomato',
#   'tomato',
#   'vanilla_bean',
#   'walnut',
#   'watermelon',
#   'white_grape',
#   'wild_cherry'},
#  'flower': {'achimenes',
#   'actinotus_helianthi',
#   'african_daisy',
#   'african_violet',
#   'ageratum',
#   'aletris',
#   'alstroemeria',
#   'alyssum',
#   'amancae',
#   'amaryllis',
#   'ammobium',
#   'anemone',
#   'apetalous_flower',
#   'asphodelus_ramosus',
#   'aster',
#   'aubrieta',
#   "baby's_breath",
#   'banksia_ericifolia',
#   'bartonia',
#   'begonia',
#   'bellis',
#   'bellis_perennis',
#   'bellwort',
#   'billy_buttons',
#   'blazing_star',
#   'bloomer',
#   'blue_daisy',
#   'blue_eyed_african_daisy',
#   'blue_eyed_meterary',
#   'brass_buttons',
#   'bud',
#   'bush_violet',
#   'butomus',
#   'butterfly_flower',
#   'calceolaria',
#   'calendula',
#   'california_poppy',
#   'calla_lily',
#   'calochortus_nuttallii',
#   'campanula_rotundifolia',
#   'candytuft',
#   'cantua_buxifolia',
#   'cape_marigold',
#   'carolina_spring_beauty',
#   'castilleja',
#   'catananche',
#   'centaury',
#   'chasmanthe',
#   'china_aster',
#   'christmas_bells',
#   'chrysanthemum',
#   'cineraria',
#   'clematis',
#   'columbine',
#   'commelina',
#   'composite',
#   'coneflower',
#   'coral_drops',
#   'cornflower',
#   'corydalis',
#   'cosmos',
#   'cosmos_bipinnatus',
#   'cosmos_plant',
#   'cosmos_sulphureus',
#   'costus_speciosus',
#   'cotton_rose',
#   'cowherb',
#   'crinum',
#   'crocosmia',
#   'cyclamen',
#   'cymopterus_multinervatus',
#   'cyrtochiloides',
#   'daffodil',
#   'dahlia',
#   'daisy',
#   'damask_violet',
#   'dandelion_flower',
#   'delphinium',
#   "dog's_mercury",
#   'dracula_orchid',
#   'duke_of_durham',
#   'easter_daisy',
#   'epidendrum_radicans',
#   'eremurus_robustus',
#   'erysimum_baeticum',
#   'erysimum_mediohispanicum',
#   'erysimum_nevadense',
#   'erythronium',
#   'fig_marigold',
#   "florest's_cineraria",
#   'floret',
#   'flower_bud',
#   'flower_of_angelica_sinensis',
#   'flower_of_hypericum_perforatum',
#   'forget_not',
#   'four_o_clock',
#   'fritillaria_meleagris',
#   'gagea',
#   'gaillardia',
#   'gardenia',
#   'gazania',
#   'gentian',
#   'geranium_cinereum',
#   'gerardia',
#   'gerbera',
#   'globe_amaranth',
#   'golden_age',
#   'goldenhead',
#   'grape_hyacinth',
#   'guernsey_lily',
#   'gymea_lily',
#   'heliconia_tortuosa',
#   'heliophila',
#   'hellebore',
#   'hemerocallis_minor',
#   'hibiscus',
#   'hidalgoa',
#   'hidalgoa_ternata',
#   'hippeastrum',
#   'hollyhock',
#   'horn_poppy',
#   'hymenocallis',
#   'hymenocallis_speciosa',
#   'hypericum_calycinum',
#   'iberis_sempervirens',
#   'impatiens_walleriana',
#   'inflorescence',
#   'kentucky_wisteria',
#   'kingfisher_daisy',
#   'kniphofia',
#   'lace_flower_vine',
#   'laelia_albida',
#   'lesser_celandine',
#   'lilium_columbianum',
#   'lilium_humboldtii',
#   'limnanthes_douglasii',
#   'liparophyllum',
#   'lobelia_deckenii',
#   'lobelia_oligophylla',
#   'lobelia_telekii',
#   'lobelia_thapsoidea',
#   'london_pride_plant',
#   'lotus_uliginosus',
#   'luculia',
#   'lunaria',
#   'lupin',
#   'lupinus_odoratus',
#   'lychnis',
#   'magnolia',
#   'malcolm_stock',
#   'marigold',
#   'matilija_poppy',
#   'mexican_sunflower',
#   'mistflower',
#   'monochaetum_floribundum',
#   'myosurus',
#   'nasturtium',
#   'nelumbo_lutea',
#   'nephrophyllidium',
#   'nigella',
#   'nosegay',
#   'nymphaea',
#   'nymphaea_alba',
#   'nymphaea_capensis',
#   'nymphaeaceae',
#   'nymphoides',
#   'oenothera',
#   'orchid',
#   'osteospermum',
#   'oxeye_daisy',
#   'painted_daisy',
#   'parul',
#   'pasque_flower',
#   'passiflora_caerulea',
#   'pelargonium',
#   'peony',
#   'petrea',
#   'petunia',
#   "pheasant's_eye",
#   'phlox_flower',
#   'pink',
#   'pollination_syndrome',
#   'poppy',
#   'portulaca',
#   'prairie_rocket',
#   'primula',
#   'primula_auricula',
#   'primula_beesiana',
#   'primula_elatior',
#   'primula_veris',
#   'primula_vulgaris',
#   'protea_cynaroides',
#   'pulsatilla_alpina',
#   'pyoli',
#   'rafflesia',
#   'ranunculus',
#   'ray_flower',
#   'red_valerian',
#   'rocket_larkspur',
#   'rose',
#   'rue_anemone',
#   'saintpaulia_inconspicua',
#   'sandwort',
#   'scabious',
#   'scarborough_lily',
#   'scarlet_musk_flower',
#   'schizopetalon',
#   'scilla',
#   'scorpionweed',
#   'senecio_squalidus',
#   'shortia',
#   'siam_tulip',
#   'silene',
#   'snapdragon',
#   'snowdrop',
#   'soapwort',
#   'sowbread',
#   'spathiphyllum',
#   'spring_beauty',
#   'star_of_bethlehem',
#   'stock',
#   'stokes_aster',
#   'strelitzia_nicolai',
#   'streptocarpus',
#   'sunflower',
#   'swan_river_daisy',
#   'sweet_alyssum',
#   'sweet_sultan',
#   'tagetes',
#   'texas_star',
#   'tidytips',
#   'tillandsia_excelsa',
#   'toadflax',
#   'tradescantia',
#   'trillium_nivale',
#   'tritonia_plant',
#   'trollius',
#   'tuberose',
#   'umbrellawort',
#   'ursinia',
#   'valerian',
#   'verbena',
#   'veronica',
#   'villarsia',
#   'viola_canadensis',
#   'viola_pedunculata',
#   'viola_plant',
#   'viola_tricolor',
#   'virginia_spring_beauty',
#   'virginia_stock',
#   'virginian_stock',
#   'wallflower',
#   'wandflower',
#   'waratah',
#   'watsonia_plant',
#   'werauhia_insignis',
#   'western_wall_flower',
#   'white_checkermallow',
#   'white_topped_aster',
#   'white_woolly_daisy',
#   'wildflower',
#   'woodland_star',
#   'xeranthemum',
#   'yareta',
#   'yellow_tack_stem',
#   'ylang_ylang',
#   'zantedeschia',
#   'zinnia'},
#  'color': {'achromatic_color',
#   'aubergine',
#   'azure',
#   'bright_color',
#   'chromatic_color',
#   'coloration',
#   'complexion',
#   'dark_color',
#   'eye_color',
#   'hair_color',
#   'heather_mixture',
#   'light_color',
#   'mauve',
#   'metallic_color',
#   'mottle',
#   'non_spectral_color',
#   'nonsolid_color',
#   'olive',
#   'primary_colour',
#   'shade',
#   'skin_color',
#   'spectral_color'},
#  'bird': {'acrocephalus',
#   'aix',
#   'akiapola_au',
#   'albatross',
#   'american_coot',
#   'american_goldfinch',
#   'anser',
#   'apodiform_bird',
#   'apus',
#   'aquatic_bird',
#   'aquila',
#   'ara',
#   'archaeopteryx',
#   'archaeornis',
#   'archilochus',
#   'ardea',
#   'argus',
#   'arses',
#   'athene',
#   'attila',
#   "attwater's_greater_prairie_chicken",
#   "audubon's_crested_caracara",
#   'auk',
#   'bee_eater',
#   'bird_of_passage',
#   'bird_of_prey',
#   'blackbird',
#   'blue_jay',
#   'bridled_white_eye',
#   'brown_headed_cowbird',
#   'california_clapper_rail',
#   'california_condor',
#   'cape_sable_seaside_sparrow',
#   'caprimulgiform_bird',
#   'caracara',
#   'cardinal',
#   'carinate',
#   'cassowary',
#   'catamenia',
#   'chen',
#   'chickadee',
#   'chicken',
#   'coastal_california_gnatcatcher',
#   'cock',
#   'columba',
#   'colymbiformes',
#   'coot',
#   'coraciiform_bird',
#   'corvus',
#   'cotinga',
#   'crane',
#   'crested_honeycreeper',
#   'crow',
#   'cuckoo',
#   'cuculiform_bird',
#   'dickeybird',
#   'diving_bird',
#   'dodo',
#   'domestic_fowl',
#   'domestic_turkey',
#   'dove',
#   'eagle',
#   'electron',
#   'elvira',
#   'emu',
#   'eos',
#   'eskimo_curlew',
#   'everglade_snail_kite',
#   'female_bird',
#   'finch',
#   'flavescent_flycatcher',
#   'flightless_bird',
#   'florida_grasshopper_sparrow',
#   'florida_scrub_jay',
#   'flycatcher',
#   'galbuliformes',
#   'gallinaceous_bird',
#   'gerfalcon',
#   'goldeneye',
#   'goldfinch',
#   'grackle',
#   'great_auk',
#   'grus',
#   'guam_broadbill',
#   'guam_rail',
#   'halcyon',
#   'hawaii_akepa',
#   'hawaii_creeper',
#   'hawaiian_common_moorhen',
#   'hawaiian_dark_rumped_petrel',
#   'hawaiian_duck',
#   'hawaiian_stilt',
#   'hawk',
#   'hen',
#   'hermit',
#   'hoatzin',
#   'honey_buzzard',
#   'huia',
#   'hummingbird',
#   'ibero_mesornis',
#   'ibis',
#   'inyo_california_towhee',
#   'jackdaw',
#   'jacobin',
#   'kauai_akialoa',
#   'kauai_o_o',
#   'kingfisher',
#   'kite',
#   'kittiwake',
#   'kiwi',
#   'kookaburra',
#   'large_bird',
#   'laysan_duck',
#   'laysan_finch',
#   'least_tern',
#   'light_footed_clapper_rail',
#   'man_of_war',
#   'mao',
#   'marbled_murrelet',
#   'mariana_common_moorhen',
#   'mariana_gray_swiftlet',
#   'masked_bobwhite',
#   'maui_akepa',
#   'maui_parrotbill',
#   'medium_sized_bird',
#   'merlin',
#   'merops',
#   'micronesian_megapode',
#   'migratory_bird',
#   'mino',
#   'mockingbird',
#   'modern_bird',
#   'molokai_creeper',
#   'nene',
#   'nester',
#   'nestor',
#   'new_world_oriole',
#   "newell'stownsend's_shearwater",
#   'night_bird',
#   'nightingale',
#   'nightjar',
#   'nihoa_millerbird',
#   'nonpasserine_bird',
#   'northern_bald_ibis',
#   'nukupu_u',
#   'o_u',
#   'oahu_creeper',
#   'ortolan',
#   'ostrich',
#   'ovenbird',
#   'owl',
#   'palila',
#   'parrot',
#   'passerine',
#   'peacock',
#   'pelican',
#   'penguin',
#   'petrel',
#   'pheasant',
#   'phoebe',
#   'pica',
#   'piciform_bird',
#   'picumnus',
#   'picus',
#   'pigeon',
#   'piopio',
#   'plover',
#   'po_ouli',
#   'poultry',
#   'prion',
# ...
#   'circle',
#   'column',
#   'concavity',
#   'connection',
#   'convexity',
#   'crookedness',
#   'curvature',
#   'distorted_shape',
#   'dullness',
#   'figure',
#   'flare',
#   'line',
#   'lobularity',
#   'narrowing',
#   'natural_shape',
#   'plane',
#   'plume',
#   'round_shape',
#   'roundness',
#   'sharpness',
#   'solid',
#   'square',
#   'straightness',
#   'stratification',
#   'topography',
#   'triangle'},
#  'instrument': {'analyzer',
#   'cautery',
#   'drafting_instrument',
#   'engine',
#   'extractor',
#   'harmonium',
#   'instrument_of_execution',
#   'instrument_of_punishment',
#   'measuring_instrument',
#   'medical_instrument',
#   'navigational_instrument',
#   'optical_instrument',
#   'plotter',
#   'scientific_instrument',
#   'sonograph',
#   'surveying_instrument',
#   'tracer',
#   'typing_supply',
#   'weapon',
#   'whip'},
#  'constellation': {'andromeda',
#   'aquarius',
#   'aquila',
#   'ara',
#   'aries',
#   'auriga',
#   'cancer',
#   'carina',
#   'cassiopeia',
#   'cepheus',
#   'columba',
#   'corvus',
#   'crater',
#   'cygnus',
#   'draco',
#   'eridanus',
#   'gemini',
#   'grus',
#   'hercules',
#   'horologium',
#   'hydra',
#   'indus',
#   'leo',
#   'lepus',
#   'libra',
#   'lupus',
#   'lynx',
#   'mensa',
#   'norma',
#   'orion',
#   'pavo',
#   'pegasus',
#   'perseus',
#   'phoenix',
#   'pisces',
#   'sagittarius',
#   'sculptor',
#   'taurus',
#   'vela',
#   'virgo',
#   'zodiac_constellation'},
#  'room': {'anechoic_chamber',
#   'anteroom',
#   'art_studio',
#   'back_room',
#   'backroom',
#   'ballroom',
#   'bank_vault',
#   'barroom',
#   'basement',
#   'bathroom',
#   'bedroom',
#   'belfry',
#   'billiard_room',
#   'boardroom',
#   'boiler_room',
#   'breathing_room',
#   'cardroom',
#   'cath_lab',
#   'cell',
#   'chamber',
#   'checkroom',
#   'classroom',
#   'clean_room',
#   'cloakroom',
#   'closet',
#   'clubroom',
#   'common_room',
#   'compartment',
#   'conference_room',
#   'control_room',
#   'court',
#   'courtroom',
#   'cubbyhole',
#   'cutting_room',
#   'dance_studio',
#   'darkroom',
#   'den',
#   'dinette',
#   'dining_room',
#   'door',
#   'dressing_room',
#   'durbar',
#   'elevator',
#   'engineering',
#   'examining_room',
#   'family_room',
#   'floor',
#   'furnace_room',
#   'gallery',
#   'garage',
#   'greenroom',
#   'guardroom',
#   'gymnasium',
#   'hall',
#   'hallway',
#   'headroom',
#   'hospital_room',
#   'houseroom',
#   'jail_cell',
#   'kitchen',
#   'laundry_room',
#   'library',
#   'library_room',
#   'living_room',
#   'living_space',
#   'lobby',
#   'locker_room',
#   'lounge',
#   'mailroom',
#   'manor_hall',
#   'newsroom',
#   'nursery',
#   'operating_room',
#   'parking',
#   'patient_room',
#   'poolroom',
#   'presence_chamber',
#   'rathole',
#   'reading_room',
#   'reception_room',
#   'records_room',
#   'recreation_room',
#   'restroom',
#   'room',
#   'rotunda',
#   'sauna',
#   'scriptorium',
#   'scullery',
#   'sea_room',
#   'seating',
#   'server_room',
#   'sewing_room',
#   'shipping_room',
#   'shower_room',
#   'showroom',
#   'sickbay',
#   'sickroom',
#   'single_room_office',
#   'sitting_room',
#   'smoking_room',
#   'squad_room',
#   'staffroom',
#   'standing_room',
#   'steam_bath',
#   'storage_room',
#   'storeroom',
#   'study',
#   'sun_parlor',
#   'sunroom',
#   'surgery',
#   'television_room',
#   'test_room',
#   'toilet',
#   'torture_chamber',
#   'utility_room',
#   'vestry',
#   'waiting_room',
#   'walk_in',
#   'war_room',
#   'washroom',
#   'workroom',
#   'workshop_room'},
#  'month': {'anomalistic_month',
#   'april',
#   'august',
#   'december',
#   'february',
#   'gregorian_month',
#   'islamic_month',
#   'january',
#   'jewish_month',
#   'july',
#   'june',
#   'lunar_month',
#   'march',
#   'may',
#   'november',
#   'october',
#   'september',
#   'sidereal_month',
#   'solar_month',
#   'year'},
#  'continent': {'antarctica',
#   'australia',
#   'traditional_continent',
#   'true_continent'},
#  'collectable': {'antique_furniture',
#   'beanie_baby',
#   'cane',
#   'dead_insect',
#   'device_used_for_smoking',
#   'figurine',
#   'flower',
#   'game_equipment_set',
#   'jewelry',
#   'medical_device',
#   'model',
#   'musical_instrument',
#   'navigation_device',
#   'pez_dispenser',
#   'railroad_set',
#   'rubber_stamp',
#   'scientific_instrument',
#   'sewing_supplies_market_category',
#   'shell',
#   'small_arm',
#   'sound_recording',
#   'sports_card',
#   'sticker',
#   'token',
#   'toy',
#   'trading_card',
#   'whistle',
#   'work_of_art'},
#  'religion': {'apophatism',
#   'bahaism',
#   'brahmanism',
#   'buddhism',
#   'cataphatism',
#   'christianity',
#   'church',
#   'cult',
#   'doctrine_of_analogy',
#   'ecclesiasticism',
#   'established_church',
#   'hinduism',
#   'islam',
#   'jainism',
#   'judaism',
#   'khalsa',
#   'local_traditional_religion',
#   'manichaeism',
#   'mithraism',
#   'mysticism',
#   'nature_worship',
#   'non_theistic_religion',
#   'paganism',
#   'paganism_religion',
#   'religious_denomination',
#   'revealed_religion',
#   'scientology',
#   'sect',
#   'shamanism',
#   'shinto',
#   'sikhism',
#   'taoism',
#   'theism',
#   'theistic_religion',
#   'unitarianism',
#   'wicca',
#   'zoroastrianism'},
#  'sport': {'archery',
#   'athletic_game',
#   'blood_sport',
#   'board_sport',
#   'college_sport',
#   'contact_sport',
#   'cycling',
#   'gymnastics',
#   'judo',
#   'motor_sport',
#   'outdoor_sport',
#   'professional_baseball',
#   'professional_basketball',
#   'professional_boxing',
#   'professional_football',
#   'professional_golf',
#   'professional_sport',
#   'professional_tennis',
#   'professional_wrestling',
#   'racing',
#   'riding',
#   'rock_climbing',
#   'rowing',
#   'skating',
#   'skeleton',
#   'skiing',
#   'sledding',
#   'spectator_sport',
#   'sports_game',
#   'squash',
#   'sumo',
#   'team_sport',
#   'tightrope_walking',
#   'track_and_field',
#   'ultimate',
#   'water_sport',
#   'winter_sport'},
#  'dinosaur': {'argentinosaur',
#   'brontosaurus',
#   'diplodocus',
#   'ground_shaker',
#   'iguanodon',
#   'ornithischian',
#   'paralititan',
#   'saurischian',
#   'stegosaur',
#   'therapod',
#   'titanosaur'},
#  'exercise': {'arm_exercise',
#   'back_exercise',
#   'bodybuilding',
#   'calisthenics',
#   'cardiopulmonary_exercise',
#   'commencement',
#   'fire_drill',
#   'gymnastic_exercise',
#   'isometrics',
#   'isotonic_exercise',
#   'kegel_exercises',
#   'kick_up',
#   'leg_exercise',
#   'manual_of_arms',
#   'military_drill',
#   'neck_exercise',
#   'rehearsal',
#   'review',
#   'scrimmage',
#   'set',
#   'shadowboxing',
#   'stomach_exercise',
#   'stretch',
#   'target_practice',
#   'yoga'},
#  'vegetable': {'artichoke',
#   'artichoke_heart',
#   'asparagus',
#   'bamboo_shoot',
#   'bean',
#   'bean_pod',
#   'beet',
#   'broccoli_foodstuff',
#   'brussel_sprout',
#   'cabbage',
#   'cardoon',
#   'carrot',
#   'cassava',
#   'celery',
#   'cruciferous_vegetable',
#   'cucumber',
#   'edible_olive',
#   'fennel',
#   'greens',
#   'gumbo',
#   'julienne_vegetable',
#   'leek',
#   'legume',
#   'lettuce',
#   'mushroom',
#   'onion',
#   'pea',
#   'pepper',
#   'pieplant',
#   'plantain',
#   'potato',
#   'potherb',
#   'pumpkin',
#   'radish',
#   'raw_vegetable',
#   'root_vegetable',
#   'solanaceous_vegetable',
#   'soybean',
#   'spinach',
#   'squash',
#   'sweet_potato',
#   'tomato',
#   'truffle',
#   'turnip',
#   'turnip_green',
#   'yam',
#   'zucchini'},
#  'sound': {'audible_sound',
#   'beat',
#   'beep',
#   'bell',
#   'bong',
#   'buzz',
#   'chink',
#   'chirp',
#   'chirrup',
#   'chorus',
#   'click_clack',
#   'clippety_clop',
#   'cry',
#   'ding',
#   'dissonance',
#   'drip',
#   'drum',
#   'dub',
#   'footfall',
#   'gargle',
#   'gurgle',
#   'jingle',
#   'knock',
#   'music',
#   'mutter',
#   'navigation_canal',
#   'noise',
#   'noisiness',
#   'paradiddle',
#   'pat',
#   'patter',
#   'peal',
#   'ping',
#   'plunk',
#   'pop',
#   'purr',
#   'quack',
#   'quaver',
#   'ring',
#   'rub_dub',
#   'sigh',
#   'skirl',
#   'song',
#   'strait',
#   'strum',
#   'susurration',
#   'swish',
#   'tapping',
#   'throbbing',
#   'thrum',
#   'thump',
#   'thunk',
#   'tick',
#   'ting',
#   'tone',
#   'toot',
#   'tootle',
#   'trample',
#   'twang',
#   'ultrasound',
#   'unison',
#   'vibrato',
#   'voice',
#   'vroom',
#   'whack',
#   'whir',
#   'whistle',
#   'whiz',
#   'zing',
#   'zizz'},
#  'communication': {'auditory_communication',
#   'channel',
#   'contact',
#   'contagion',
#   'didacticism',
#   'discussion',
#   'display',
#   'dissuasion',
#   'document',
#   'dramaturgy',
#   'examination',
#   'exhortation',
#   'expostulation',
#   'expression',
#   'expressive_style',
#   'indication',
#   'intercommunication',
#   'language',
#   'mail',
#   'medium',
#   'message',
#   'paralanguage',
#   'persuasion',
#   'psychic_communication',
#   'publication',
#   'sign',
#   'signal',
#   'traffic',
#   'transmission',
#   'visual_communication',
#   'voice',
#   'written_communication'},
#  'symbol': {'award',
#   'crossbones',
#   'crown',
#   "death's_head",
#   'dollar',
#   'emblem',
#   'horn_of_plenty',
#   'icon',
#   'identifier',
#   'lingam',
#   'mantle',
#   'mark',
#   'marker',
#   'monogram',
#   'nose',
#   'numeral',
#   'oriflamme',
#   'pound_sign',
#   'staff',
#   'stamp',
#   'stock_symbol',
#   'symbolism',
#   'token',
#   'type',
#   'variable',
#   'white_feather',
#   'written_symbol'},
#  'toy': {"baby's_rattle",
#   'beanie_baby',
#   'bird_toy',
#   'cat_toy',
#   'construction_toy',
#   'diecast_toy',
#   'dog_toy',
#   'doll',
#   'doll_house',
#   'frisbee',
#   'kaleidoscope',
#   'kite',
#   'little_pony',
#   'piggy_bank',
#   'playhouse',
#   'soft_toy',
#   'stuffed_toy',
#   'toy_aeroplanes',
#   'toy_animal',
#   'toy_balloons',
#   'toy_bear',
#   'toy_car',
#   'toy_glider',
#   'toy_handguns',
#   'toy_military_vehicle',
#   'toy_motorcycle',
#   'toy_people',
#   'toy_race_car',
#   'toy_rail',
#   'toy_train',
#   'toy_train_car',
#   'toy_truck',
#   'virtual_pet',
#   'wind_up_toy',
#   'windmill',
#   'yo_yo'},
#  'container': {'bag',
#   'basket',
#   'bin',
#   'bowl',
#   'box',
#   'bread_bin',
#   'bunker',
#   'can',
#   'canister',
#   'capsid',
#   'capsule',
#   'cargo_container',
#   'case',
#   'cassette',
#   'compartment',
#   'container_product',
#   'cup',
#   'cylinder',
#   'dice_cup',
#   'dish',
#   'dispenser',
#   'drawer',
#   'drum',
#   'eggshell',
#   'empty',
#   'envelope',
#   'glass',
#   'grab_bag',
#   'liquid_storage_tank',
#   'magnetic_bottle',
#   'mailer',
#   'manger',
#   'measure',
#   'mold',
#   'package',
#   'pan',
#   'pipe',
#   'pod',
#   'pot',
#   'powder_horn',
#   'pressure_barrier_container',
#   'pupal_container',
#   'receptacle',
#   'reliquary',
#   'sac',
#   'saltcellar',
#   'savings_bank',
#   'scuttle',
#   'shaker',
#   'spoon',
#   'storage_ring',
#   'thimble',
#   'time_capsule',
#   'vessel',
#   'wastepaper_basket',
#   'watering_can',
#   'wheeled_vehicle',
#   'workbasket'},
#  'job': {'ball_buster',
#   'job_of_accountant',
#   'job_of_analyst',
#   'job_of_architect',
#   'job_of_astronomer',
#   'job_of_bacteriologist',
#   'job_of_bartender',
#   'job_of_biochemist',
#   'job_of_botanist',
#   'job_of_bouncer',
#   'job_of_butcher',
#   'job_of_captain',
#   'job_of_cardiologist',
#   'job_of_cashier',
#   'job_of_chauffeur',
#   'job_of_chemist',
#   'job_of_comedian',
#   'job_of_dancer',
#   'job_of_deliveryman',
#   'job_of_designer',
#   'job_of_doctor',
#   'job_of_dramatist',
#   'job_of_dressmaker',
#   'job_of_editor',
#   'job_of_engineer',
#   'job_of_ethologist',
#   'job_of_farmer',
#   'job_of_firefighter',
#   'job_of_florist',
#   'job_of_forester',
#   'job_of_geneticist',
#   'job_of_geologist',
#   'job_of_geriatrician',
#   'job_of_gynecologist',
#   'job_of_hairstylist',
#   'job_of_handyman',
#   'job_of_housekeeper',
#   'job_of_internist',
#   'job_of_janitor',
#   'job_of_journalist',
#   'job_of_lawyer',
#   'job_of_librarian',
#   'job_of_lifeguard',
#   'job_of_maid',
#   'job_of_mailman',
#   'job_of_manager',
#   'job_of_marketer',
#   'job_of_matador',
#   'job_of_mathematician',
#   'job_of_microbiologist',
#   'job_of_novelist',
#   'job_of_nurse',
#   'job_of_obstetrician',
#   'job_of_oceanographer',
#   'job_of_operator',
#   'job_of_orthopaedist',
#   'job_of_paediatrician',
#   'job_of_paramedic',
#   'job_of_pharmacist',
#   'job_of_physicist',
#   'job_of_physiologist',
#   'job_of_plumber',
#   'job_of_porter',
#   'job_of_professor',
#   'job_of_projectionist',
#   'job_of_psychiatrist',
#   'job_of_psychologist',
#   'job_of_radiologist',
#   'job_of_refinisher',
#   'job_of_researcher',
#   'job_of_sailor',
#   'job_of_salesperson',
#   'job_of_scientist',
#   'job_of_secretary',
#   'job_of_sitter',
#   'job_of_soldier',
#   'job_of_stockboy',
#   'job_of_surgeon',
#   'job_of_tailor',
#   'job_of_toxicologist',
#   'job_of_trader',
#   'job_of_translator',
#   'job_of_usher',
#   'job_of_waitperson',
#   'job_of_writer',
#   'job_of_zoologist',
#   'scut_work',
#   'stint',
#   'vocation'},
#  'condiment': {'barbecue_sauce',
#   'butter',
#   'caper',
#   'catsup',
#   'chili_sauce',
#   'chutney',
#   'cocktail_sauce',
#   'corn_syrup',
#   'cranberry_sauce',
#   'dip',
#   'duck_sauce',
#   'half_and_half',
#   'horseradish',
#   'hot_sauce',
#   'jam',
#   'ketchup',
#   'maple_syrup',
#   'margarine',
#   'marinade',
#   'mayonnaise',
#   'mint_sauce',
#   'miracle_whip',
#   'mustard',
#   'pepper',
#   'refined_sugar',
#   'relish',
#   'salad_dressing',
#   'salsa',
#   'sauce',
#   'soy_sauce',
#   'spread',
#   'steak_sauce',
#   'table_salt',
#   'taco_sauce',
#   'tartar_sauce',
#   'vinegar',
#   'wasabi'},
#  'coin': {'bawbee',
#   'bezant',
#   'change',
#   'crown',
#   'denier',
#   'dime',
#   'dollar',
#   'double_eagle',
#   'doubloon',
#   'ducat',
#   'eagle',
#   'eightpence',
#   'farthing',
#   'fivepence',
#   'fourpence',
#   'gold_coin',
#   'guinea',
#   'half_crown',
#   'half_dollar',
#   'half_eagle',
#   'halfpenny',
#   'loonie',
#   'louis_d_or',
#   'maundy_money',
#   'medallion',
#   'nickel',
#   'ninepence',
#   'penny',
#   'piece_of_eight',
#   'quarter',
#   'real',
#   'shilling',
#   'silver_coin',
#   'sixpence',
#   'slug',
#   'sou',
#   'stater',
#   'tenpence',
#   'threepence',
#   'twopence',
#   'u.s_coin'},
#  'pattern': {'blotched_thing',
#   'checkered_thing',
#   'dashed_line',
#   'dotted_line',
#   'multi_color_pattern',
#   'plaid',
#   'solid_color',
#   'speckled_pattern',
#   'spot',
#   'stripe'},
#  'hazard': {'bunker',
#   'deploying_chemical_agent',
#   'emergency',
#   'extreme_thermal_situation',
#   'health_hazard',
#   'life_threatening_condition',
#   'moral_hazard',
#   'natural_hazard',
#   'occupational_hazard',
#   'physical_attack',
#   'sword_of_damocles',
#   'water_hazard',
#   'wildfire'},
#  'silverware': {'butter_knife',
#   'flatware',
#   'fork',
#   'hollowware',
#   'silverware_spoon',
#   'table_knife'},
#  'gem': {'cabochon',
#   'diamond',
#   'opaque_gem',
#   'precious_stone',
#   'semi_precious_stone',
#   'transparent_gem'},
#  'landmark': {'cairn',
#   'ceremonial_mound',
#   'craniometric_point',
#   'fall_of_man',
#   'merestone',
#   'monument',
#   'museum_building',
#   'road_to_damascus'},
#  'currency': {'cash',
#   'coinage',
#   'dollar',
#   'eurocurrency',
#   'hard_currency',
#   'loonie',
#   'money',
#   'paper_currency',
#   'paper_money',
#   'u.s_currency',
#   'unclaimed_fund'},
#  'size': {'circumference',
#   'distance',
#   'extra_large',
#   'large',
#   'largeness',
#   'length',
#   'number',
#   'octavo',
#   'outsize',
#   'petite',
#   'quarto',
#   'regular',
#   'small',
#   'smallness',
#   'stout',
#   'tall',
#   'volume'},
#  'colony': {'colony',
#   'crown_colony',
#   'frontier_settlement',
#   'plantation',
#   'proprietary_colony'},
#  'measure': {'complex_measure',
#   'cordage',
#   'countermeasure',
#   'definite_quantity',
#   'economic_index_rate_slot',
#   'fundamental_quantity',
#   'indefinite_quantity',
#   'magnetization',
#   'measuring_cup',
#   'octane_number',
#   'physical_measure',
#   'playing_period',
#   'point',
#   'positive_measure',
#   'precaution',
#   'probability',
#   'proof',
#   'quantum',
#   'radical',
#   'relative_quantity',
#   'shark_repellent',
#   'system_of_measurement',
#   'time_interval',
#   'time_unit',
#   'value',
#   'volume',
#   'σ_finite_measure'},
#  'organ': {'contractile_organ',
#   'ctene',
#   'effector',
#   'end_organ',
#   'erectile_organ',
#   'external_organ',
#   'eye',
#   'foot',
#   'gland',
#   'hammond_organ',
#   'house_organ',
#   'internal_organ',
#   'lens',
#   'organelle',
#   'ovipositor',
#   'photophore',
#   'primordium',
#   'reproductive_organ',
#   'sense_organ',
#   'skin_on_whole_body',
#   'speech_organ',
#   'stinger',
#   'sucker',
#   'syphon',
#   'taret_organ',
#   'target_organ',
#   'tongue',
#   'vital_organ',
#   'wing'},
#  'ocean': {'deep'},
#  'cuisine': {'dim_sum',
#   'gastronomy',
#   'haute_cuisine',
#   'nouvelle_cuisine',
#   'rechauffe'},
#  'president': {'ex_president', 'kalon_tripa', 'vice_chairman'},
#  'precipitation': {'fine_spray',
#   'fog',
#   'hail',
#   'rain',
#   'sleet',
#   'snow',
#   'virga'},
#  'texture': {'grain', 'marbleization', 'nap', 'roughness', 'smoothness'},
#  'habitat': {'habitation', 'rookery'},
#  'sense': {'modality',
#   'sense_of_direction',
#   'sense_of_responsibility',
#   'sensitivity',
#   'word_meaning'},
#  'clothes': {'raincoat', 'shoe'},
#  'seasoning': {'salting', 'spice', 'sweetening'}}

# %% [markdown]
# The category exemplars are either very sparse (especially for the amount of categories taken from Jaramillo et al.) or again on different levels of hierarchy, with some more typical items on the direct level. I would again need to recursively get hyponyms as I tried for wordnet, with the caveat that the levels of hierarchy diverge more and more. I will look for another dataset that already contains categories and useful/typical exemplars.
