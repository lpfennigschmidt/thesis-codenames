# %% [markdown]
# # WordNet Category Hyponyms
# The goal of this notebook is to extract fitting hyponyms for two lists of categories that can then function as wordlists where I can sample from for the Codenames Boards.

# %%
import json
with open('../category lists/schroeder et al.json') as file:
    categories_schroeder = json.load(file)["categories"]
    print(categories_schroeder)
# Out:
# ['animal', 'bird', 'fruit', 'vegetable', 'clothing', 'furniture', 'vehicle', 'tool', 'musical_instrument', 'profession', 'sport']

# %%
with open('../category lists/jaramillo et al cleaned.json') as file:
    categories_jaramillo = json.load(file)["categories"]
    print(categories_jaramillo)
# Out:
# ['animal', 'body', 'clothes', 'color', 'day', 'dessert', 'food', 'relative', 'room', 'shape', 'sound', 'toy', 'beverage', 'bird', 'building', 'coin', 'collectable', 'condiment', 'container', 'dinosaur', 'direction', 'emotion', 'flower', 'fruit', 'holiday', 'ingredient', 'insect', 'instrument', 'job', 'jungle animal', 'liquid', 'measure', 'month', 'movie', 'story', 'pattern', 'planet', 'plant', 'reptile', 'rhyming', 'season', 'sense', 'silverware', 'size', 'solid', 'sport', 'transportation', 'tool', 'vegetable', 'writing', 'ability', 'businesses', 'city', 'country', 'communication', 'continent', 'currency', 'exercise', 'habitat', 'hazard', 'mammal', 'material', 'metal', 'ocean', 'president', 'school subject', 'seasoning', 'state', 'symbol', 'texture', 'tree', 'weather', 'colony', 'ancient civilization', 'constellation', 'cuisine', 'element', 'landmark', 'government type', 'gas', 'gem', 'organ', 'language', 'mineral', 'mountain', 'music type', 'precipitation', 'book', 'religion', 'tradition']

# %%
len(categories_jaramillo)
# Out:
# 90

# %%
set(categories_jaramillo).intersection(set(categories_schroeder))
# Out:
# {'animal', 'bird', 'fruit', 'sport', 'tool', 'vegetable'}

# %%
from nltk.corpus import wordnet

# %%
from typing import List, Dict

# %%
def inspect_synsets(word: str):
    synsets = wordnet.synsets(word)
    for synset in synsets:
        print(synset.lemma_names())
        print(synset.definition())
    return synsets

# %%
inspect_synsets('vegetable')
# Out:
# ['vegetable', 'veggie', 'veg']
# edible seeds or roots or stems or leaves or bulbs or tubers or nonsweet fruits of any of numerous herbaceous plant
# ['vegetable']
# any of various herbaceous plants cultivated for an edible part such as the fruit or the root of the beet or the leaf of spinach or the seeds of bean plants or the flower buds of broccoli or cauliflower
# [Synset('vegetable.n.01'), Synset('vegetable.n.02')]

# %%
def get_hyponyms(word: str):
    synsets = inspect_synsets(word)
    for synset in synsets:
        hyponyms = []
        for hyponym in synset.hyponyms():
            hyponyms.append(hyponym.lemma_names()[0])
        print(hyponyms)

# %%
get_hyponyms('vegetable')
# Out:
# ['vegetable', 'veggie', 'veg']
# edible seeds or roots or stems or leaves or bulbs or tubers or nonsweet fruits of any of numerous herbaceous plant
# ['vegetable']
# any of various herbaceous plants cultivated for an edible part such as the fruit or the root of the beet or the leaf of spinach or the seeds of bean plants or the flower buds of broccoli or cauliflower
# ['artichoke', 'artichoke_heart', 'asparagus', 'bamboo_shoot', 'cardoon', 'celery', 'cruciferous_vegetable', 'cucumber', 'fennel', 'greens', 'gumbo', 'julienne', 'leek', 'legume', 'mushroom', 'onion', 'pieplant', 'plantain', 'potherb', 'pumpkin', 'raw_vegetable', 'root_vegetable', 'solanaceous_vegetable', 'squash', 'truffle']
# ['artichoke', 'beet', 'cardoon', 'spinach']

# %% [markdown]
# There seem to be a lot of sub-categories which would need to be expanded to get more good examples, e.g. root_vegetable or raw_vegetable, hyponyms are not on the same level so to speak... maybe concept net works better here

# %%
def get_hyponyms(word: str):
    synsets = wordnet.synsets(word)
    if len(synsets) == 0:
        print("Word does not exist in wordnet!")
        return []
    max_depth = wordnet.synsets(word)[0].min_depth() + 2
    hyponyms = []
    get_hyponyms_recursive(word, hyponyms)
    return hyponyms

def get_hyponyms_recursive(word: str, hyponyms, max_depth = 10, verbose = False):
    if verbose:
        print("word", word)
    synset = wordnet.synsets(word)[0] # just using the first synset of the word because 
    # it's probably going to be the the most frequent one, i.e. the one that I want
    if synset.min_depth() >= 20:
        return
    else:
        for hyponym in synset.hyponyms():
            lemmas = hyponym.lemma_names()
            if len(lemmas) == 0:
                return
            lemma = lemmas[0]
            if verbose:
                print("Lemma", lemma)
            if lemma in hyponyms:
                return
            hyponyms.append(lemma)
            more_hyponyms = get_hyponyms_recursive(lemma, hyponyms, max_depth)
                
            if verbose:
                print("hyponyms", hyponyms)

def remove_compound_words(list_of_words: List):
    return [word for word in list_of_words if not '_' in word and not '-' in word]

# %%
len(remove_compound_words(get_hyponyms('vegetable')))
# Out:
# 68

# %%
wordlists = {}
for category in categories_schroeder:
    wordlists[category] = remove_compound_words(get_hyponyms(category))
    print(category, len(wordlists[category]))
# Out:
# animal 1263
# bird 340
# fruit 66
# vegetable 68
# clothing 658
# furniture 109
# vehicle 901
# tool 183
# musical_instrument 465
# profession 9
# sport 146

# %%
def collect_wordlists(categories: List) -> Dict:
    wordlists = {}
    for category in categories:
        wordlist = remove_compound_words(get_hyponyms(category))
        if len(wordlist) >= 25:
            wordlists[category] = wordlist
            print(category, len(wordlists[category]))
        else:
            print(f"Skipping {category}, only contains {len(wordlist)} words.")
    return wordlists

# %%
collect_wordlists(categories_schroeder)
# Out:
# animal 1263
# bird 340
# fruit 66
# vegetable 68
# clothing 658
# furniture 109
# vehicle 901
# tool 183
# musical_instrument 465
# Skipping profession, only contains 9 words.
# sport 146
# {'animal': ['acrodont',
#   'adult',
#   'brachycephalic',
#   'caregiver',
#   'bonesetter',
#   'electrologist',
#   'dentist',
#   'endodontist',
#   'exodontist',
#   'orthodontist',
#   'pedodontist',
#   'periodontist',
#   'prosthodontist',
#   'doctor',
#   'abortionist',
#   'allergist',
#   'angiologist',
#   'extern',
#   'gastroenterologist',
#   'hakim',
#   'intern',
#   'quack',
#   'specialist',
#   'attache',
#   'canonist',
#   'criminologist',
#   'crystallographer',
#   'dietician',
#   'educationist',
#   'enologist',
#   'Germanist',
#   'graphologist',
#   'limnologist',
#   'meteorologist',
#   'weatherman',
#   'optometrist',
#   'orientalist',
#   'Teutonist',
#   'surgeon',
#   'amputator',
#   'neurosurgeon',
#   'veterinarian',
#   'inoculator',
#   'nurse',
#   'matron',
#   'midwife',
#   'probationer',
#   'pharmacist',
#   'pharmacologist',
#   'catch',
#   'centrist',
#   'character',
#   'conservative',
#   'capitalist',
#   'conformist',
#   'hardliner',
#   'minimalist',
#   'mossback',
#   'neoconservative',
#   'reactionary',
#   'Bourbon',
#   'rightist',
#   'fascist',
#   'Blackshirt',
#   'falangist',
#   'fascista',
#   'Nazi',
#   'Brownshirt',
#   'monarchist',
#   'Cavalier',
#   'Orleanist',
#   'Tory',
#   'square',
#   'quadrate',
#   'traditionalist',
#   'dolichocephalic',
#   'elder',
#   'dean',
#   'doyenne',
#   'host',
#   'hostess',
#   'knocker',
#   'supremo',
#   'celebrity',
#   'immortal',
#   'lion',
#   'lioness',
#   'lionet',
#   'luminary',
#   'personality',
#   'identity',
#   'identification',
#   'diagnosis',
#   'prognosis',
#   'urinalysis',
#   'personhood',
#   'personableness',
#   'toast',
#   'zwieback',
#   'colossus',
#   'Excellency',
#   'fixer',
#   'hierarch',
#   'kingmaker',
#   'kingpin',
#   'magnifico',
#   'name',
#   'agnomen',
#   'alias',
#   'appellation',
#   'nickname',
#   'title',
#   'eponym',
#   'nepotist',
#   'sirdar',
#   'socialite',
#   'sun',
#   'worthy',
#   'liberal',
#   'latitudinarian',
#   'neoliberal',
#   'pluralist',
#   'Whig',
#   'biped',
#   'captive',
#   'convict',
#   'lifer',
#   'trusty',
#   'detainee',
#   'hostage',
#   'internee',
#   'chordate',
#   'cephalochordate',
#   'lancelet',
#   'tunicate',
#   'appendicularia',
#   'ascidian',
#   'doliolum',
#   'larvacean',
#   'salp',
#   'vertebrate',
#   'Amniota',
#   'amniote',
#   'amphibian',
#   'fish',
#   'crossopterygian',
#   'coelacanth',
#   'lungfish',
#   'ceratodus',
#   'cornetfish',
#   'ganoid',
#   'bowfin',
#   'gar',
#   'paddlefish',
#   'sturgeon',
#   'beluga',
#   'halfbeak',
#   'needlefish',
#   'timucu',
#   'pipefish',
#   'seahorse',
#   'saury',
#   'shrimpfish',
#   'snipefish',
#   'anchovy',
#   'argentine',
#   'bonefish',
#   'catfish',
#   'alewife',
#   'herring',
#   'bloater',
#   'kipper',
#   'rollmops',
#   'sprat',
#   'whitebait',
#   'menhaden',
#   'pilchard',
#   'sardine',
#   'shad',
#   'catostomid',
#   'sucker',
#   'characin',
#   'piranha',
#   'tetra',
#   'cyprinid',
#   'carp',
#   'chub',
#   'dace',
#   'goldfish',
#   'silverfish',
#   'gudgeon',
#   'mudskipper',
#   'minnow',
#   'roach',
#   'rudd',
#   'shiner',
#   'tench',
#   'cyprinodont',
#   'guppy',
#   'killifish',
#   'flagfish',
#   'mummichog',
#   'rivulus',
#   'swordtail',
#   'loach',
#   'topminnow',
#   'mollie',
#   'mosquitofish',
#   'platy',
#   'eel',
#   'elver',
#   'gadoid',
#   'cod',
#   'cusk',
#   'grenadier',
#   'haddock',
#   'hake',
#   'ling',
#   'pollack',
#   'whiting',
#   'greeneye',
#   'lancetfish',
#   'lanternfish',
#   'lizardfish',
#   'oarfish',
#   'opah',
#   'Ostariophysi',
#   'ribbonfish',
#   'salmonid',
#   'char',
#   'snuff',
#   'salmon',
#   'blackfish',
#   'chinook',
#   'coho',
#   'redfish',
#   'sockeye',
#   'trout',
#   'smelt',
#   'tarpon',
#   'ladyfish',
#   'whitefish',
#   'anomalops',
#   'barracuda',
#   'batfish',
#   'boarfish',
#   'sweeper',
#   'trumpetfish',
#   'elasmobranch',
#   'ray',
#   'moonbeam',
#   'sunbeam',
#   'shark',
#   'dogfish',
#   'hammerhead',
#   'mako',
#   'porbeagle',
#   'thresher',
#   'holocephalan',
#   'chimaera',
#   'fingerling',
#   'barracouta',
#   'groundfish',
#   'mouthbreeder',
#   'spawner',
#   'brit',
#   'patrial',
#   'parr',
#   'anaspid',
#   'conodont',
#   'cyclostome',
#   'hagfish',
#   'eptatretus',
#   'heterostracan',
#   'lamprey',
#   'osteostracan',
#   'ostracoderm',
#   'placoderm',
#   'bird',
#   'hummingbird',
#   'thornbill',
#   'swift',
#   'gallinule',
#   'moorhen',
#   'seabird',
#   'auk',
#   'auklet',
#   'guillemot',
#   'murre',
#   'razorbill',
#   'jaeger',
#   'skua',
#   'larid',
#   'gull',
#   'tern',
#   'skimmer',
#   'loon',
#   'albatross',
#   'petrel',
#   'fulmar',
#   'shearwater',
#   'cormorant',
#   'gannet',
#   'booby',
#   'solan',
#   'pelican',
#   'snakebird',
#   'grebe',
#   'dabchick',
#   'puffin',
#   'penguin',
#   'Adelie',
#   'swan',
#   'cob',
#   'coscoroba',
#   'cygnet',
#   'pen',
#   'ballpoint',
#   'quill',
#   'Sharpie',
#   'goffer',
#   'trumpeter',
#   'bugler',
#   'whooper',
#   'bustard',
#   'chunga',
#   'courlan',
#   'crane',
#   'flamingo',
#   'heron',
#   'ibis',
#   'limpkin',
#   'ortygan',
#   'rail',
#   'bar',
#   'barrelhouse',
#   'speakeasy',
#   'taffrail',
#   'shoebill',
#   'shorebird',
#   'avocet',
#   'courser',
#   'curlew',
#   'godwit',
#   'oystercatcher',
#   'phalarope',
#   'plover',
#   'dotterel',
#   'killdeer',
#   'lapwing',
#   'turnstone',
#   'pratincole',
#   'sandpiper',
#   'greenshank',
#   'knot',
#   'redshank',
#   'ruff',
#   'sanderling',
#   'tattler',
#   'yellowlegs',
#   'snipe',
#   'dowitcher',
#   'greyback',
#   'jacksnipe',
#   'stilt',
#   'spoonbill',
#   'stork',
#   'jabiru',
#   'marabou',
#   'openbill',
#   'saddlebill',
#   'waterfowl',
#   'duck',
#   'bufflehead',
#   'canvasback',
#   'drake',
#   'duckling',
#   'goldeneye',
#   'mallard',
#   'pintail',
#   'pochard',
#   'redhead',
#   'scaup',
#   'eider',
#   'merganser',
#   'goosander',
#   'smew',
#   'scoter',
#   'sheldrake',
#   'shoveler',
#   'teal',
#   'cyan',
#   'widgeon',
#   'goose',
#   'brant',
#   'gander',
#   'gosling',
#   'greylag',
#   'honker',
#   'screamer',
#   'crier',
#   'bawler',
#   'blubberer',
#   'archaeopteryx',
#   'archaeornis',
#   'nomad',
#   'Bedouin',
#   'Bushman',
#   'Hun',
#   'Saracen',
#   'Scythian',
#   'vagrant',
#   'beachcomber',
#   'sundowner',
#   'tramp',
#   'dosser',
#   'Accipitriformes',
#   'eagle',
#   'eaglet',
#   'ringtail',
#   'harpy',
#   'hawk',
#   'buteonine',
#   'buzzard',
#   'eyas',
#   'falcon',
#   'caracara',
#   'carancha',
#   'gyrfalcon',
#   'hobby',
#   'speleology',
#   'kestrel',
#   'peregrine',
#   'goshawk',
#   'harrier',
#   'kite',
#   'osprey',
#   'redtail',
#   'owl',
#   'owlet',
#   'vulture',
#   'Aegypiidae',
#   'frogmouth',
#   'goatsucker',
#   'nighthawk',
#   'poorwill',
#   'whippoorwill',
#   'oilbird',
#   'carinate',
#   'cock',
#   'hoopoe',
#   'hornbill',
#   'kingfisher',
#   'kookaburra',
#   'motmot',
#   'roller',
#   'tody',
#   'cuckoo',
#   'touraco',
#   'dickeybird',
#   'chachalaca',
#   'dodo',
#   'pigeon',
#   'dove',
#   'turtledove',
#   'squab',
#   'sandgrouse',
#   'solitaire',
#   'curassow',
#   'bantam',
#   'chicken',
#   'broiler',
#   'capon',
#   'fryer',
#   'hen',
#   'cackler',
#   'layer',
#   'backing',
#   'blanket',
#   'afghan',
#   'mackinaw',
#   'manta',
#   'course',
#   'propaedeutic',
#   'seminar',
#   'workshop',
#   'bindery',
#   'bookbindery',
#   'brickyard',
#   'pottery',
#   'agateware',
#   'lusterware',
#   'Wedgwood',
#   'saddlery',
#   'bit',
#   'caparison',
#   'bard',
#   'horsecloth',
#   'cinch',
#   'doddle',
#   'hame',
#   'harness',
#   'headgear',
#   'cap',
#   'balaclava',
#   'Balmoral',
#   'beret',
#   'biggin',
#   'biretta',
#   'calpac',
#   'cockscomb',
#   'fez',
#   'Glengarry',
#   'kalansuwa',
#   'kepi',
#   'mobcap',
#   'mortarboard',
#   'nightcap',
#   'pinner',
#   'skullcap',
#   'beanie',
#   'coif',
#   'Afro',
#   'bang',
#   'beehive',
#   'bob',
#   'bouffant',
#   'braid',
#   'pigtail',
#   'queue',
#   'breadline',
#   'chignon',
#   'haircut',
#   'mohawk',
#   'marcel',
#   'pageboy',
#   'pompadour',
#   'ponytail',
#   'yarmulke',
#   'tam',
#   'hat',
#   'bearskin',
#   'boater',
#   'bonnet',
#   'sunbonnet',
#   'bicorn',
#   'tricorn',
#   'deerstalker',
#   'fedora',
#   'beaver',
#   'millinery',
#   'porkpie',
#   'sombrero',
#   "sou'wester",
#   'sunhat',
#   'titfer',
#   'toque',
#   'tyrolean',
#   'helmet',
#   'armet',
#   'basinet',
#   'casque',
#   'casquet',
#   'heaume',
#   'morion',
#   'pickelhaube',
#   'sallet',
#   'hood',
#   'bully',
#   'bullyboy',
#   'muscleman',
#   'skinhead',
#   'Ted',
#   'crown',
#   'tiara',
#   'kaffiyeh',
#   'miter',
#   'topknot',
#   'turban',
#   'wimple',
#   'martingale',
#   'apishamore',
#   'yoke',
#   'tucker',
#   'turnery',
#   'cushion',
#   'interlayer',
#   'lift',
#   'overlay',
#   'ply',
#   'tier',
#   'wall',
#   'attic',
#   'cockloft',
#   'hayloft',
#   'firewall',
#   'gable',
#   'pediment',
#   'parapet',
#   'proscenium',
#   'sidewall',
#   'wainscoting',
#   'pullet',
#   'roaster',
#   'spatchcock',
#   'cochin',
#   'Cornish',
#   'Dorking',
#   'turkey',
#   'grouse',
#   'phasianid',
#   'partridge',
#   'pheasant',
#   'afropavo',
#   'argus',
#   'monal',
#   'peafowl',
#   'peachick',
#   'peacock',
#   'peahen',
#   'tragopan',
#   'quail',
#   'tinamou',
#   'guan',
#   'hoatzin',
#   'megapode',
#   'maleo',
#   'fetus',
#   'abortus',
#   'baby',
#   'cherub',
#   'foundling',
#   'godchild',
#   'goddaughter',
#   'godson',
#   'neonate',
#   'nursling',
#   'papoose',
#   'monster',
#   'bogeyman',
#   'amphisbaena',
#   'basilisk',
#   'centaur',
#   'Chiron',
#   'Cerberus',
#   'Chimera',
#   'cockatrice',
#   'dragon',
#   'wyvern',
#   'Geryon',
#   'Gorgon',
#   'Euryale',
#   'Medusa',
#   'Stheno',
#   'gryphon',
#   'Harpy',
#   'Hydra',
#   'doppelganger',
#   'leviathan',
#   'manticore',
#   'Minotaur',
#   'roc',
#   'salamander',
#   'ambystomid',
#   'axolotl',
#   'waterdog',
#   'amphiuma',
#   'dicamptodon',
#   'hellbender',
#   'newt',
#   'eft',
#   'olm',
#   'siren',
#   'Sphinx',
#   'troll',
#   'Typhoeus',
#   'Typhon',
#   'werewolf',
#   'gnathostome',
#   'mammal',
#   'queen',
#   'metatherian',
#   'marsupial',
#   'bandicoot',
#   'dasyure',
#   'numbat',
#   'thylacine',
#   'kangaroo',
#   'bettong',
#   'potoroo',
#   'wallaby',
#   'pademelon',
#   'opossum',
#   'cuscus',
#   'koala',
#   'phalanger',
#   'wombat',
#   'placental',
#   'aardvark',
#   'cetacean',
#   'whale',
#   'seal',
#   'walrus',
#   'dugong',
#   'manatee',
#   'bat',
#   'freetail',
#   'pipistrelle',
#   'serotine',
#   'buck',
#   'bull',
#   'bullock',
#   'carnivore',
#   'bear',
#   'grizzly',
#   'bruin',
#   'canine',
#   'fang',
#   'feline',
#   'cheetah',
#   'jaguar',
#   'leopard',
#   'liger',
#   'cat',
#   'Abyssinian',
#   'Angora',
#   'kitty',
#   'Maltese',
#   'Manx',
#   'mouser',
#   'tabby',
#   'wildcat',
#   'badger',
#   'glutton',
#   'grison',
#   'marten',
#   'fisher',
#   'angler',
#   'trawler',
#   'sable',
#   'rigger',
#   'mink',
#   'otter',
#   'polecat',
#   'ratel',
#   'skunk',
#   'tayra',
#   'weasel',
#   'wolverine',
#   'procyonid',
#   'bassarisk',
#   'coati',
#   'kinkajou',
#   'raccoon',
#   'viverrine',
#   'civet',
#   'binturong',
#   'Cryptoprocta',
#   'fanaloka',
#   'fossa',
#   'genet',
#   'meerkat',
#   'suricate',
#   'mongoose',
#   'ichneumon',
#   'cow',
#   'heifer',
#   'springer',
#   'doe',
#   'edentate',
#   'anteater',
#   'armadillo',
#   'apar',
#   'peba',
#   'peludo',
#   'pichiciago',
#   'tatouay',
#   'megatherian',
#   'mylodon',
#   'mylodontid',
#   'mapinguari',
#   'sloth',
#   'Fissipedia',
#   'hyrax',
#   'insectivore',
#   'hedgehog',
#   'mole',
#   'shrew',
#   'virago',
#   'yenta',
#   'tenrec',
#   'lagomorph',
#   'Duplicidentata',
#   'leporid',
#   'hare',
#   'jackrabbit',
#   'leveret',
#   'rabbit',
#   'pika',
#   'livestock',
#   'pachyderm',
#   'elephant',
#   'gomphothere',
#   'mammoth',
#   'pangolin',
#   'primate',
#   'proboscidean',
#   'rodent',
#   'abrocome',
#   'agouti',
#   'pentail',
#   'Unguiculata',
#   'unguiculate',
#   'Ungulata',
#   'ungulate',
#   'dinocerate',
#   'dinoceras',
#   'camel',
#   'hippopotamus',
#   'llama',
#   'alpaca',
#   'guanaco',
#   'peccary',
#   'ruminant',
#   'bovid',
#   'antelope',
#   'addax',
#   'blackbuck',
#   'bongo',
#   'eland',
#   'gazelle',
#   'springbok',
#   'gerenuk',
#   'gnu',
#   'bushbuck',
#   'nyala',
#   'hartebeest',
#   'impala',
#   'kudu',
#   'nilgai',
#   'oryx',
#   'gemsbok',
#   'puku',
#   'saiga',
#   'sassaby',
#   'steenbok',
#   'waterbuck',
#   'kob',
#   'lechwe',
#   'bison',
#   'wisent',
#   'bovine',
#   'Brahman',
#   'cattle',
#   'Africander',
#   'beef',
#   'cattalo',
#   'Charolais',
#   'Durham',
#   'Galloway',
#   'Hereford',
#   'longhorn',
#   'ox',
#   'goat',
#   'billy',
#   'kid',
#   'bairn',
#   'buster',
#   'changeling',
#   'mongoloid',
#   'imp',
#   'leprechaun',
#   'sandman',
#   'kiddy',
#   'orphan',
#   'peanut',
#   'pickaninny',
#   'preschooler',
#   'silly',
#   'sprog',
#   'toddler',
#   'urchin',
#   'ragamuffin',
#   'gamine',
#   'waif',
#   'nanny',
#   'mammy',
#   'ibex',
#   'markhor',
#   'chamois',
#   'goral',
#   'serow',
#   'takin',
#   'anoa',
#   'tamarau',
#   'carabao',
#   'sheep',
#   'broadtail',
#   'Cheviot',
#   'Cotswold',
#   'Exmoor',
#   'Hampshire',
#   'Lincoln',
#   'longwool',
#   'merino',
#   'Rambouillet',
#   'ewe',
#   'ram',
#   'wether',
#   'bellwether',
#   'aoudad',
#   'argali',
#   'bighorn',
#   'mouflon',
#   'urial',
#   'chevrotain',
#   'kanchil',
#   'napu',
#   'deer',
#   'brocket',
#   'caribou',
#   'elk',
#   'fawn',
#   'muntjac',
#   'pricket',
#   'roebuck',
#   'sambar',
#   'wapiti',
#   'giraffe',
#   'okapi',
#   'pollard',
#   'pronghorn',
#   'swine',
#   'babirusa',
#   'boar',
#   'hog',
#   'razorback',
#   'sow',
#   'warthog',
#   'vicuna',
#   'equine',
#   'ass',
#   'hinny',
#   'horse',
#   'bay',
#   'bight',
#   'chestnut',
#   'eohippus',
#   'hack',
#   'plodder',
#   'mule',
#   'quagga',
#   'zebra',
#   'rhinoceros',
#   'tapir',
#   'yearling',
#   'prototherian',
#   'monotreme',
#   'echidna',
#   'tusker',
#   'reptile',
#   'anapsid',
#   'chelonian',
#   'turtle',
#   'diapsid',
#   'archosaur',
#   'dinosaur',
#   'argentinosaur',
#   'diplodocus',
#   'iguanodon',
#   'ornithischian',
#   'ankylosaur',
#   'Edmontonia',
#   'stegosaur',
#   'pachycephalosaur',
#   'ceratopsian',
#   'protoceratops',
#   'psittacosaur',
#   'styracosaur',
#   'triceratops',
#   'hadrosaur',
#   'anatotitan',
#   'corythosaur',
#   'edmontosaurus',
#   'trachodon',
#   'ornithopod',
#   'pisanosaur',
#   'staurikosaur',
#   'saurischian',
#   'sauropod',
#   'apatosaur',
#   'barosaur',
#   'theropod',
#   'allosaur',
#   'carnosaur',
#   'ceratosaur',
#   'coelophysis',
#   'compsognathus',
#   'eoraptor',
#   'herrerasaur',
#   ...],
#  'bird': ['hummingbird',
#   'thornbill',
#   'swift',
#   'gallinule',
#   'moorhen',
#   'seabird',
#   'auk',
#   'auklet',
#   'guillemot',
#   'murre',
#   'razorbill',
#   'jaeger',
#   'skua',
#   'larid',
#   'gull',
#   'tern',
#   'skimmer',
#   'loon',
#   'albatross',
#   'petrel',
#   'fulmar',
#   'shearwater',
#   'cormorant',
#   'gannet',
#   'booby',
#   'solan',
#   'pelican',
#   'snakebird',
#   'grebe',
#   'dabchick',
#   'puffin',
#   'penguin',
#   'Adelie',
#   'swan',
#   'cob',
#   'coscoroba',
#   'cygnet',
#   'pen',
#   'ballpoint',
#   'quill',
#   'Sharpie',
#   'goffer',
#   'trumpeter',
#   'bugler',
#   'whooper',
#   'bustard',
#   'chunga',
#   'courlan',
#   'crane',
#   'flamingo',
#   'heron',
#   'ibis',
#   'limpkin',
#   'ortygan',
#   'rail',
#   'bar',
#   'barrelhouse',
#   'speakeasy',
#   'taffrail',
#   'shoebill',
#   'shorebird',
#   'avocet',
#   'courser',
#   'curlew',
#   'godwit',
#   'oystercatcher',
#   'phalarope',
#   'plover',
#   'dotterel',
#   'killdeer',
#   'lapwing',
#   'turnstone',
#   'pratincole',
#   'sandpiper',
#   'greenshank',
#   'knot',
#   'redshank',
#   'ruff',
#   'sanderling',
#   'tattler',
#   'yellowlegs',
#   'snipe',
#   'dowitcher',
#   'greyback',
#   'jacksnipe',
#   'stilt',
#   'spoonbill',
#   'stork',
#   'jabiru',
#   'marabou',
#   'openbill',
#   'saddlebill',
#   'waterfowl',
#   'duck',
#   'bufflehead',
#   'canvasback',
#   'drake',
#   'duckling',
#   'goldeneye',
#   'mallard',
#   'pintail',
#   'pochard',
#   'redhead',
#   'scaup',
#   'eider',
#   'merganser',
#   'goosander',
#   'smew',
#   'scoter',
#   'sheldrake',
#   'shoveler',
#   'teal',
#   'cyan',
#   'widgeon',
#   'goose',
#   'brant',
#   'gander',
#   'gosling',
#   'greylag',
#   'honker',
#   'screamer',
#   'crier',
#   'bawler',
#   'blubberer',
#   'archaeopteryx',
#   'archaeornis',
#   'nomad',
#   'Bedouin',
#   'Bushman',
#   'Hun',
#   'Saracen',
#   'Scythian',
#   'vagrant',
#   'beachcomber',
#   'sundowner',
#   'tramp',
#   'dosser',
#   'Accipitriformes',
#   'eagle',
#   'eaglet',
#   'ringtail',
#   'harpy',
#   'hawk',
#   'buteonine',
#   'buzzard',
#   'eyas',
#   'falcon',
#   'caracara',
#   'carancha',
#   'gyrfalcon',
#   'hobby',
#   'speleology',
#   'kestrel',
#   'peregrine',
#   'goshawk',
#   'harrier',
#   'kite',
#   'osprey',
#   'redtail',
#   'owl',
#   'owlet',
#   'vulture',
#   'Aegypiidae',
#   'frogmouth',
#   'goatsucker',
#   'nighthawk',
#   'poorwill',
#   'whippoorwill',
#   'oilbird',
#   'carinate',
#   'cock',
#   'hoopoe',
#   'hornbill',
#   'kingfisher',
#   'kookaburra',
#   'motmot',
#   'roller',
#   'tody',
#   'cuckoo',
#   'touraco',
#   'dickeybird',
#   'chachalaca',
#   'dodo',
#   'pigeon',
#   'dove',
#   'turtledove',
#   'squab',
#   'sandgrouse',
#   'solitaire',
#   'curassow',
#   'bantam',
#   'chicken',
#   'broiler',
#   'capon',
#   'fryer',
#   'hen',
#   'cackler',
#   'layer',
#   'backing',
#   'blanket',
#   'afghan',
#   'mackinaw',
#   'manta',
#   'course',
#   'propaedeutic',
#   'seminar',
#   'workshop',
#   'bindery',
#   'bookbindery',
#   'brickyard',
#   'pottery',
#   'agateware',
#   'lusterware',
#   'Wedgwood',
#   'saddlery',
#   'bit',
#   'caparison',
#   'bard',
#   'horsecloth',
#   'cinch',
#   'doddle',
#   'hame',
#   'harness',
#   'headgear',
#   'cap',
#   'balaclava',
#   'Balmoral',
#   'beret',
#   'biggin',
#   'biretta',
#   'calpac',
#   'cockscomb',
#   'fez',
#   'Glengarry',
#   'kalansuwa',
#   'kepi',
#   'mobcap',
#   'mortarboard',
#   'nightcap',
#   'pinner',
#   'skullcap',
#   'beanie',
#   'coif',
#   'Afro',
#   'bang',
#   'beehive',
#   'bob',
#   'bouffant',
#   'braid',
#   'pigtail',
#   'queue',
#   'breadline',
#   'chignon',
#   'haircut',
#   'mohawk',
#   'marcel',
#   'pageboy',
#   'pompadour',
#   'ponytail',
#   'roach',
#   'thatch',
#   'wave',
#   'billow',
#   'comber',
#   'lift',
#   'ripple',
#   'yarmulke',
#   'tam',
#   'hat',
#   'bearskin',
#   'boater',
#   'bonnet',
#   'sunbonnet',
#   'bicorn',
#   'tricorn',
#   'deerstalker',
#   'fedora',
#   'beaver',
#   'millinery',
#   'porkpie',
#   'sombrero',
#   "sou'wester",
#   'sunhat',
#   'titfer',
#   'toque',
#   'tyrolean',
#   'helmet',
#   'armet',
#   'basinet',
#   'casque',
#   'casquet',
#   'heaume',
#   'morion',
#   'pickelhaube',
#   'sallet',
#   'hood',
#   'bully',
#   'bullyboy',
#   'muscleman',
#   'skinhead',
#   'Ted',
#   'crown',
#   'tiara',
#   'kaffiyeh',
#   'miter',
#   'topknot',
#   'turban',
#   'wimple',
#   'martingale',
#   'apishamore',
#   'yoke',
#   'tucker',
#   'turnery',
#   'cushion',
#   'interlayer',
#   'pullet',
#   'roaster',
#   'spatchcock',
#   'cochin',
#   'Cornish',
#   'Dorking',
#   'turkey',
#   'grouse',
#   'phasianid',
#   'partridge',
#   'pheasant',
#   'afropavo',
#   'argus',
#   'monal',
#   'peafowl',
#   'peachick',
#   'peacock',
#   'peahen',
#   'tragopan',
#   'quail',
#   'tinamou',
#   'guan',
#   'hoatzin',
#   'megapode',
#   'maleo'],
#  'fruit': ['achene',
#   'samara',
#   'acorn',
#   'syconium',
#   'berry',
#   'acerola',
#   'bilberry',
#   'blackberry',
#   'blueberry',
#   'boysenberry',
#   'cranberry',
#   'cowberry',
#   'currant',
#   'gooseberry',
#   'dewberry',
#   'huckleberry',
#   'lingonberry',
#   'loganberry',
#   'mulberry',
#   'persimmon',
#   'raspberry',
#   'cloudberry',
#   'salmonberry',
#   'saskatoon',
#   'strawberry',
#   'sugarberry',
#   'wintergreen',
#   'chokecherry',
#   'cubeb',
#   'drupe',
#   'almond',
#   'cherry',
#   'drupelet',
#   'acinus',
#   'elderberry',
#   'jujube',
#   'olive',
#   'peach',
#   'plum',
#   'bullace',
#   'ear',
#   'ackee',
#   'apple',
#   'Baldwin',
#   'Cortland',
#   'Delicious',
#   'Empire',
#   'Jonathan',
#   'McIntosh',
#   'Macoun',
#   'Pearmain',
#   'Pippin',
#   'Prima',
#   'Stayman',
#   'Winesap',
#   'apricot',
#   'avocado',
#   'banana',
#   'abaca',
#   'plantain',
#   'fleawort',
#   'fruitlet',
#   'gourd',
#   'hagberry',
#   'hip',
#   'marasca'],
#  'vegetable': ['artichoke',
#   'asparagus',
#   'cardoon',
#   'celery',
#   'broccoli',
#   'cabbage',
#   'kale',
#   'cauliflower',
#   'kohlrabi',
#   'mustard',
#   'rape',
#   'radish',
#   'turnip',
#   'cucumber',
#   'fennel',
#   'greens',
#   'chard',
#   'celtuce',
#   'chicory',
#   'cress',
#   'bittercress',
#   'crinkleroot',
#   'sicklepod',
#   'watercress',
#   'lettuce',
#   'sorrel',
#   'goatsfoot',
#   'oca',
#   'spinach',
#   'sprout',
#   'bud',
#   'rosebud',
#   'shoot',
#   'sucker',
#   'tiller',
#   'gumbo',
#   'julienne',
#   'leek',
#   'legume',
#   'bean',
#   'soy',
#   'chickpea',
#   'cowpea',
#   'guar',
#   'lentil',
#   'locoweed',
#   'mung',
#   'pea',
#   'peanut',
#   'sesbania',
#   'snailflower',
#   'mushroom',
#   'onion',
#   'pieplant',
#   'plantain',
#   'fleawort',
#   'potherb',
#   'pumpkin',
#   'beet',
#   'beetroot',
#   'carrot',
#   'celeriac',
#   'parsnip',
#   'potato',
#   'eggplant',
#   'pepper',
#   'squash',
#   'truffle'],
#  'clothing': ['accessory',
#   'belt',
#   'band',
#   'clique',
#   'bohemia',
#   'cabal',
#   'faction',
#   'galere',
#   'loop',
#   'mafia',
#   'cohort',
#   'conspiracy',
#   'party',
#   'Gironde',
#   'Kuomintang',
#   'Opposition',
#   'lockout',
#   'reaction',
#   'decomposition',
#   'displacement',
#   'hydrolysis',
#   'neutralization',
#   'oxidation',
#   'calcination',
#   'combustion',
#   'deflagration',
#   'fire',
#   'backfire',
#   'backblast',
#   'bonfire',
#   'campfire',
#   'conflagration',
#   'wildfire',
#   'grassfire',
#   'smoulder',
#   'smudge',
#   'nitrification',
#   'rust',
#   'reduction',
#   'amortization',
#   'contraction',
#   'contracture',
#   'tetanus',
#   'vaginismus',
#   'cut',
#   'cutback',
#   'declassification',
#   'deflation',
#   'depletion',
#   'consumption',
#   'drinking',
#   'gulping',
#   'potation',
#   'quaff',
#   'eating',
#   'bite',
#   'snakebite',
#   'browse',
#   'coprophagy',
#   'dining',
#   'engorgement',
#   'feasting',
#   'graze',
#   'lunching',
#   'mycophagy',
#   'necrophagia',
#   'omophagia',
#   'repletion',
#   'scatophagy',
#   'supping',
#   'tasting',
#   'sucking',
#   'swallow',
#   'drain',
#   'exhaustion',
#   'frazzle',
#   'inanition',
#   'depreciation',
#   'devaluation',
#   'devitalization',
#   'discount',
#   'easing',
#   'disembarrassment',
#   'extenuation',
#   'lowering',
#   'tapering',
#   'minimization',
#   'moderation',
#   'reasonableness',
#   'rollback',
#   'shortening',
#   'shrinking',
#   'compression',
#   'subtraction',
#   'weakening',
#   'atrophy',
#   'amyotrophia',
#   'kraurosis',
#   'tabes',
#   'attenuation',
#   'debilitation',
#   'fall',
#   'relaxation',
#   'saponification',
#   'carousel',
#   'track',
#   'round',
#   'steps',
#   'ladder',
#   'swath',
#   'trail',
#   'slot',
#   'spoor',
#   'furnishing',
#   'apparel',
#   'workwear',
#   'jean',
#   "Levi's",
#   'array',
#   'bank',
#   'riverbank',
#   'waterside',
#   'column',
#   'matrix',
#   'determinant',
#   'clincher',
#   'influence',
#   'force',
#   'duress',
#   'heartbeat',
#   'diastole',
#   'systole',
#   'extrasystole',
#   'throb',
#   'lifeblood',
#   'pressure',
#   'overpressure',
#   'head',
#   'attic',
#   'cockloft',
#   'hayloft',
#   'bullethead',
#   'hypertonicity',
#   'hypotonicity',
#   'suction',
#   'wheel',
#   'cartwheel',
#   'gear',
#   'pinion',
#   'handwheel',
#   'nosewheel',
#   'paddlewheel',
#   'pinwheel',
#   'roller',
#   'roulette',
#   'cycloid',
#   'epicycloid',
#   'cardioid',
#   'hypocycloid',
#   'rowel',
#   'sprocket',
#   'trundle',
#   'waterwheel',
#   'grip',
#   'chokehold',
#   'embrace',
#   'cuddle',
#   'hug',
#   'lock',
#   'doorlock',
#   'latch',
#   'padlock',
#   'nelson',
#   'scissors',
#   'clipper',
#   'shears',
#   'snuffers',
#   'stranglehold',
#   'toehold',
#   'transpose',
#   'panoply',
#   'row',
#   'serration',
#   'terrace',
#   'suntrap',
#   'spectrum',
#   'table',
#   'calendar',
#   'contents',
#   'attire',
#   'costume',
#   'beachwear',
#   'black',
#   'blue',
#   'azure',
#   'ultramarine',
#   'change',
#   'acceleration',
#   'pickup',
#   'technical',
#   'precipitation',
#   'avulsion',
#   'birth',
#   'cradle',
#   'break',
#   'dislocation',
#   'eclipse',
#   'punctuation',
#   'suspension',
#   'mash',
#   'resuspension',
#   'slurry',
#   'vapor',
#   'steam',
#   'spray',
#   'conversion',
#   'glycogenesis',
#   'isomerization',
#   'rectification',
#   'damage',
#   'detriment',
#   'expense',
#   'distortion',
#   'warp',
#   'run',
#   'death',
#   'fatality',
#   'killing',
#   'martyrdom',
#   'megadeath',
#   'passing',
#   'deceleration',
#   'decrease',
#   'attrition',
#   'casualty',
#   'dwindling',
#   'deformation',
#   'destabilization',
#   'development',
#   'advancement',
#   'broadening',
#   'elaboration',
#   'civies',
#   'mufti',
#   'drag',
#   'windage',
#   'footwear',
#   'hosiery',
#   'sock',
#   'anklet',
#   'argyle',
#   'tabi',
#   'stocking',
#   'boothose',
#   'tights',
#   'maillot',
#   'pantyhose',
#   'garment',
#   'breechcloth',
#   'dhoti',
#   'burqa',
#   'camlet',
#   'diaper',
#   'fur',
#   'astrakhan',
#   'bearskin',
#   'beaver',
#   'chinchilla',
#   'ermine',
#   'fox',
#   'lambskin',
#   'broadtail',
#   'lapin',
#   'leopard',
#   'mink',
#   'muskrat',
#   'otter',
#   'raccoon',
#   'sable',
#   'rigger',
#   'seal',
#   'squirrel',
#   'taguan',
#   'baronduki',
#   'chipmunk',
#   'chickeree',
#   'gown',
#   'mantua',
#   'haik',
#   'chador',
#   'niqab',
#   'yashmak',
#   'hose',
#   'ironing',
#   'flatwork',
#   'kanzu',
#   'laundry',
#   'legging',
#   'chap',
#   'dog',
#   'basenji',
#   'corgi',
#   'Cardigan',
#   'Pembroke',
#   'cur',
#   'feist',
#   'dalmatian',
#   'griffon',
#   'courser',
#   'dachshund',
#   'hound',
#   'basset',
#   'beagle',
#   'bloodhound',
#   'bluetick',
#   'boarhound',
#   'coonhound',
#   'coondog',
#   'foxhound',
#   'greyhound',
#   'whippet',
#   'harrier',
#   'otterhound',
#   'redbone',
#   'Saluki',
#   'staghound',
#   'Weimaraner',
#   'wolfhound',
#   'borzoi',
#   'terrier',
#   'Airedale',
#   'bullterrier',
#   'cairn',
#   'Lhasa',
#   'schnauzer',
#   'wirehair',
#   'lapdog',
#   'Leonberg',
#   'Newfoundland',
#   'pooch',
#   'poodle',
#   'pug',
#   'puppy',
#   'spitz',
#   'chow',
#   'keeshond',
#   'Pomeranian',
#   'Samoyed',
#   'Chihuahua',
#   'Pekinese',
#   'papillon',
#   'boxer',
#   'bantamweight',
#   'featherweight',
#   'flyweight',
#   'heavyweight',
#   'lightweight',
#   'middleweight',
#   'prizefighter',
#   'puncher',
#   'cowgirl',
#   'gaucho',
#   'roper',
#   'vaquero',
#   'slugger',
#   'bunter',
#   'whiffer',
#   'stumblebum',
#   'welterweight',
#   'bulldog',
#   'mastiff',
#   'Sennenhunde',
#   'Appenzeller',
#   'EntleBucher',
#   'groenendael',
#   'malinois',
#   'briard',
#   'collie',
#   'kelpie',
#   'komondor',
#   'Rottweiler',
#   'malamute',
#   'watchdog',
#   'gaiter',
#   'puttee',
#   'spat',
#   'leotard',
#   'mending',
#   'motley',
#   'range',
#   'confines',
#   'contrast',
#   'gamut',
#   'horizon',
#   'internationality',
#   'latitude',
#   'palette',
#   'sampler',
#   'selection',
#   'casting',
#   'coloration',
#   'decision',
#   'appointment',
#   'delegacy',
#   'virus',
#   'adenovirus',
#   'alphavirus',
#   'arenavirus',
#   'bunyavirus',
#   'filovirus',
#   'flavivirus',
#   'hepadnavirus',
#   'herpes',
#   'lyssavirus',
#   'myxovirus',
#   'orthomyxovirus',
#   'paramyxovirus',
#   'papovavirus',
#   'polyoma',
#   'parvovirus',
#   'picornavirus',
#   'enterovirus',
#   'coxsackievirus',
#   'echovirus',
#   'poliovirus',
#   'rhinovirus',
#   'poxvirus',
#   'alastrim',
#   'reovirus',
#   'rotavirus',
#   'retrovirus',
#   'rhabdovirus',
#   'vesiculovirus',
#   'arbovirus',
#   'Arenaviridae',
#   'Bunyaviridae',
#   'Flaviviridae',
#   'Reoviridae',
#   'Rhabdoviridae',
#   'Togaviridae',
#   'bacteriophage',
#   'coliphage',
#   'viroid',
#   'vector',
#   'nomination',
#   'ordination',
#   'recognition',
#   'call',
#   'move',
#   'demarche',
#   'maneuver',
#   'resolution',
#   'election',
#   'primary',
#   'reelection',
#   'runoff',
#   'sampling',
#   'volition',
#   'velleity',
#   'vote',
#   'veto',
#   'neckwear',
#   'cravat',
#   'ascot',
#   'neckcloth',
#   'necktie',
#   'overgarment',
#   'aba',
#   'cloak',
#   'coat',
#   'coatee',
#   'cutaway',
#   'greatcoat',
#   'capote',
#   'chesterfield',
#   'surtout',
#   'ulster',
#   'jacket',
#   'banyan',
#   'blazer',
#   'bolero',
#   'dolman',
#   'doublet',
#   'jerkin',
#   'jumper',
#   'parachutist',
#   'skydiver',
#   'lumberjack',
#   'scorer',
#   'parka',
#   'cagoule',
#   'sack',
#   'mackinaw',
#   'newmarket',
#   'raincoat',
#   'Burberry',
#   'macintosh',
#   'surcoat',
#   'topper',
#   'izar',
#   'snowsuit',
#   'peplos',
#   'raglan',
#   'reversible',
#   'robe',
#   'abaya',
#   'bathrobe',
#   'kimono',
#   'romper',
#   'sackcloth',
#   'scapular',
#   'scarf',
#   'fichu',
#   'kerchief',
#   'headscarf',
#   'babushka',
#   'hijab',
#   'khimar',
#   'neckerchief',
#   'lambrequin',
#   'mantilla',
#   'muffler',
#   'patka',
#   'rebozo',
#   'sealskin',
#   'separate',
#   'shirt',
#   'camise',
#   'dashiki',
#   'jersey',
#   'kurta',
#   'silks',
#   'skirt',
#   'stomacher',
#   'straitjacket',
#   'suit',
#   'pinstripe',
#   'sunsuit',
#   'sweater',
#   'cardigan',
#   'pullover',
#   'sweatshirt',
#   'turtleneck',
#   'swimsuit',
#   'bikini',
#   'trouser',
#   'breeches',
#   'britches',
#   'buckskins',
#   'chino',
#   'churidars',
#   'cords',
#   'flannel',
#   'grey',
#   'handwear',
#   'glove',
#   'muff',
#   'headdress',
#   'cap',
#   'balaclava',
#   'Balmoral',
#   'beret',
#   'biggin',
#   'biretta',
#   'calpac',
#   'cockscomb',
#   'fez',
#   'Glengarry',
#   'kalansuwa',
#   'kepi',
#   'mobcap',
#   'mortarboard',
#   'nightcap',
#   'pinner',
#   'skullcap',
#   'beanie',
#   'coif',
#   'Afro',
#   'bang',
#   'beehive',
#   'bob',
#   'bouffant',
#   'braid',
#   'pigtail',
#   'queue',
#   'breadline',
#   'chignon',
#   'haircut',
#   'mohawk',
#   'marcel',
#   'pageboy',
#   'pompadour',
#   'ponytail',
#   'roach',
#   'thatch',
#   'wave',
#   'billow',
#   'comber',
#   'lift',
#   'ripple',
#   'yarmulke',
#   'tam',
#   'hat',
#   'helmet',
#   'armet',
#   'basinet',
#   'casque',
#   'casquet',
#   'heaume',
#   'morion',
#   'pickelhaube',
#   'sallet',
#   'hood',
#   'bully',
#   'bullyboy',
#   'muscleman',
#   'skinhead',
#   'Ted',
#   'crown',
#   'tiara',
#   'kaffiyeh',
#   'miter',
#   'topknot',
#   'turban',
#   'wimple',
#   'knitwear',
#   'loungewear',
#   'lounger',
#   'brace',
#   'skeg',
#   'neckpiece',
#   'collar',
#   'choker',
#   'rabato',
#   'nightwear',
#   'nightgown',
#   'nightshirt',
#   'pajama',
#   'outerwear',
#   'apron',
#   'slops',
#   'togs',
#   'uniform',
#   'vestiture',
#   'brassiere',
#   'uplift',
#   'dress',
#   'caftan',
#   'chemise',
#   'coatdress',
#   'dirndl',
#   'negligee',
#   'camisole',
#   'top',
#   'capital',
#   'stock',
#   'float',
#   'overall'],
#  'furniture': ['bassinet',
#   'carrycot',
#   'cradle',
#   'crib',
#   'bed',
#   'berth',
#   'academicianship',
#   'accountantship',
#   'admiralty',
#   'ambassadorship',
#   'apostleship',
#   'apprenticeship',
#   'associateship',
#   'attorneyship',
#   'bailiffship',
#   'baronetage',
#   'bishopry',
#   'cadetship',
#   'caliphate',
#   'captainship',
#   'cardinalship',
#   'chairmanship',
#   'chancellorship',
#   'chaplaincy',
#   'chieftaincy',
#   'clerkship',
#   'commandership',
#   'comptrollership',
#   'consulship',
#   'controllership',
#   'councillorship',
#   'counselorship',
#   'curacy',
#   'curatorship',
#   'custodianship',
#   'deanship',
#   'directorship',
#   'discipleship',
#   'editorship',
#   'eldership',
#   'emirate',
#   'fatherhood',
#   'bunk',
#   'cot',
#   'couch',
#   'convertible',
#   'daybed',
#   'divan',
#   'settee',
#   'squab',
#   'deathbed',
#   'hammock',
#   'anthill',
#   'kopje',
#   'molehill',
#   'sickbed',
#   'bedstead',
#   'bookcase',
#   'buffet',
#   'credenza',
#   'minibar',
#   'cabinet',
#   'dresser',
#   'chiffonier',
#   'highboy',
#   'lowboy',
#   'etagere',
#   'fitment',
#   'hallstand',
#   'lamp',
#   'candle',
#   'chandlery',
#   'dip',
#   'rushlight',
#   'flashlight',
#   'penlight',
#   'flash',
#   'flicker',
#   'gleam',
#   'glitter',
#   'lightning',
#   'thunderbolt',
#   'streak',
#   'lantern',
#   'limelight',
#   'spotlight',
#   'streetlight',
#   'taillight',
#   'nest',
#   'beehive',
#   'aerie',
#   'drey',
#   'nidus',
#   'file',
#   'tickler',
#   'seat',
#   'perch',
#   'roost',
#   'henroost',
#   'sectional',
#   'Sheraton',
#   'sleeper',
#   'dreamer',
#   'sleepwalker',
#   'snorer',
#   'somniloquist',
#   'table',
#   'calendar',
#   'contents'],
#  'vehicle': ['craft',
#   'basketry',
#   'carpentry',
#   'cabinetmaking',
#   'cabinetwork',
#   'drafting',
#   'dressmaking',
#   'couture',
#   'handicraft',
#   'lumbering',
#   'masonry',
#   'brickwork',
#   'nogging',
#   'fiberboard',
#   'Masonite',
#   'plasterboard',
#   'Sheetrock',
#   'stonework',
#   'mintage',
#   'coin',
#   'bawbee',
#   'bezant',
#   'change',
#   'acceleration',
#   'pickup',
#   'technical',
#   'precipitation',
#   'avulsion',
#   'birth',
#   'cradle',
#   'break',
#   'dislocation',
#   'eclipse',
#   'punctuation',
#   'suspension',
#   'mash',
#   'resuspension',
#   'slurry',
#   'vapor',
#   'steam',
#   'spray',
#   'conversion',
#   'glycogenesis',
#   'isomerization',
#   'rectification',
#   'damage',
#   'detriment',
#   'expense',
#   'depreciation',
#   'distortion',
#   'warp',
#   'run',
#   'death',
#   'fatality',
#   'killing',
#   'martyrdom',
#   'megadeath',
#   'passing',
#   'deceleration',
#   'decrease',
#   'attrition',
#   'casualty',
#   'dwindling',
#   'shrinking',
#   'compression',
#   'sinking',
#   'foundering',
#   'settling',
#   'submergence',
#   'dip',
#   'waning',
#   'deformation',
#   'destabilization',
#   'development',
#   'advancement',
#   'broadening',
#   'elaboration',
#   'easing',
#   'disembarrassment',
#   'increase',
#   'accretion',
#   'backup',
#   'buildup',
#   'deposit',
#   'lode',
#   'deposition',
#   'electrodeposition',
#   'pigmentation',
#   'redeposition',
#   'superposition',
#   'faint',
#   'mutation',
#   'freak',
#   'leviathan',
#   'crown',
#   'denier',
#   'dime',
#   'dollar',
#   'Eurodollar',
#   'doubloon',
#   'ducat',
#   'eagle',
#   'eaglet',
#   'ringtail',
#   'harpy',
#   'eightpence',
#   'farthing',
#   'fivepence',
#   'fourpence',
#   'guinea',
#   'halfpenny',
#   'medallion',
#   'nickel',
#   'ninepence',
#   'penny',
#   'quarter',
#   'real',
#   'e',
#   'pi',
#   'fraction',
#   'shilling',
#   'sixpence',
#   'slug',
#   'dumdum',
#   'sou',
#   'stater',
#   'tenpence',
#   'threepence',
#   'twopence',
#   'oculism',
#   'painting',
#   'abstraction',
#   'absolute',
#   'right',
#   'access',
#   'door',
#   'hatchback',
#   'batwing',
#   'advowson',
#   'cabotage',
#   'claim',
#   'dibs',
#   'pretension',
#   'due',
#   'entree',
#   'plate',
#   'floor',
#   'floorboard',
#   'parquet',
#   'flatbed',
#   'grant',
#   'subsidy',
#   'subvention',
#   'copyright',
#   'franchise',
#   'preemption',
#   'seat',
#   'perch',
#   'roost',
#   'henroost',
#   'tenure',
#   'episcopate',
#   'presidency',
#   'title',
#   'use',
#   'application',
#   'misapplication',
#   'technology',
#   'automation',
#   'computerization',
#   'exploitation',
#   'capitalization',
#   'commercialization',
#   'electrification',
#   'overexploitation',
#   'unitization',
#   'misuse',
#   'play',
#   'playlet',
#   'practice',
#   'biologism',
#   'calisthenics',
#   'cannibalism',
#   'anthropophagy',
#   'careerism',
#   'cooperation',
#   'collaboration',
#   'custom',
#   'Americanism',
#   'Anglicism',
#   'consuetude',
#   'couvade',
#   'Germanism',
#   'habit',
#   'hijab',
#   'ritual',
#   'betrothal',
#   'ringing',
#   'marriage',
#   'bigamy',
#   'cuckoldom',
#   'endogamy',
#   'exogamy',
#   'misalliance',
#   'mesalliance',
#   'monandry',
#   'monogamy',
#   'monogyny',
#   'polygamy',
#   'polyandry',
#   'polygyny',
#   'sigeh',
#   'fashion',
#   'baroque',
#   'classicism',
#   'neoclassicism',
#   'order',
#   'summons',
#   'word',
#   'anagram',
#   'antigram',
#   'anaphor',
#   'antonym',
#   'charade',
#   'classifier',
#   'cognate',
#   'headword',
#   'modifier',
#   'adjective',
#   'comparative',
#   'positive',
#   'pertainym',
#   'superlative',
#   'adverb',
#   'intensifier',
#   'noun',
#   'adnoun',
#   'gerund',
#   'verb',
#   'infinitive',
#   'participle',
#   'contraction',
#   'contracture',
#   'tetanus',
#   'vaginismus',
#   'deictic',
#   'derivative',
#   'curvature',
#   'diminutive',
#   'bawdry',
#   'scatology',
#   'disyllable',
#   'form',
#   'abbreviation',
#   'apocope',
#   'acronym',
#   'etymon',
#   'plural',
#   'root',
#   'briarroot',
#   'calamus',
#   'rattan',
#   'carrot',
#   'cassava',
#   'chicory',
#   'ginseng',
#   'horseradish',
#   'orrisroot',
#   'parsnip',
#   'pneumatophore',
#   'radish',
#   'rootlet',
#   'salsify',
#   'senega',
#   'taproot',
#   'taro',
#   'singular',
#   'conjunction',
#   'concomitance',
#   'contemporaneity',
#   'overlap',
#   'crossroads',
#   'interface',
#   'unison',
#   'determiner',
#   'particle',
#   'chylomicron',
#   'flyspeck',
#   'grain',
#   'granule',
#   'chondrule',
#   'microsome',
#   'plastid',
#   'chloroplast',
#   'chromoplast',
#   'grinding',
#   'Microtaggant',
#   'preposition',
#   'pronoun',
#   'head',
#   'attic',
#   'cockloft',
#   'hayloft',
#   'bullethead',
#   'rococo',
#   'Romanticism',
#   'treatment',
#   'acupressure',
#   'acupuncture',
#   'chiropractic',
#   'detoxification',
#   'fomentation',
#   'hydropathy',
#   'massage',
#   'effleurage',
#   'petrissage',
#   'reflexology',
#   'rubdown',
#   'tapotement',
#   'aftercare',
#   'allopathy',
#   'anticoagulation',
#   'bloodletting',
#   'cupping',
#   'venesection',
#   'defibrillation',
#   'modality',
#   'naprapathy',
#   'naturopathy',
#   'orthoptics',
#   'osteoclasis',
#   'osteopathy',
#   'drape',
#   'festoon',
#   'frontal',
#   'portiere',
#   'fit',
#   'featherbedding',
#   'formalism',
#   'habitude',
#   'round',
#   'lobbyism',
#   'mistreatment',
#   'annoyance',
#   'bummer',
#   'huff',
#   'pinprick',
#   'restlessness',
#   'snit',
#   'disregard',
#   'omission',
#   'failure',
#   'backsliding',
#   'recidivism',
#   'default',
#   'error',
#   'ballup',
#   'blot',
#   'blotch',
#   'fingermark',
#   'inkblot',
#   'blunder',
#   'bobble',
#   'bull',
#   'bullock',
#   'clanger',
#   'fluff',
#   'fumble',
#   'howler',
#   'snafu',
#   'spectacle',
#   'trip',
#   'errand',
#   'flight',
#   'junket',
#   'confusion',
#   'bluster',
#   'chaos',
#   'balagan',
#   'demoralization',
#   'schemozzle',
#   'failing',
#   'fatigue',
#   'exhaustion',
#   'frazzle',
#   'inanition',
#   'eyestrain',
#   'grogginess',
#   'loginess',
#   'flaw',
#   'blister',
#   'bug',
#   'hole',
#   'aperture',
#   'cranny',
#   'knothole',
#   'leak',
#   'perforation',
#   'rathole',
#   'insufficiency',
#   'loss',
#   'forfeit',
#   'sacrifice',
#   'wastage',
#   'naught',
#   'nihil',
#   'nonconformity',
#   'out',
#   'putout',
#   'strikeout',
#   'whiff',
#   'modernism',
#   'nonconformism',
#   'nudism',
#   'occult',
#   'ornamentalism',
#   'peonage',
#   'pluralism',
#   'popery',
#   'quotation',
#   'recycling',
#   'usufruct',
#   'teacher',
#   'Bahai',
#   'catechist',
#   'coach',
#   'conditioner',
#   'demonstrator',
#   'docent',
#   'governess',
#   'instructress',
#   'missionary',
#   'Cyril',
#   'preceptor',
#   'schoolteacher',
#   'schoolmarm',
#   'thing',
#   'cityscape',
#   'daub',
#   'distemper',
#   'icon',
#   'landscape',
#   'miniature',
#   'monochrome',
#   'mural',
#   'fresco',
#   'nude',
#   'canvas',
#   'tarpaulin',
#   'pentimento',
#   'seascape',
#   'tanka',
#   'watercolor',
#   'gouache',
#   'wash',
#   'blackwash',
#   'calcimine',
#   'whitewash',
#   'papermaking',
#   'piloting',
#   'plumbing',
#   'pottery',
#   'agateware',
#   'lusterware',
#   'Wedgwood',
#   'pyrotechnics',
#   'roofing',
#   'shingling',
#   'shoemaking',
#   'tailoring',
#   'tanning',
#   'typography',
#   'undertaking',
#   'adventure',
#   'assignment',
#   'mission',
#   'reassignment',
#   'secondment',
#   'baby',
#   'cherub',
#   'foundling',
#   'godchild',
#   'goddaughter',
#   'godson',
#   'neonate',
#   'nursling',
#   'papoose',
#   'cinch',
#   'doddle',
#   'enterprise',
#   'business',
#   'agency',
#   'police',
#   'Europol',
#   'gendarmerie',
#   "Mutawa'een",
#   'posse',
#   'Schutzstaffel',
#   'Gestapo',
#   'organ',
#   'muscle',
#   'agonist',
#   'antihero',
#   'antagonist',
#   'dueler',
#   'enemy',
#   'Luddite',
#   'withstander',
#   'levator',
#   'pronator',
#   'rectus',
#   'abdominal',
#   'abductor',
#   'crimp',
#   'kink',
#   'pleat',
#   'tuck',
#   'pucker',
#   'shanghaier',
#   'adductor',
#   'biceps',
#   'calf',
#   'dogie',
#   'maverick',
#   'deltoid',
#   'depressor',
#   'quadriceps',
#   'masseter',
#   'platysma',
#   'gastrocnemius',
#   'gluteus',
#   'intercostal',
#   'pectoral',
#   'peroneus',
#   'psoas',
#   'rhomboid',
#   'sartorius',
#   'scalenus',
#   'serratus',
#   'soleus',
#   'splenius',
#   'sternocleidomastoid',
#   'teres',
#   'tibialis',
#   'trapezius',
#   'triceps',
#   'myometrium',
#   'sphincter',
#   'supinator',
#   'tensor',
#   'ctene',
#   'effector',
#   'osmoreceptor',
#   'clitoris',
#   'penis',
#   'cock',
#   'micropenis',
#   'precordium',
#   'foot',
#   'flatfoot',
#   'gland',
#   'gonad',
#   'ovary',
#   'ovotestis',
#   'testis',
#   'cobblers',
#   'pituitary',
#   'breast',
#   'bosom',
#   'dug',
#   'udder',
#   'pancreas',
#   'kidney',
#   'heart',
#   'hindgut',
#   'intestine',
#   'colon',
#   'megacolon',
#   'duodenum',
#   'ileum',
#   'jejunum',
#   'liver',
#   'gill',
#   'lung',
#   'stomach',
#   'abomasum',
#   'craw',
#   'psalterium',
#   'reticulum',
#   'rumen',
#   'viscera',
#   'lens',
#   'anastigmat',
#   'condenser',
#   'electrolytic',
#   'trimmer',
#   'contact',
#   'brush',
#   'brake',
#   'airbrake',
#   'canebrake',
#   'spinney',
#   'underbrush',
#   'groundcover',
#   'pearlwort',
#   'rupturewort',
#   'whitlowwort',
#   'placement',
#   'alignment',
#   'Allies',
#   'columniation',
#   'composition',
#   'fenestration',
#   'formation',
#   'backfield',
#   'center',
#   'hub',
#   'midfield',
#   'midstream',
#   'flank',
#   'misalignment',
#   'proportion',
#   'content',
#   'percentage',
#   'rate',
#   'scale',
#   'index',
#   'ramification',
#   'bifurcation',
#   'divarication',
#   'fibrillation',
#   'trifurcation',
#   'spacing',
#   'tandem',
#   'sunglass',
#   'eyepiece',
#   'meniscus',
#   'monocle',
#   'objective',
#   'organelle',
#   'centriole',
#   'cilium',
#   'lysosome',
#   'mitochondrion',
#   'sarcosome',
#   'nucleolus',
#   'nucleus',
#   'pronucleus',
#   'ribosome',
#   'ovipositor',
#   'primordium',
#   'genitalia',
#   'cunt',
#   'minge',
#   'vulva',
#   'pudendum',
#   'nipple',
#   'baroreceptor',
#   'chemoreceptor',
#   'nose',
#   'beak',
#   'conk',
#   'proboscis',
#   'snout',
#   'tastebud',
#   'ear',
#   'exteroceptor',
#   'eye',
#   'peeper',
#   'ommatidium',
#   'interoceptor',
#   'thermoreceptor',
#   'siphon',
#   'articulator',
#   'speaker',
#   'alliterator',
#   'caller',
#   'chatterer',
#   'conversationalist',
#   'deipnosophist',
#   'interlocutor',
#   'dictator',
#   'drawler',
#   'driveller',
#   'ejaculator',
#   'growler',
#   'inquirer',
#   'examiner',
#   'inquisitor',
#   'interviewer',
#   'pollster',
#   'lecturer',
#   'lisper',
#   'mentioner',
#   'motormouth',
#   'mutterer',
#   'narrator',
#   'anecdotist',
#   'fabulist',
#   'griot',
#   'orator',
#   'elocutionist',
#   'eulogist',
#   'haranguer',
#   'spellbinder',
#   'prattler',
#   'ranter',
#   'reciter',
#   'stammerer',
#   'stentor',
#   'venter',
#   'vociferator',
#   'voicer',
#   'wailer',
#   'whisperer',
#   'witness',
#   'attester',
#   'testifier',
#   'subvocalizer',
#   'glottis',
#   'larynx',
#   'stinger',
#   'sucker',
#   'tongue',
#   'wing',
#   'ala',
#   'forewing',
#   'halter',
#   'pennon',
#   'pennoncel',
#   'brokerage',
#   'carrier',
#   'chain',
#   'catena',
#   'firm',
#   'corporation',
#   'conglomerate',
#   'dealer',
#   'barterer',
#   'bibliopole',
#   'cheesemonger',
#   'costermonger',
#   'cutler',
#   'draper',
#   'linendraper',
#   'fence',
#   'backstop',
#   'hedge',
#   'windbreak',
#   'wall',
#   'weir',
#   'fishmonger',
#   'ironmonger',
#   'mercer',
#   'seedsman',
#   'slopseller',
#   'stockjobber',
#   'publisher',
#   'magazine',
#   'pulp',
#   'slick',
#   'newspaper',
#   'daily',
#   'gazette',
#   'tabloid',
#   'operation',
#   'commission',
#   'board',
#   'cabinet',
#   'dresser',
#   'chiffonier',
#   'highboy',
#   'lowboy',
#   'Kashag',
#   'directorate',
#   'conservancy',
#   'jury',
#   'politburo',
#   'presidium',
#   'subcommittee',
#   'vestry',
#   'idle',
#   'running',
#   'draw',
#   'return',
#   'reverse',
#   'rush',
#   'dash',
#   'scamper',
#   'racket',
#   'marathon',
#   'proposition',
#   'axiom',
#   'aphorism',
#   'gnome',
#   'Andvari',
#   'Nibelung',
#   'moralism',
#   'conclusion',
#   'predetermination',
#   'election',
#   'primary',
#   'reelection',
#   'runoff',
#   'converse',
#   'lemma',
#   'negation',
#   'particular',
#   'postulate',
#   'premise',
#   'condition',
#   'absolution',
#   'anchorage',
#   'astigmatism',
#   'keratectasia',
#   'keratoconus',
#   'atmosphere',
#   'gloom',
#   'miasma',
#   'spirit',
#   'soul',
#   'ghost',
#   'atonicity',
#   'scenario',
#   'thesis',
#   'theorem',
#   'universal',
#   'venture',
#   'campaign',
#   'experiment',
#   'testing',
#   'risk',
#   'biohazard',
#   'sally',
#   'upholstery',
#   'winemaking',
#   'caisson',
#   'Humvee',
#   'picket',
#   'tank',
#   'panzer',
#   'rocket',
#   'missile',
#   'Minuteman',
#   'Exocet',
#   'MANPAD',
#   'Stinger',
#   'sidewinder',
#   'skibob',
#   'sled',
#   'bobsled',
#   'steamroller',
#   'bassinet',
#   'bicycle',
#   'ordinary',
#   'velocipede',
#   'boneshaker',
#   'car',
#   'ambulance',
#   'bus',
#   'minibus',
#   'trolleybus',
#   'cab',
#   'compact',
#   'convertible',
#   'coupe',
#   'cruiser',
#   'electric',
#   'hardtop',
#   'handcart',
#   'applecart',
#   'barrow',
#   'carriage',
#   'nonsmoker',
#   'Pullman',
#   'smoker',
#   'chariot',
#   'limber',
#   'sulky',
#   'scooter',
#   'skateboard',
#   'trailer',
#   'loiterer',
#   'plodder',
#   'putterer',
#   'straggler',
#   'tricycle',
#   'pedicab',
#   'unicycle',
#   'wagon',
#   'bandwagon',
#   'cart',
#   'dogcart',
#   'dumpcart',
#   'tumbrel',
#   'dray',
#   'jinrikisha',
#   'oxcart',
#   'lorry',
#   'tramcar',
#   'wain'],
#  'tool': ['abrader',
#   'bender',
#   'clincher',
#   'comb',
#   'currycomb',
#   'pocketcomb',
#   'bit',
#   'blade',
#   'cutter',
#   'drill',
#   'auger',
#   'reamer',
#   'trepan',
#   'eolith',
#   'fork',
#   'tablefork',
#   'gang',
#   'nest',
#   'beehive',
#   'aerie',
#   'drey',
#   'nidus',
#   'edger',
#   'grapnel',
#   'crampon',
#   'hack',
#   'plodder',
#   'awl',
#   'bradawl',
#   'scriber',
#   'bevel',
#   'splay',
#   'bodkin',
#   'hoe',
#   'scuffle',
#   'jack',
#   'neolith',
#   'paleolith',
#   'pestle',
#   'plow',
#   'lister',
#   'buffer',
#   'burr',
#   'hammer',
#   'plane',
#   'airliner',
#   'airbus',
#   'amphibian',
#   'biplane',
#   'bomber',
#   'fighter',
#   'boxer',
#   'bantamweight',
#   'featherweight',
#   'flyweight',
#   'heavyweight',
#   'lightweight',
#   'middleweight',
#   'prizefighter',
#   'puncher',
#   'cowgirl',
#   'gaucho',
#   'roper',
#   'vaquero',
#   'slugger',
#   'bunter',
#   'whiffer',
#   'stumblebum',
#   'welterweight',
#   'brawler',
#   'butter',
#   'ghee',
#   'stick',
#   'bow',
#   'club',
#   'drumstick',
#   'linstock',
#   'matchstick',
#   'maulstick',
#   'singlestick',
#   'spindle',
#   'staff',
#   'newsroom',
#   'office',
#   'countinghouse',
#   'jobcentre',
#   'headquarters',
#   'mukataa',
#   'stob',
#   'cane',
#   'malacca',
#   'supplejack',
#   'defender',
#   'admonisher',
#   'bodyguard',
#   'outrider',
#   'yeoman',
#   'champion',
#   'chaperon',
#   'duenna',
#   'housemother',
#   'custodian',
#   'caretaker',
#   'concierge',
#   'sexton',
#   'superintendent',
#   'ramrod',
#   'verger',
#   'curator',
#   'gamekeeper',
#   'warrener',
#   'greenskeeper',
#   'janitor',
#   'fireman',
#   'guard',
#   'bouncer',
#   'doorkeeper',
#   'halberdier',
#   'screener',
#   'watchman',
#   'lookout',
#   'patroller',
#   'portwatcher',
#   'keeper',
#   'babyminder',
#   'babysitter',
#   'nanny',
#   'mammy',
#   'lawman',
#   'constable',
#   'deputy',
#   'flatfoot',
#   'lieutenant',
#   'sublieutenant',
#   'marshal',
#   'redcap',
#   'narc',
#   'policeman',
#   'bobby',
#   'bull',
#   'bullock',
#   'captain',
#   'peacekeeper',
#   'tribune',
#   'watchdog',
#   'fencer',
#   'gladiator',
#   'gouger',
#   'mauler',
#   'skirmisher',
#   'victor',
#   'conqueror',
#   'subjugator',
#   'wrestler',
#   'jet',
#   'fanjet',
#   'jetliner',
#   'jumbojet',
#   'twinjet',
#   'monoplane',
#   'propjet',
#   'seaplane',
#   'floatplane',
#   'punch',
#   'counterpunch',
#   'haymaker',
#   'hook',
#   'jab',
#   'rake',
#   'ram',
#   'rounder',
#   'adulterer',
#   'adulteress',
#   'wencher',
#   'gigolo',
#   'die',
#   'nickel',
#   'strickle',
#   'stylus',
#   'tamp',
#   'stemmer',
#   'tap',
#   'upset'],
#  'musical_instrument': ['bass',
#   'calliope',
#   'synthesizer',
#   'theremin',
#   'accordion',
#   'celesta',
#   'clavichord',
#   'clavier',
#   'organ',
#   'muscle',
#   'agonist',
#   'antihero',
#   'antagonist',
#   'dueler',
#   'enemy',
#   'Luddite',
#   'withstander',
#   'levator',
#   'pronator',
#   'rectus',
#   'abdominal',
#   'abductor',
#   'crimp',
#   'kink',
#   'pleat',
#   'tuck',
#   'pucker',
#   'shanghaier',
#   'adductor',
#   'biceps',
#   'calf',
#   'dogie',
#   'maverick',
#   'deltoid',
#   'depressor',
#   'quadriceps',
#   'masseter',
#   'platysma',
#   'gastrocnemius',
#   'gluteus',
#   'intercostal',
#   'pectoral',
#   'peroneus',
#   'psoas',
#   'rhomboid',
#   'sartorius',
#   'scalenus',
#   'serratus',
#   'soleus',
#   'splenius',
#   'sternocleidomastoid',
#   'teres',
#   'tibialis',
#   'trapezius',
#   'triceps',
#   'myometrium',
#   'sphincter',
#   'supinator',
#   'tensor',
#   'ctene',
#   'effector',
#   'osmoreceptor',
#   'clitoris',
#   'penis',
#   'cock',
#   'micropenis',
#   'precordium',
#   'foot',
#   'flatfoot',
#   'gland',
#   'gonad',
#   'ovary',
#   'ovotestis',
#   'testis',
#   'cobblers',
#   'pituitary',
#   'breast',
#   'bosom',
#   'dug',
#   'udder',
#   'pancreas',
#   'kidney',
#   'heart',
#   'hindgut',
#   'intestine',
#   'colon',
#   'megacolon',
#   'duodenum',
#   'ileum',
#   'jejunum',
#   'liver',
#   'gill',
#   'lung',
#   'stomach',
#   'abomasum',
#   'craw',
#   'psalterium',
#   'reticulum',
#   'rumen',
#   'viscera',
#   'lens',
#   'anastigmat',
#   'condenser',
#   'electrolytic',
#   'trimmer',
#   'contact',
#   'brush',
#   'brake',
#   'airbrake',
#   'canebrake',
#   'spinney',
#   'underbrush',
#   'groundcover',
#   'pearlwort',
#   'rupturewort',
#   'whitlowwort',
#   'placement',
#   'alignment',
#   'Allies',
#   'columniation',
#   'composition',
#   'fenestration',
#   'formation',
#   'backfield',
#   'center',
#   'hub',
#   'midfield',
#   'midstream',
#   'seat',
#   'perch',
#   'roost',
#   'henroost',
#   'flank',
#   'flight',
#   'head',
#   'attic',
#   'cockloft',
#   'hayloft',
#   'bullethead',
#   'line',
#   'chorus',
#   'diagonal',
#   'linemen',
#   'lineup',
#   'rank',
#   'row',
#   'serration',
#   'terrace',
#   'suntrap',
#   'misalignment',
#   'proportion',
#   'content',
#   'percentage',
#   'rate',
#   'acceleration',
#   'pickup',
#   'technical',
#   'precipitation',
#   'birthrate',
#   'deathrate',
#   'deceleration',
#   'flow',
#   'airflow',
#   'backflow',
#   'regurgitation',
#   'current',
#   'juice',
#   'gravy',
#   'discharge',
#   'elves',
#   'jet',
#   'fanjet',
#   'jetliner',
#   'jumbojet',
#   'twinjet',
#   'lightning',
#   'thunderbolt',
#   'sprites',
#   'spike',
#   'explosion',
#   'airburst',
#   'backfire',
#   'backblast',
#   'blast',
#   'blowback',
#   'fragmentation',
#   'inflation',
#   'reflation',
#   'stagflation',
#   'drip',
#   'dripping',
#   'ebb',
#   'emission',
#   'flush',
#   'flux',
#   'fountain',
#   'freshet',
#   'overflow',
#   'effusion',
#   'cry',
#   'bellow',
#   'boo',
#   'catcall',
#   'clamor',
#   'halloo',
#   'hoot',
#   'hosanna',
#   'noise',
#   'bang',
#   'banging',
#   'bark',
#   'canella',
#   'cascara',
#   'cinchona',
#   'cinnamon',
#   'cork',
#   'magnolia',
#   'mezereum',
#   'phellem',
#   'tanbark',
#   'tapa',
#   'blare',
#   'boom',
#   'chatter',
#   'prate',
#   'scream',
#   'whoop',
#   'yelling',
#   'yodel',
#   'rush',
#   'dash',
#   'scamper',
#   'seepage',
#   'exudation',
#   'gum',
#   'latex',
#   'rubber',
#   'scale',
#   'index',
#   'ramification',
#   'bifurcation',
#   'divarication',
#   'fibrillation',
#   'trifurcation',
#   'spacing',
#   'tandem',
#   'sunglass',
#   'eyepiece',
#   'meniscus',
#   'monocle',
#   'objective',
#   'business',
#   'agency',
#   'police',
#   'Europol',
#   'gendarmerie',
#   "Mutawa'een",
#   'posse',
#   'Schutzstaffel',
#   'Gestapo',
#   'brokerage',
#   'carrier',
#   'chain',
#   'catena',
#   'firm',
#   'corporation',
#   'conglomerate',
#   'dealer',
#   'barterer',
#   'bibliopole',
#   'cheesemonger',
#   'costermonger',
#   'cutler',
#   'draper',
#   'linendraper',
#   'fence',
#   'backstop',
#   'hedge',
#   'windbreak',
#   'fiberboard',
#   'Masonite',
#   'plasterboard',
#   'Sheetrock',
#   'wall',
#   'weir',
#   'fishmonger',
#   'ironmonger',
#   'mercer',
#   'seedsman',
#   'slopseller',
#   'stockjobber',
#   'publisher',
#   'magazine',
#   'pulp',
#   'slick',
#   'newspaper',
#   'daily',
#   'gazette',
#   'tabloid',
#   'franchise',
#   'manufacturer',
#   'armorer',
#   'bottler',
#   'partnership',
#   'copartnership',
#   'processor',
#   'shipbuilder',
#   'underperformer',
#   'grail',
#   'point',
#   'attractor',
#   'intercept',
#   'intersection',
#   'metacenter',
#   'vertex',
#   'thing',
#   'organelle',
#   'centriole',
#   'cilium',
#   'lysosome',
#   'mitochondrion',
#   'sarcosome',
#   'nucleolus',
#   'nucleus',
#   'pronucleus',
#   'ribosome',
#   'ovipositor',
#   'primordium',
#   'genitalia',
#   'cunt',
#   'minge',
#   'vulva',
#   'pudendum',
#   'nipple',
#   'baroreceptor',
#   'chemoreceptor',
#   'nose',
#   'beak',
#   'conk',
#   'proboscis',
#   'snout',
#   'tastebud',
#   'ear',
#   'exteroceptor',
#   'eye',
#   'peeper',
#   'ommatidium',
#   'interoceptor',
#   'thermoreceptor',
#   'siphon',
#   'articulator',
#   'speaker',
#   'alliterator',
#   'caller',
#   'chatterer',
#   'conversationalist',
#   'deipnosophist',
#   'interlocutor',
#   'dictator',
#   'drawler',
#   'driveller',
#   'ejaculator',
#   'growler',
#   'inquirer',
#   'examiner',
#   'inquisitor',
#   'interviewer',
#   'pollster',
#   'lecturer',
#   'lisper',
#   'mentioner',
#   'motormouth',
#   'mutterer',
#   'narrator',
#   'anecdotist',
#   'fabulist',
#   'griot',
#   'orator',
#   'elocutionist',
#   'eulogist',
#   'haranguer',
#   'spellbinder',
#   'prattler',
#   'ranter',
#   'reciter',
#   'stammerer',
#   'stentor',
#   'venter',
#   'vociferator',
#   'voicer',
#   'wailer',
#   'whisperer',
#   'witness',
#   'attester',
#   'testifier',
#   'subvocalizer',
#   'glottis',
#   'larynx',
#   'stinger',
#   'sucker',
#   'tongue',
#   'wing',
#   'ala',
#   'forewing',
#   'halter',
#   'pennon',
#   'pennoncel',
#   'piano',
#   'upright',
#   'column',
#   'jamb',
#   'doorjamb',
#   'post',
#   'bridgehead',
#   'airhead',
#   'beachhead',
#   'lookout',
#   'outstation',
#   'scantling',
#   'shaft',
#   'stile',
#   'bones',
#   'chime',
#   'carillon',
#   'handbell',
#   'cymbal',
#   'zill',
#   'drum',
#   'bongo',
#   'tabor',
#   'tambour',
#   'tambourine',
#   'timbrel',
#   'glockenspiel',
#   'gong',
#   'kettle',
#   'teakettle',
#   'lagerphone',
#   'maraca',
#   'marimba',
#   'banjo',
#   'cello',
#   'viol',
#   'viola',
#   'pansy',
#   'violet',
#   'violin',
#   'Amati',
#   'Guarnerius',
#   'Stradavarius',
#   'chordophone',
#   'balalaika',
#   'harp',
#   'lyre',
#   'trigon',
#   'delta',
#   'wedge',
#   'lute',
#   'mandolin',
#   'mandola',
#   'brass',
#   'latten',
#   'ormolu',
#   'kazoo',
#   'ocarina'],
#  'sport': ['archery',
#   'badminton',
#   'battledore',
#   'doubles',
#   'singles',
#   'basketball',
#   'fives',
#   'handball',
#   'netball',
#   'pallone',
#   'racquetball',
#   'squash',
#   'pumpkin',
#   'cymling',
#   'marrow',
#   'cushaw',
#   'tennis',
#   'volleyball',
#   'croquet',
#   'baseball',
#   'ball',
#   'hardball',
#   'rounders',
#   'softball',
#   'steal',
#   'song',
#   'anthem',
#   'aria',
#   'arietta',
#   'ballad',
#   'minstrelsy',
#   'barcarole',
#   'dirge',
#   'keen',
#   'ditty',
#   'blues',
#   'boogie',
#   'fado',
#   'lied',
#   'lullaby',
#   'oldie',
#   'partsong',
#   'madrigal',
#   'round',
#   'prothalamion',
#   'carol',
#   'chant',
#   'plainsong',
#   'hymn',
#   'canticle',
#   'chorale',
#   'dithyramb',
#   'doxology',
#   'hymeneal',
#   'paean',
#   'recessional',
#   'spiritual',
#   'roundelay',
#   'scolion',
#   'serenade',
#   'chantey',
#   'stickball',
#   'cricket',
#   'shinny',
#   'football',
#   'rugby',
#   'soccer',
#   'hurling',
#   'lacrosse',
#   'polo',
#   'pushball',
#   'golf',
#   'paintball',
#   'quoits',
#   'shuffleboard',
#   'tetherball',
#   'bullfighting',
#   'cockfighting',
#   'hunt',
#   'boxing',
#   'fight',
#   'Armageddon',
#   'assault',
#   'storm',
#   'blizzard',
#   'firestorm',
#   'hailstorm',
#   'northeaster',
#   'rainstorm',
#   'thundershower',
#   'thunderstorm',
#   'windstorm',
#   'cyclone',
#   'tempest',
#   'whirlwind',
#   'combat',
#   'aggression',
#   'hostilities',
#   'dogfight',
#   'spar',
#   'calcite',
#   'alabaster',
#   'chalk',
#   'feldspar',
#   'moonstone',
#   'orthoclase',
#   'plagioclase',
#   'albite',
#   'anorthite',
#   'cycling',
#   'bicycling',
#   'motorcycling',
#   'funambulism',
#   'gymnastics',
#   'acrobatics',
#   'judo',
#   'fishing',
#   'angling',
#   'troll',
#   'casting',
#   'racing',
#   'riding',
#   'dressage',
#   'curvet',
#   'piaffe',
#   'showjumping',
#   'rowing',
#   'crab',
#   'sculling',
#   'skating',
#   'rollerblading',
#   'skateboarding',
#   'skiing',
#   'sledding',
#   'bobsledding',
#   'tobogganing',
#   'luging',
#   'jumping',
#   'track',
#   'surfing',
#   'swimming',
#   'bathe',
#   'dip',
#   'dive',
#   'floating',
#   'snorkeling']}

# %%
collect_wordlists(categories_jaramillo)
# Out:
# animal 1263
# body 1636
# Skipping clothes, only contains 3 words.
# color 226
# Skipping day, only contains 4 words.
# Skipping dessert, only contains 19 words.
# food 392
# relative 109
# Skipping room, only contains 18 words.
# shape 62
# Skipping sound, only contains 6 words.
# toy 47
# beverage 200
# bird 340
# building 39
# coin 109
# Skipping collectable, only contains 1 words.
# condiment 95
# container 40
# dinosaur 45
# direction 153
# emotion 85
# Skipping flower, only contains 1 words.
# fruit 66
# Skipping holiday, only contains 2 words.
# Skipping ingredient, only contains 3 words.
# insect 1049
# instrument 743
# job 299
# Word does not exist in wordnet!
# Skipping jungle animal, only contains 0 words.
# liquid 170
# measure 313
# month 59
# movie 435
# Skipping story, only contains 3 words.
# Skipping pattern, only contains 6 words.
# Skipping planet, only contains 0 words.
# Skipping plant, only contains 22 words.
# reptile 102
# Skipping rhyming, only contains 2 words.
# Skipping season, only contains 4 words.
# Skipping sense, only contains 0 words.
# Skipping silverware, only contains 11 words.
# size 213
# solid 419
# sport 146
# Skipping transportation, only contains 1 words.
# tool 183
# vegetable 68
# writing 56
# ability 1095
# businesses 399
# Skipping city, only contains 0 words.
# Skipping country, only contains 9 words.
# communication 2115
# Skipping continent, only contains 0 words.
# currency 87
# exercise 43
# Skipping habitat, only contains 3 words.
# Skipping hazard, only contains 1 words.
# mammal 303
# material 927
# metal 81
# Skipping ocean, only contains 1 words.
# Skipping president, only contains 0 words.
# Word does not exist in wordnet!
# Skipping school subject, only contains 0 words.
# seasoning 221
# Skipping state, only contains 2 words.
# symbol 361
# Skipping texture, only contains 11 words.
# tree 53
# weather 80
# Skipping colony, only contains 2 words.
# Word does not exist in wordnet!
# Skipping ancient civilization, only contains 0 words.
# Skipping constellation, only contains 3 words.
# Skipping cuisine, only contains 2 words.
# Skipping element, only contains 7 words.
# Skipping landmark, only contains 0 words.
# Word does not exist in wordnet!
# Skipping government type, only contains 0 words.
# Skipping gas, only contains 0 words.
# Skipping gem, only contains 0 words.
# organ 399
# language 280
# mineral 197
# Skipping mountain, only contains 5 words.
# Word does not exist in wordnet!
# Skipping music type, only contains 0 words.
# Skipping precipitation, only contains 0 words.
# book 216
# religion 43
# Skipping tradition, only contains 0 words.
# {'animal': ['acrodont',
#   'adult',
#   'brachycephalic',
#   'caregiver',
#   'bonesetter',
#   'electrologist',
#   'dentist',
#   'endodontist',
#   'exodontist',
#   'orthodontist',
#   'pedodontist',
#   'periodontist',
#   'prosthodontist',
#   'doctor',
#   'abortionist',
#   'allergist',
#   'angiologist',
#   'extern',
#   'gastroenterologist',
#   'hakim',
#   'intern',
#   'quack',
#   'specialist',
#   'attache',
#   'canonist',
#   'criminologist',
#   'crystallographer',
#   'dietician',
#   'educationist',
#   'enologist',
#   'Germanist',
#   'graphologist',
#   'limnologist',
#   'meteorologist',
#   'weatherman',
#   'optometrist',
#   'orientalist',
#   'Teutonist',
#   'surgeon',
#   'amputator',
#   'neurosurgeon',
#   'veterinarian',
#   'inoculator',
#   'nurse',
#   'matron',
#   'midwife',
#   'probationer',
#   'pharmacist',
#   'pharmacologist',
#   'catch',
#   'centrist',
#   'character',
#   'conservative',
#   'capitalist',
#   'conformist',
#   'hardliner',
#   'minimalist',
#   'mossback',
#   'neoconservative',
#   'reactionary',
#   'Bourbon',
#   'rightist',
#   'fascist',
#   'Blackshirt',
#   'falangist',
#   'fascista',
#   'Nazi',
#   'Brownshirt',
#   'monarchist',
#   'Cavalier',
#   'Orleanist',
#   'Tory',
#   'square',
#   'quadrate',
#   'traditionalist',
#   'dolichocephalic',
#   'elder',
#   'dean',
#   'doyenne',
#   'host',
#   'hostess',
#   'knocker',
#   'supremo',
#   'celebrity',
#   'immortal',
#   'lion',
#   'lioness',
#   'lionet',
#   'luminary',
#   'personality',
#   'identity',
#   'identification',
#   'diagnosis',
#   'prognosis',
#   'urinalysis',
#   'personhood',
#   'personableness',
#   'toast',
#   'zwieback',
#   'colossus',
#   'Excellency',
#   'fixer',
#   'hierarch',
#   'kingmaker',
#   'kingpin',
#   'magnifico',
#   'name',
#   'agnomen',
#   'alias',
#   'appellation',
#   'nickname',
#   'title',
#   'eponym',
#   'nepotist',
#   'sirdar',
#   'socialite',
#   'sun',
#   'worthy',
#   'liberal',
#   'latitudinarian',
#   'neoliberal',
#   'pluralist',
#   'Whig',
#   'biped',
#   'captive',
#   'convict',
#   'lifer',
#   'trusty',
#   'detainee',
#   'hostage',
#   'internee',
#   'chordate',
#   'cephalochordate',
#   'lancelet',
#   'tunicate',
#   'appendicularia',
#   'ascidian',
#   'doliolum',
#   'larvacean',
#   'salp',
#   'vertebrate',
#   'Amniota',
#   'amniote',
#   'amphibian',
#   'fish',
#   'crossopterygian',
#   'coelacanth',
#   'lungfish',
#   'ceratodus',
#   'cornetfish',
#   'ganoid',
#   'bowfin',
#   'gar',
#   'paddlefish',
#   'sturgeon',
#   'beluga',
#   'halfbeak',
#   'needlefish',
#   'timucu',
#   'pipefish',
#   'seahorse',
#   'saury',
#   'shrimpfish',
#   'snipefish',
#   'anchovy',
#   'argentine',
#   'bonefish',
#   'catfish',
#   'alewife',
#   'herring',
#   'bloater',
#   'kipper',
#   'rollmops',
#   'sprat',
#   'whitebait',
#   'menhaden',
#   'pilchard',
#   'sardine',
#   'shad',
#   'catostomid',
#   'sucker',
#   'characin',
#   'piranha',
#   'tetra',
#   'cyprinid',
#   'carp',
#   'chub',
#   'dace',
#   'goldfish',
#   'silverfish',
#   'gudgeon',
#   'mudskipper',
#   'minnow',
#   'roach',
#   'rudd',
#   'shiner',
#   'tench',
#   'cyprinodont',
#   'guppy',
#   'killifish',
#   'flagfish',
#   'mummichog',
#   'rivulus',
#   'swordtail',
#   'loach',
#   'topminnow',
#   'mollie',
#   'mosquitofish',
#   'platy',
#   'eel',
#   'elver',
#   'gadoid',
#   'cod',
#   'cusk',
#   'grenadier',
#   'haddock',
#   'hake',
#   'ling',
#   'pollack',
#   'whiting',
#   'greeneye',
#   'lancetfish',
#   'lanternfish',
#   'lizardfish',
#   'oarfish',
#   'opah',
#   'Ostariophysi',
#   'ribbonfish',
#   'salmonid',
#   'char',
#   'snuff',
#   'salmon',
#   'blackfish',
#   'chinook',
#   'coho',
#   'redfish',
#   'sockeye',
#   'trout',
#   'smelt',
#   'tarpon',
#   'ladyfish',
#   'whitefish',
#   'anomalops',
#   'barracuda',
#   'batfish',
#   'boarfish',
#   'sweeper',
#   'trumpetfish',
#   'elasmobranch',
#   'ray',
#   'moonbeam',
#   'sunbeam',
#   'shark',
#   'dogfish',
#   'hammerhead',
#   'mako',
#   'porbeagle',
#   'thresher',
#   'holocephalan',
#   'chimaera',
#   'fingerling',
#   'barracouta',
#   'groundfish',
#   'mouthbreeder',
#   'spawner',
#   'brit',
#   'patrial',
#   'parr',
#   'anaspid',
#   'conodont',
#   'cyclostome',
#   'hagfish',
#   'eptatretus',
#   'heterostracan',
#   'lamprey',
#   'osteostracan',
#   'ostracoderm',
#   'placoderm',
#   'bird',
#   'hummingbird',
#   'thornbill',
#   'swift',
#   'gallinule',
#   'moorhen',
#   'seabird',
#   'auk',
#   'auklet',
#   'guillemot',
#   'murre',
#   'razorbill',
#   'jaeger',
#   'skua',
#   'larid',
#   'gull',
#   'tern',
#   'skimmer',
#   'loon',
#   'albatross',
#   'petrel',
#   'fulmar',
#   'shearwater',
#   'cormorant',
#   'gannet',
#   'booby',
#   'solan',
#   'pelican',
#   'snakebird',
#   'grebe',
#   'dabchick',
#   'puffin',
#   'penguin',
#   'Adelie',
#   'swan',
#   'cob',
#   'coscoroba',
#   'cygnet',
#   'pen',
#   'ballpoint',
#   'quill',
#   'Sharpie',
#   'goffer',
#   'trumpeter',
#   'bugler',
#   'whooper',
#   'bustard',
#   'chunga',
#   'courlan',
#   'crane',
#   'flamingo',
#   'heron',
#   'ibis',
#   'limpkin',
#   'ortygan',
#   'rail',
#   'bar',
#   'barrelhouse',
#   'speakeasy',
#   'taffrail',
#   'shoebill',
#   'shorebird',
#   'avocet',
#   'courser',
#   'curlew',
#   'godwit',
#   'oystercatcher',
#   'phalarope',
#   'plover',
#   'dotterel',
#   'killdeer',
#   'lapwing',
#   'turnstone',
#   'pratincole',
#   'sandpiper',
#   'greenshank',
#   'knot',
#   'redshank',
#   'ruff',
#   'sanderling',
#   'tattler',
#   'yellowlegs',
#   'snipe',
#   'dowitcher',
#   'greyback',
#   'jacksnipe',
#   'stilt',
#   'spoonbill',
#   'stork',
#   'jabiru',
#   'marabou',
#   'openbill',
#   'saddlebill',
#   'waterfowl',
#   'duck',
#   'bufflehead',
#   'canvasback',
#   'drake',
#   'duckling',
#   'goldeneye',
#   'mallard',
#   'pintail',
#   'pochard',
#   'redhead',
#   'scaup',
#   'eider',
#   'merganser',
#   'goosander',
#   'smew',
#   'scoter',
#   'sheldrake',
#   'shoveler',
#   'teal',
#   'cyan',
#   'widgeon',
#   'goose',
#   'brant',
#   'gander',
#   'gosling',
#   'greylag',
#   'honker',
#   'screamer',
#   'crier',
#   'bawler',
#   'blubberer',
#   'archaeopteryx',
#   'archaeornis',
#   'nomad',
#   'Bedouin',
#   'Bushman',
#   'Hun',
#   'Saracen',
#   'Scythian',
#   'vagrant',
#   'beachcomber',
#   'sundowner',
#   'tramp',
#   'dosser',
#   'Accipitriformes',
#   'eagle',
#   'eaglet',
#   'ringtail',
#   'harpy',
#   'hawk',
#   'buteonine',
#   'buzzard',
#   'eyas',
#   'falcon',
#   'caracara',
#   'carancha',
#   'gyrfalcon',
#   'hobby',
#   'speleology',
#   'kestrel',
#   'peregrine',
#   'goshawk',
#   'harrier',
#   'kite',
#   'osprey',
#   'redtail',
#   'owl',
#   'owlet',
#   'vulture',
#   'Aegypiidae',
#   'frogmouth',
#   'goatsucker',
#   'nighthawk',
#   'poorwill',
#   'whippoorwill',
#   'oilbird',
#   'carinate',
#   'cock',
#   'hoopoe',
#   'hornbill',
#   'kingfisher',
#   'kookaburra',
#   'motmot',
#   'roller',
#   'tody',
#   'cuckoo',
#   'touraco',
#   'dickeybird',
#   'chachalaca',
#   'dodo',
#   'pigeon',
#   'dove',
#   'turtledove',
#   'squab',
#   'sandgrouse',
#   'solitaire',
#   'curassow',
#   'bantam',
#   'chicken',
#   'broiler',
#   'capon',
#   'fryer',
#   'hen',
#   'cackler',
#   'layer',
#   'backing',
#   'blanket',
#   'afghan',
#   'mackinaw',
#   'manta',
#   'course',
#   'propaedeutic',
#   'seminar',
#   'workshop',
#   'bindery',
#   'bookbindery',
#   'brickyard',
#   'pottery',
#   'agateware',
#   'lusterware',
#   'Wedgwood',
#   'saddlery',
#   'bit',
#   'caparison',
#   'bard',
#   'horsecloth',
#   'cinch',
#   'doddle',
#   'hame',
#   'harness',
#   'headgear',
#   'cap',
#   'balaclava',
#   'Balmoral',
#   'beret',
#   'biggin',
#   'biretta',
#   'calpac',
#   'cockscomb',
#   'fez',
#   'Glengarry',
#   'kalansuwa',
#   'kepi',
#   'mobcap',
#   'mortarboard',
#   'nightcap',
#   'pinner',
#   'skullcap',
#   'beanie',
#   'coif',
#   'Afro',
#   'bang',
#   'beehive',
#   'bob',
#   'bouffant',
#   'braid',
#   'pigtail',
#   'queue',
#   'breadline',
#   'chignon',
#   'haircut',
#   'mohawk',
#   'marcel',
#   'pageboy',
#   'pompadour',
#   'ponytail',
#   'yarmulke',
#   'tam',
#   'hat',
#   'bearskin',
#   'boater',
#   'bonnet',
#   'sunbonnet',
#   'bicorn',
#   'tricorn',
#   'deerstalker',
#   'fedora',
#   'beaver',
#   'millinery',
#   'porkpie',
#   'sombrero',
#   "sou'wester",
#   'sunhat',
#   'titfer',
#   'toque',
#   'tyrolean',
#   'helmet',
#   'armet',
#   'basinet',
#   'casque',
#   'casquet',
#   'heaume',
#   'morion',
#   'pickelhaube',
#   'sallet',
#   'hood',
#   'bully',
#   'bullyboy',
#   'muscleman',
#   'skinhead',
#   'Ted',
#   'crown',
#   'tiara',
#   'kaffiyeh',
#   'miter',
#   'topknot',
#   'turban',
#   'wimple',
#   'martingale',
#   'apishamore',
#   'yoke',
#   'tucker',
#   'turnery',
#   'cushion',
#   'interlayer',
#   'lift',
#   'overlay',
#   'ply',
#   'tier',
#   'wall',
#   'attic',
#   'cockloft',
#   'hayloft',
#   'firewall',
#   'gable',
#   'pediment',
#   'parapet',
#   'proscenium',
#   'sidewall',
#   'wainscoting',
#   'pullet',
#   'roaster',
#   'spatchcock',
#   'cochin',
#   'Cornish',
#   'Dorking',
#   'turkey',
#   'grouse',
#   'phasianid',
#   'partridge',
#   'pheasant',
#   'afropavo',
#   'argus',
#   'monal',
#   'peafowl',
#   'peachick',
#   'peacock',
#   'peahen',
#   'tragopan',
#   'quail',
#   'tinamou',
#   'guan',
#   'hoatzin',
#   'megapode',
#   'maleo',
#   'fetus',
#   'abortus',
#   'baby',
#   'cherub',
#   'foundling',
#   'godchild',
#   'goddaughter',
#   'godson',
#   'neonate',
#   'nursling',
#   'papoose',
#   'monster',
#   'bogeyman',
#   'amphisbaena',
#   'basilisk',
#   'centaur',
#   'Chiron',
#   'Cerberus',
#   'Chimera',
#   'cockatrice',
#   'dragon',
#   'wyvern',
#   'Geryon',
#   'Gorgon',
#   'Euryale',
#   'Medusa',
#   'Stheno',
#   'gryphon',
#   'Harpy',
#   'Hydra',
#   'doppelganger',
#   'leviathan',
#   'manticore',
#   'Minotaur',
#   'roc',
#   'salamander',
#   'ambystomid',
#   'axolotl',
#   'waterdog',
#   'amphiuma',
#   'dicamptodon',
#   'hellbender',
#   'newt',
#   'eft',
#   'olm',
#   'siren',
#   'Sphinx',
#   'troll',
#   'Typhoeus',
#   'Typhon',
#   'werewolf',
#   'gnathostome',
#   'mammal',
#   'queen',
#   'metatherian',
#   'marsupial',
#   'bandicoot',
#   'dasyure',
#   'numbat',
#   'thylacine',
#   'kangaroo',
#   'bettong',
#   'potoroo',
#   'wallaby',
#   'pademelon',
#   'opossum',
#   'cuscus',
#   'koala',
#   'phalanger',
#   'wombat',
#   'placental',
#   'aardvark',
#   'cetacean',
#   'whale',
#   'seal',
#   'walrus',
#   'dugong',
#   'manatee',
#   'bat',
#   'freetail',
#   'pipistrelle',
#   'serotine',
#   'buck',
#   'bull',
#   'bullock',
#   'carnivore',
#   'bear',
#   'grizzly',
#   'bruin',
#   'canine',
#   'fang',
#   'feline',
#   'cheetah',
#   'jaguar',
#   'leopard',
#   'liger',
#   'cat',
#   'Abyssinian',
#   'Angora',
#   'kitty',
#   'Maltese',
#   'Manx',
#   'mouser',
#   'tabby',
#   'wildcat',
#   'badger',
#   'glutton',
#   'grison',
#   'marten',
#   'fisher',
#   'angler',
#   'trawler',
#   'sable',
#   'rigger',
#   'mink',
#   'otter',
#   'polecat',
#   'ratel',
#   'skunk',
#   'tayra',
#   'weasel',
#   'wolverine',
#   'procyonid',
#   'bassarisk',
#   'coati',
#   'kinkajou',
#   'raccoon',
#   'viverrine',
#   'civet',
#   'binturong',
#   'Cryptoprocta',
#   'fanaloka',
#   'fossa',
#   'genet',
#   'meerkat',
#   'suricate',
#   'mongoose',
#   'ichneumon',
#   'cow',
#   'heifer',
#   'springer',
#   'doe',
#   'edentate',
#   'anteater',
#   'armadillo',
#   'apar',
#   'peba',
#   'peludo',
#   'pichiciago',
#   'tatouay',
#   'megatherian',
#   'mylodon',
#   'mylodontid',
#   'mapinguari',
#   'sloth',
#   'Fissipedia',
#   'hyrax',
#   'insectivore',
#   'hedgehog',
#   'mole',
#   'shrew',
#   'virago',
#   'yenta',
#   'tenrec',
#   'lagomorph',
#   'Duplicidentata',
#   'leporid',
#   'hare',
#   'jackrabbit',
#   'leveret',
#   'rabbit',
#   'pika',
#   'livestock',
#   'pachyderm',
#   'elephant',
#   'gomphothere',
#   'mammoth',
#   'pangolin',
#   'primate',
#   'proboscidean',
#   'rodent',
#   'abrocome',
#   'agouti',
#   'pentail',
#   'Unguiculata',
#   'unguiculate',
#   'Ungulata',
#   'ungulate',
#   'dinocerate',
#   'dinoceras',
#   'camel',
#   'hippopotamus',
#   'llama',
#   'alpaca',
#   'guanaco',
#   'peccary',
#   'ruminant',
#   'bovid',
#   'antelope',
#   'addax',
#   'blackbuck',
#   'bongo',
#   'eland',
#   'gazelle',
#   'springbok',
#   'gerenuk',
#   'gnu',
#   'bushbuck',
#   'nyala',
#   'hartebeest',
#   'impala',
#   'kudu',
#   'nilgai',
#   'oryx',
#   'gemsbok',
#   'puku',
#   'saiga',
#   'sassaby',
#   'steenbok',
#   'waterbuck',
#   'kob',
#   'lechwe',
#   'bison',
#   'wisent',
#   'bovine',
#   'Brahman',
#   'cattle',
#   'Africander',
#   'beef',
#   'cattalo',
#   'Charolais',
#   'Durham',
#   'Galloway',
#   'Hereford',
#   'longhorn',
#   'ox',
#   'goat',
#   'billy',
#   'kid',
#   'bairn',
#   'buster',
#   'changeling',
#   'mongoloid',
#   'imp',
#   'leprechaun',
#   'sandman',
#   'kiddy',
#   'orphan',
#   'peanut',
#   'pickaninny',
#   'preschooler',
#   'silly',
#   'sprog',
#   'toddler',
#   'urchin',
#   'ragamuffin',
#   'gamine',
#   'waif',
#   'nanny',
#   'mammy',
#   'ibex',
#   'markhor',
#   'chamois',
#   'goral',
#   'serow',
#   'takin',
#   'anoa',
#   'tamarau',
#   'carabao',
#   'sheep',
#   'broadtail',
#   'Cheviot',
#   'Cotswold',
#   'Exmoor',
#   'Hampshire',
#   'Lincoln',
#   'longwool',
#   'merino',
#   'Rambouillet',
#   'ewe',
#   'ram',
#   'wether',
#   'bellwether',
#   'aoudad',
#   'argali',
#   'bighorn',
#   'mouflon',
#   'urial',
#   'chevrotain',
#   'kanchil',
#   'napu',
#   'deer',
#   'brocket',
#   'caribou',
#   'elk',
#   'fawn',
#   'muntjac',
#   'pricket',
#   'roebuck',
#   'sambar',
#   'wapiti',
#   'giraffe',
#   'okapi',
#   'pollard',
#   'pronghorn',
#   'swine',
#   'babirusa',
#   'boar',
#   'hog',
#   'razorback',
#   'sow',
#   'warthog',
#   'vicuna',
#   'equine',
#   'ass',
#   'hinny',
#   'horse',
#   'bay',
#   'bight',
#   'chestnut',
#   'eohippus',
#   'hack',
#   'plodder',
#   'mule',
#   'quagga',
#   'zebra',
#   'rhinoceros',
#   'tapir',
#   'yearling',
#   'prototherian',
#   'monotreme',
#   'echidna',
#   'tusker',
#   'reptile',
#   'anapsid',
#   'chelonian',
#   'turtle',
#   'diapsid',
#   'archosaur',
#   'dinosaur',
#   'argentinosaur',
#   'diplodocus',
#   'iguanodon',
#   'ornithischian',
#   'ankylosaur',
#   'Edmontonia',
#   'stegosaur',
#   'pachycephalosaur',
#   'ceratopsian',
#   'protoceratops',
#   'psittacosaur',
#   'styracosaur',
#   'triceratops',
#   'hadrosaur',
#   'anatotitan',
#   'corythosaur',
#   'edmontosaurus',
#   'trachodon',
#   'ornithopod',
#   'pisanosaur',
#   'staurikosaur',
#   'saurischian',
#   'sauropod',
#   'apatosaur',
#   'barosaur',
#   'theropod',
#   'allosaur',
#   'carnosaur',
#   'ceratosaur',
#   'coelophysis',
#   'compsognathus',
#   'eoraptor',
#   'herrerasaur',
#   ...],
#  'body': ['person',
#   'abator',
#   'abjurer',
#   'abomination',
#   'abstainer',
#   'puritan',
#   'stylite',
#   'achiever',
#   'great',
#   'highflier',
#   'natural',
#   'sleeper',
#   'dreamer',
#   'sleepwalker',
#   'snorer',
#   'somniloquist',
#   'acquaintance',
#   'acquirer',
#   'appropriator',
#   'kleptomaniac',
#   'poacher',
#   'preemptor',
#   'procurer',
#   'procuress',
#   'whoremaster',
#   'recipient',
#   'addressee',
#   'alienee',
#   'annuitant',
#   'assignee',
#   'beneficiary',
#   'devisee',
#   'legatee',
#   'pensioner',
#   'borrower',
#   'freeloader',
#   'conferee',
#   'consignee',
#   'dependant',
#   'charge',
#   'countercharge',
#   'minion',
#   'grantee',
#   'heir',
#   'heiress',
#   'honoree',
#   'academician',
#   'laureate',
#   'Nobelist',
#   'host',
#   'hostess',
#   'mandatary',
#   'payee',
#   'protege',
#   'protegee',
#   'sendee',
#   'transferee',
#   'warrantee',
#   'active',
#   'actor',
#   'actress',
#   'starlet',
#   'tragedienne',
#   'barnstormer',
#   'comedian',
#   'clown',
#   'comedienne',
#   'gagman',
#   'joker',
#   'ham',
#   'prosciutto',
#   'heavy',
#   'ingenue',
#   'mime',
#   'plant',
#   'brewery',
#   'brewpub',
#   'microbrewery',
#   'distillery',
#   'winery',
#   'factory',
#   'maquiladora',
#   'cannery',
#   'foundry',
#   'armory',
#   'lumbermill',
#   'battery',
#   'sweatshop',
#   'mint',
#   'flood',
#   'debacle',
#   'floodhead',
#   'haymow',
#   'packinghouse',
#   'refinery',
#   'saltworks',
#   'smelter',
#   'reenactor',
#   'star',
#   'lodestar',
#   'Trapezium',
#   'pulsar',
#   'nova',
#   'sun',
#   'supergiant',
#   'supernova',
#   'supernumerary',
#   'tragedian',
#   'understudy',
#   'upstager',
#   'adjudicator',
#   'judge',
#   'alcalde',
#   'Daniel',
#   'doge',
#   'justiciar',
#   'magistrate',
#   'stipendiary',
#   'ordinary',
#   'praetor',
#   'qadi',
#   'recorder',
#   'Dictaphone',
#   'oscillograph',
#   'trier',
#   'official',
#   'agent',
#   'eliminator',
#   'obliterator',
#   'impairer',
#   'pathogen',
#   'virus',
#   'adenovirus',
#   'alphavirus',
#   'arenavirus',
#   'bunyavirus',
#   'filovirus',
#   'flavivirus',
#   'hepadnavirus',
#   'herpes',
#   'lyssavirus',
#   'myxovirus',
#   'orthomyxovirus',
#   'paramyxovirus',
#   'papovavirus',
#   'polyoma',
#   'parvovirus',
#   'picornavirus',
#   'enterovirus',
#   'coxsackievirus',
#   'echovirus',
#   'poliovirus',
#   'rhinovirus',
#   'poxvirus',
#   'alastrim',
#   'reovirus',
#   'rotavirus',
#   'retrovirus',
#   'rhabdovirus',
#   'vesiculovirus',
#   'arbovirus',
#   'Arenaviridae',
#   'Bunyaviridae',
#   'Flaviviridae',
#   'Reoviridae',
#   'Rhabdoviridae',
#   'Togaviridae',
#   'bacteriophage',
#   'coliphage',
#   'viroid',
#   'vector',
#   'motor',
#   'starter',
#   'engine',
#   'generator',
#   'diesel',
#   'turbine',
#   'fanjet',
#   'ramjet',
#   'rocket',
#   'missile',
#   'Minuteman',
#   'Exocet',
#   'MANPAD',
#   'Stinger',
#   'sidewinder',
#   'stepper',
#   'mutagen',
#   'quickener',
#   'relaxer',
#   'repressor',
#   'retardant',
#   'satisfier',
#   'shortener',
#   'stressor',
#   'teratogen',
#   'thalidomide',
#   'vasoconstrictor',
#   'adrenergic',
#   'phenylephrine',
#   'phenylpropanolamine',
#   'angiotensin',
#   'coldness',
#   'epinephrine',
#   'lypressin',
#   'naphazoline',
#   'nicotine',
#   'noradrenaline',
#   'vasopressin',
#   'vasopressor',
#   'apparatchik',
#   'appointee',
#   'placeman',
#   'bailiff',
#   'beadle',
#   'bureaucrat',
#   'procurator',
#   'lister',
#   'taxer',
#   'caretaker',
#   'concierge',
#   'sexton',
#   'superintendent',
#   'ramrod',
#   'verger',
#   'censor',
#   'churchwarden',
#   'deacon',
#   'deaconess',
#   'elder',
#   'dean',
#   'doyenne',
#   'commissar',
#   'diplomat',
#   'ambassador',
#   'ambassadress',
#   'consul',
#   'envoy',
#   'internuncio',
#   'Kennan',
#   'minister',
#   'ministrant',
#   'nuncio',
#   'plenipotentiary',
#   'selectman',
#   'selectwoman',
#   'equerry',
#   'coyote',
#   'coydog',
#   'holdover',
#   'incumbent',
#   'Inquisitor',
#   'invalidator',
#   'admirer',
#   'anglophile',
#   'believer',
#   'abiogenist',
#   'apostle',
#   'colonialist',
#   'Confucian',
#   'evolutionist',
#   'imperialist',
#   'Malthusian',
#   'vitalist',
#   'Boswell',
#   'cheerleader',
#   'Confederate',
#   'bushwhacker',
#   'Rebel',
#   'corporatist',
#   'enthusiast',
#   'addict',
#   'backslapper',
#   'balletomane',
#   'fanatic',
#   'gadgeteer',
#   'shutterbug',
#   'aficionado',
#   'railbird',
#   'Francophile',
#   'functionalist',
#   'Jacobite',
#   'loyalist',
#   'philhellene',
#   'pillar',
#   'hajj',
#   'salat',
#   'sawm',
#   'shahadah',
#   'zakat',
#   'Roundhead',
#   'seconder',
#   'Shavian',
#   'subscriber',
#   'sympathizer',
#   'toaster',
#   'upholder',
#   'voucher',
#   'Whig',
#   'adoptee',
#   'adult',
#   'brachycephalic',
#   'caregiver',
#   'bonesetter',
#   'electrologist',
#   'dentist',
#   'endodontist',
#   'exodontist',
#   'orthodontist',
#   'pedodontist',
#   'periodontist',
#   'prosthodontist',
#   'doctor',
#   'abortionist',
#   'allergist',
#   'angiologist',
#   'extern',
#   'gastroenterologist',
#   'hakim',
#   'intern',
#   'quack',
#   'specialist',
#   'attache',
#   'canonist',
#   'criminologist',
#   'crystallographer',
#   'dietician',
#   'educationist',
#   'enologist',
#   'Germanist',
#   'graphologist',
#   'limnologist',
#   'meteorologist',
#   'weatherman',
#   'optometrist',
#   'orientalist',
#   'Teutonist',
#   'surgeon',
#   'amputator',
#   'neurosurgeon',
#   'veterinarian',
#   'inoculator',
#   'nurse',
#   'matron',
#   'midwife',
#   'probationer',
#   'pharmacist',
#   'pharmacologist',
#   'catch',
#   'centrist',
#   'character',
#   'conservative',
#   'capitalist',
#   'conformist',
#   'hardliner',
#   'minimalist',
#   'mossback',
#   'neoconservative',
#   'reactionary',
#   'Bourbon',
#   'rightist',
#   'fascist',
#   'Blackshirt',
#   'falangist',
#   'fascista',
#   'Nazi',
#   'Brownshirt',
#   'monarchist',
#   'Cavalier',
#   'Orleanist',
#   'Tory',
#   'square',
#   'quadrate',
#   'traditionalist',
#   'dolichocephalic',
#   'adventurer',
#   'adventuress',
#   'argonaut',
#   'cowboy',
#   'cowgirl',
#   'gaucho',
#   'roper',
#   'vaquero',
#   'daredevil',
#   'tearaway',
#   'gambler',
#   'bettor',
#   'caller',
#   'taker',
#   'bookmaker',
#   'crapshooter',
#   'croupier',
#   'loser',
#   'shooter',
#   'speculator',
#   'Edwardian',
#   'winner',
#   'contestee',
#   'medalist',
#   'upsetter',
#   'walloper',
#   'hotspur',
#   'mercenary',
#   'ninja',
#   'mountaineer',
#   'alpinist',
#   'adversary',
#   'dueler',
#   'enemy',
#   'Luddite',
#   'withstander',
#   'advisee',
#   'advocate',
#   'apologist',
#   'constitutionalist',
#   'Darwinian',
#   'democrat',
#   'federalist',
#   'Gnostic',
#   'humanist',
#   'classicist',
#   'philologist',
#   'ideologist',
#   'internationalist',
#   'irredentist',
#   'isolationist',
#   'Jansenist',
#   'libertarian',
#   'Maoist',
#   'Marxist',
#   'nationalist',
#   'chauvinist',
#   'neoclassicist',
#   'neutralist',
#   'nullifier',
#   'partisan',
#   'bigot',
#   'antifeminist',
#   'dogmatist',
#   'partitionist',
#   'Platonist',
#   'presenter',
#   'protectionist',
#   'republican',
#   'ritualist',
#   'ruralist',
#   'secessionist',
#   'secularist',
#   'separatist',
#   'spokesperson',
#   'suffragist',
#   'suffragette',
#   'supporter',
#   'supremacist',
#   'Klansman',
#   'teleologist',
#   'Thatcherite',
#   'unilateralist',
#   'affiant',
#   'African',
#   'Algerian',
#   'Angolan',
#   'Angolese',
#   'Bantu',
#   'Herero',
#   'Hutu',
#   'Luba',
#   'Shona',
#   'Sotho',
#   'Tswana',
#   'Tutsi',
#   'Basotho',
#   'Beninese',
#   'Berber',
#   'Almoravid',
#   'Riff',
#   'kaffir',
#   'Burundian',
#   'Cameroonian',
#   'Carthaginian',
#   'Chadian',
#   'Chewa',
#   'Congolese',
#   'Djiboutian',
#   'Egyptian',
#   'Cairene',
#   'Copt',
#   'Nubian',
#   'Theban',
#   'Ethiopian',
#   'Amhara',
#   'Eritrean',
#   'Eurafrican',
#   'Ewe',
#   'Fulani',
#   'Gabonese',
#   'Gambian',
#   'Ghanian',
#   'Guinean',
#   'Kenyan',
#   'Liberian',
#   'Libyan',
#   'Madagascan',
#   'Malawian',
#   'Malian',
#   'Mauritanian',
#   'Moroccan',
#   'Mozambican',
#   'Namibian',
#   'Nigerian',
#   'Edo',
#   'Hausa',
#   'Igbo',
#   'Yoruba',
#   'Nigerien',
#   'Rwandan',
#   'Senegalese',
#   'Somalian',
#   'Afrikaner',
#   'Sudanese',
#   'Swazi',
#   'Tanzanian',
#   'Togolese',
#   'Tuareg',
#   'Tunisian',
#   'Ugandan',
#   'Xhosa',
#   'Zairese',
#   'Zambian',
#   'Zimbabwean',
#   'Zulu',
#   'agnostic',
#   'amateur',
#   'dabbler',
#   'hobbyist',
#   'Amerindian',
#   'Arawak',
#   'Carib',
#   'Indian',
#   'Aleut',
#   'Algonquian',
#   'Abnaki',
#   'Algonkian',
#   'Arapaho',
#   'Blackfoot',
#   'Cheyenne',
#   'Conoy',
#   'Cree',
#   'Delaware',
#   'Fox',
#   'Illinois',
#   'Kickapoo',
#   'Malecite',
#   'Massachuset',
#   'Menomini',
#   'Miami',
#   'Micmac',
#   'Mohican',
#   'Nanticoke',
#   'Ojibwa',
#   'Ottawa',
#   'Pamlico',
#   'Passamaquody',
#   'Penobscot',
#   'Potawatomi',
#   'Powhatan',
#   'Sauk',
#   'Shawnee',
#   'Wampanoag',
#   'Anasazi',
#   'Athapaskan',
#   'Apache',
#   'Chipewyan',
#   'Hupa',
#   'Mattole',
#   'Navaho',
#   'Chickasaw',
#   'Creek',
#   'brooklet',
#   'Eskimo',
#   'Haida',
#   'Hokan',
#   'Chimariko',
#   'Esselen',
#   'Kulanapan',
#   'Pomo',
#   'Quoratean',
#   'Karok',
#   'Shastan',
#   'Achomawi',
#   'Atsugewi',
#   'Shasta',
#   'Yanan',
#   'Yahi',
#   'Yana',
#   'Yuman',
#   "Akwa'ala",
#   'Cochimi',
#   'Cocopa',
#   'Diegueno',
#   'Havasupai',
#   'Kamia',
#   'Kiliwa',
#   'Maricopa',
#   'Mohave',
#   'Walapai',
#   'Yavapai',
#   'Yuma',
#   'Iroquois',
#   'Cayuga',
#   'Cherokee',
#   'Erie',
#   'Mohawk',
#   'Oneida',
#   'Onondaga',
#   'Seneca',
#   'Tuscarora',
#   'Mayan',
#   'Cakchiquel',
#   'Kekchi',
#   'Mam',
#   'Quiche',
#   'Yucatec',
#   'Muskhogean',
#   'Alabama',
#   'Choctaw',
#   'Hitchiti',
#   'Koasati',
#   'Muskogee',
#   'Seminole',
#   'Nahuatl',
#   'Aztec',
#   'Toltec',
#   'Olmec',
#   'Penutian',
#   'Chinookan',
#   'Copehan',
#   'Patwin',
#   'Wintun',
#   'Costanoan',
#   'Kalapooian',
#   'Kusan',
#   'Mariposan',
#   'Moquelumnan',
#   'Pujunan',
#   'Shahaptian',
#   'Takilman',
#   'Tsimshian',
#   'Pueblo',
#   'Hopi',
#   'Taos',
#   'Zuni',
#   'Redskin',
#   'Salish',
#   'Skagit',
#   'sannup',
#   'Shoshone',
#   'Comanche',
#   'squaw',
#   'Taracahitian',
#   'Cahita',
#   'Tarahumara',
#   'Tlingit',
#   'Wakashan',
#   'Kwakiutl',
#   'Nootka',
#   'Zapotec',
#   'Guarani',
#   'Maraco',
#   'Quechua',
#   'Inca',
#   'Tupi',
#   'ancient',
#   'anomaly',
#   'ablepharia',
#   'albinism',
#   'amelia',
#   'ametria',
#   'anencephaly',
#   'clinocephaly',
#   'clinodactyly',
#   'dichromacy',
#   'deuteranopia',
#   'protanopia',
#   'tetartanopia',
#   'tritanopia',
#   'monochromacy',
#   'encephalocele',
#   'epispadias',
#   'hermaphroditism',
#   'macroglossia',
#   'meningocele',
#   'meromelia',
#   'adactylia',
#   'phocomelia',
#   'mongolism',
#   'myelomeningocele',
#   'oxycephaly',
#   'plagiocephaly',
#   'polydactyly',
#   'polysomy',
#   'pseudohermaphroditism',
#   'scaphocephaly',
#   'syndactyly',
#   'anti',
#   'applicant',
#   'aspirant',
#   'bidder',
#   'claimant',
#   'Pretender',
#   'material',
#   'abrasive',
#   'carborundum',
#   'binder',
#   'birdlime',
#   'cement',
#   'paste',
#   'aggregate',
#   'ammunition',
#   'belt',
#   'band',
#   'clique',
#   'bohemia',
#   'cabal',
#   'faction',
#   'galere',
#   'loop',
#   'mafia',
#   'cohort',
#   'conspiracy',
#   'party',
#   'Gironde',
#   'Kuomintang',
#   'Opposition',
#   'lockout',
#   'reaction',
#   'decomposition',
#   'displacement',
#   'hydrolysis',
#   'neutralization',
#   'oxidation',
#   'calcination',
#   'combustion',
#   'deflagration',
#   'fire',
#   'backfire',
#   'backblast',
#   'bonfire',
#   'campfire',
#   'conflagration',
#   'wildfire',
#   'grassfire',
#   'smoulder',
#   'smudge',
#   'nitrification',
#   'rust',
#   'reduction',
#   'amortization',
#   'contraction',
#   'contracture',
#   'tetanus',
#   'vaginismus',
#   'cut',
#   'cutback',
#   'declassification',
#   'deflation',
#   'depletion',
#   'consumption',
#   'drinking',
#   'gulping',
#   'potation',
#   'quaff',
#   'eating',
#   'bite',
#   'snakebite',
#   'browse',
#   'coprophagy',
#   'dining',
#   'engorgement',
#   'feasting',
#   'graze',
#   'lunching',
#   'mycophagy',
#   'necrophagia',
#   'omophagia',
#   'repletion',
#   'scatophagy',
#   'supping',
#   'tasting',
#   'sucking',
#   'swallow',
#   'drain',
#   'exhaustion',
#   'frazzle',
#   'inanition',
#   'depreciation',
#   'devaluation',
#   'devitalization',
#   'discount',
#   'easing',
#   'disembarrassment',
#   'extenuation',
#   'lowering',
#   'tapering',
#   'minimization',
#   'moderation',
#   'reasonableness',
#   'rollback',
#   'shortening',
#   'shrinking',
#   'compression',
#   'subtraction',
#   'weakening',
#   'atrophy',
#   'amyotrophia',
#   'kraurosis',
#   'tabes',
#   'attenuation',
#   'debilitation',
#   'fall',
#   'relaxation',
#   'saponification',
#   'carousel',
#   'track',
#   'round',
#   'steps',
#   'ladder',
#   'swath',
#   'trail',
#   'slot',
#   'spoor',
#   'cartridge',
#   'blank',
#   'cartouche',
#   'butterfat',
#   'blubber',
#   'ambergris',
#   'horsehair',
#   'silk',
#   'sarcenet',
#   'wool',
#   'fur',
#   'astrakhan',
#   'bearskin',
#   'beaver',
#   'chinchilla',
#   'ermine',
#   'fox',
#   'lambskin',
#   'broadtail',
#   'lapin',
#   'leopard',
#   'mink',
#   'muskrat',
#   'otter',
#   'raccoon',
#   'sable',
#   'rigger',
#   'seal',
#   'squirrel',
#   'taguan',
#   'baronduki',
#   'chipmunk',
#   'chickeree',
#   'hide',
#   'cowhide',
#   'goatskin',
#   'rawhide',
#   'leather',
#   'alligator',
#   'buckskin',
#   'buff',
#   'aerophile',
#   'calf',
#   'dogie',
#   'maverick',
#   'chamois',
#   'cordovan',
#   'parchment',
#   'beeswax',
#   'lac',
#   'shellac',
#   'bone',
#   'anklebone',
#   'calvaria',
#   'capitate',
#   'hamate',
#   'pisiform',
#   'trapezium',
#   'trapezoid',
#   'triquetral',
#   'centrum',
#   'cheekbone',
#   'clavicle',
#   'coccyx',
#   'cranium',
#   'dentine',
#   'ivory',
#   'ethmoid',
#   'fishbone',
#   'furcula',
#   'wishbone',
#   'gladiolus',
#   'heelbone',
#   'hipbone',
#   'hyoid',
#   'ilium',
#   'ischium',
#   'jaw',
#   'chop',
#   'humerus',
#   'radius',
#   'semidiameter',
#   'ulna',
#   'diaphysis',
#   'epiphysis',
#   'femur',
#   'fibula',
#   'tibia',
#   'manubrium',
#   'marrowbone',
#   'metacarpal',
#   'metatarsal',
#   'modiolus',
#   'nasal',
#   'occiput',
#   'ossicle',
#   'incus',
#   'malleus',
#   'stapes',
#   'palatine',
#   'pastern',
#   'phalanx',
#   'pubis',
#   'ramus',
#   'rib',
#   'sacrum',
#   'scapula',
#   'patella',
#   'sinciput',
#   'skull',
#   'sternum',
#   'tarsal',
#   'tooth',
#   'canine',
#   'fang',
#   'chopper',
#   'conodont',
#   'vertebra',
#   'atlas',
#   'axis',
#   'vomer',
#   'zygoma',
#   'atom',
#   'deuterium',
#   'isotope',
#   'monad',
#   'ballast',
#   'bimetal',
#   'builder',
#   'chemical',
#   'Alar',
#   'bactericide',
#   'carrier',
#   'compound',
#   'congener',
#   'explosive',
#   'fertilizer',
#   'organic',
#   'bonemeal',
#   'guano',
#   'manure',
#   'flux',
#   'fraction',
#   'fumigant',
#   'herbicide',
#   'atrazine',
#   'linuron',
#   'paraquat',
#   'silvex',
#   'simazine',
#   'intermediate',
#   'larvicide',
#   'pesticide',
#   'acaricide',
#   'arsenical',
#   'insecticide',
#   'dichlorodiphenyltrichloroethane',
#   'larvacide',
#   'lindane',
#   'Kwell',
#   'Malathion',
#   'organophosphate',
#   'chlorpyrifos',
#   'parathion',
#   'pyrethrum',
#   'rotenone',
#   'pediculicide',
#   'phosphine',
#   'scabicide',
#   ...],
#  'color': ['black',
#   'gray',
#   'charcoal',
#   'white',
#   'Aryan',
#   'Circassian',
#   'Abkhaz',
#   'Elamite',
#   'Kassite',
#   'paleface',
#   'Semite',
#   'Arab',
#   'Bahraini',
#   'Bedouin',
#   'Omani',
#   'Palestinian',
#   'Qatari',
#   'Saracen',
#   'Saudi',
#   'Yemeni',
#   'Aramean',
#   'Assyrian',
#   'Babylonian',
#   'Sumerian',
#   'Canaanite',
#   'Chaldean',
#   'Phoenician',
#   'WASP',
#   'whitey',
#   'blond',
#   'towhead',
#   'blue',
#   'azure',
#   'ultramarine',
#   'brown',
#   'chestnut',
#   'chocolate',
#   'hazel',
#   'beige',
#   'dun',
#   'tan',
#   'mocha',
#   'puce',
#   'copper',
#   'taupe',
#   'green',
#   'cyan',
#   'emerald',
#   'greenishness',
#   'olive',
#   'orange',
#   'pastel',
#   'pink',
#   'carnation',
#   'coral',
#   'pinkness',
#   'rose',
#   'multiflora',
#   'sweetbrier',
#   'solferino',
#   'purple',
#   'lavender',
#   'mauve',
#   'violet',
#   'red',
#   'cardinal',
#   'dean',
#   'cerise',
#   'crimson',
#   'burgundy',
#   'claret',
#   'wine',
#   'Bordeaux',
#   'Burgundy',
#   'Dubonnet',
#   'Madeira',
#   'Marsala',
#   'muscat',
#   'port',
#   'entrepot',
#   'outport',
#   'seaport',
#   'sherry',
#   'Amontillado',
#   'Manzanilla',
#   'generic',
#   'macon',
#   'bishop',
#   'archbishop',
#   'metropolitan',
#   'negus',
#   'plonk',
#   'Beaujolais',
#   'Cabernet',
#   'Chianti',
#   'retsina',
#   'champagne',
#   'Tokay',
#   'varietal',
#   'vermouth',
#   'vintage',
#   'Chablis',
#   'Chardonnay',
#   'Montrachet',
#   'Moselle',
#   'Muscadet',
#   'liebfraumilch',
#   'Riesling',
#   'sack',
#   'Sauterne',
#   'Soave',
#   'Verdicchio',
#   'Vouvray',
#   'Yquem',
#   'fuschia',
#   'magenta',
#   'maroon',
#   'sanguine',
#   'scarlet',
#   'salmon',
#   'blackfish',
#   'chinook',
#   'coho',
#   'redfish',
#   'sockeye',
#   'yellow',
#   'amber',
#   'gamboge',
#   'ocher',
#   'coloration',
#   'complexion',
#   'darkness',
#   'blackout',
#   'night',
#   'weeknight',
#   'semidarkness',
#   'cloudiness',
#   'dimness',
#   'gloom',
#   'obscurity',
#   'shade',
#   'shadow',
#   'penumbra',
#   'umbra',
#   'lividness',
#   'paleness',
#   'ruddiness',
#   'sallowness',
#   'tawniness',
#   'whiteness',
#   'alabaster',
#   'bleach',
#   'bone',
#   'anklebone',
#   'calvaria',
#   'capitate',
#   'hamate',
#   'pisiform',
#   'trapezium',
#   'trapezoid',
#   'triquetral',
#   'centrum',
#   'cheekbone',
#   'clavicle',
#   'coccyx',
#   'cranium',
#   'dentine',
#   'ivory',
#   'ethmoid',
#   'fishbone',
#   'furcula',
#   'wishbone',
#   'gladiolus',
#   'heelbone',
#   'hipbone',
#   'hyoid',
#   'ilium',
#   'ischium',
#   'jaw',
#   'chop',
#   'humerus',
#   'radius',
#   'semidiameter',
#   'ulna',
#   'diaphysis',
#   'epiphysis',
#   'femur',
#   'fibula',
#   'tibia',
#   'manubrium',
#   'marrowbone',
#   'metacarpal',
#   'metatarsal',
#   'modiolus',
#   'nasal',
#   'occiput',
#   'ossicle',
#   'incus',
#   'malleus',
#   'stapes',
#   'palatine',
#   'pastern',
#   'phalanx',
#   'pubis',
#   'ramus',
#   'rib',
#   'sacrum',
#   'scapula',
#   'patella',
#   'sinciput',
#   'skull',
#   'sternum',
#   'tarsal',
#   'tooth',
#   'canine',
#   'fang',
#   'chopper',
#   'conodont',
#   'vertebra',
#   'atlas',
#   'axis',
#   'vomer',
#   'zygoma',
#   'chalk',
#   'frostiness',
#   'mottle'],
#  'food': ['beverage',
#   'alcohol',
#   'aperitif',
#   'brew',
#   'beer',
#   'ale',
#   'bitter',
#   'Burton',
#   'porter',
#   'redcap',
#   'skycap',
#   'stout',
#   'Guinness',
#   'Weissbier',
#   'Weizenbier',
#   'Weizenbock',
#   'lager',
#   'suds',
#   'cassiri',
#   'kvass',
#   'mead',
#   'hooch',
#   'pruno',
#   'kava',
#   'koumiss',
#   'liqueur',
#   'absinth',
#   'amaretto',
#   'anisette',
#   'benedictine',
#   'Chartreuse',
#   'Kahlua',
#   'Drambuie',
#   'Galliano',
#   'kummel',
#   'maraschino',
#   'curacao',
#   'pastis',
#   'Pernod',
#   'ratafia',
#   'sambuca',
#   'liquor',
#   'aquavit',
#   'arrack',
#   'bitters',
#   'brandy',
#   'applejack',
#   'Armagnac',
#   'Calvados',
#   'Cognac',
#   'grappa',
#   'kirsch',
#   'marc',
#   'slivovitz',
#   'firewater',
#   'gin',
#   'geneva',
#   'lacing',
#   'mescal',
#   'ouzo',
#   'rum',
#   'demerara',
#   'grog',
#   'schnapps',
#   'tequila',
#   'vodka',
#   'whiskey',
#   'bourbon',
#   'moonshine',
#   'Irish',
#   'rye',
#   'Scotch',
#   'cocktail',
#   'bullshot',
#   'daiquiri',
#   'gimlet',
#   'grasshopper',
#   'katydid',
#   'locust',
#   'manhattan',
#   'margarita',
#   'martini',
#   'Sazerac',
#   'screwdriver',
#   'sidecar',
#   'sour',
#   'stinger',
#   'flip',
#   'reconsideration',
#   'highball',
#   'cobbler',
#   'bootmaker',
#   'collins',
#   'julep',
#   'sling',
#   'zombie',
#   'mimosa',
#   'punch',
#   'counterpunch',
#   'haymaker',
#   'hook',
#   'jab',
#   'rickey',
#   'spritzer',
#   'swizzle',
#   'nipa',
#   'perry',
#   'pulque',
#   'rotgut',
#   'sake',
#   'behalf',
#   'slug',
#   'dumdum',
#   'wine',
#   'Bordeaux',
#   'Burgundy',
#   'Dubonnet',
#   'Madeira',
#   'Marsala',
#   'muscat',
#   'port',
#   'entrepot',
#   'outport',
#   'seaport',
#   'sherry',
#   'Amontillado',
#   'Manzanilla',
#   'generic',
#   'macon',
#   'bishop',
#   'archbishop',
#   'metropolitan',
#   'cardinal',
#   'dean',
#   'diocesan',
#   'eparch',
#   'exarch',
#   'negus',
#   'plonk',
#   'Beaujolais',
#   'Cabernet',
#   'Chianti',
#   'claret',
#   'Medoc',
#   'Merlot',
#   'Rioja',
#   'zinfandel',
#   'retsina',
#   'champagne',
#   'Tokay',
#   'varietal',
#   'vermouth',
#   'vintage',
#   'Chablis',
#   'Chardonnay',
#   'Montrachet',
#   'Moselle',
#   'Muscadet',
#   'liebfraumilch',
#   'Riesling',
#   'sack',
#   'Sauterne',
#   'Soave',
#   'Verdicchio',
#   'Vouvray',
#   'Yquem',
#   'cider',
#   'cocoa',
#   'coffee',
#   'cappuccino',
#   'chicory',
#   'Postum',
#   'espresso',
#   'mocha',
#   'cooler',
#   'seltzer',
#   'fizz',
#   'lemonade',
#   'limeade',
#   'orangeade',
#   'must',
#   'nectar',
#   'hydromel',
#   'mate',
#   'milk',
#   'buttermilk',
#   'mixer',
#   'oenomel',
#   'potion',
#   'elixir',
#   'philter',
#   'refresher',
#   'smoothie',
#   'cola',
#   'phosphate',
#   'pop',
#   'sarsaparilla',
#   'tonic',
#   'tea',
#   'cuppa',
#   'tisane',
#   'chyme',
#   'comestible',
#   'tuck',
#   'commissariat',
#   'larder',
#   'agar',
#   'fare',
#   'feed',
#   'cud',
#   'fodder',
#   'mash',
#   'mast',
#   'foremast',
#   'jiggermast',
#   'mainmast',
#   'mizzenmast',
#   'topmast',
#   'topgallant',
#   'petfood',
#   'silage',
#   'slop',
#   'foodstuff',
#   'greengrocery',
#   'micronutrient',
#   'nutriment',
#   'course',
#   'propaedeutic',
#   'seminar',
#   'workshop',
#   'bindery',
#   'bookbindery',
#   'brickyard',
#   'pottery',
#   'agateware',
#   'lusterware',
#   'Wedgwood',
#   'saddlery',
#   'bit',
#   'caparison',
#   'bard',
#   'horsecloth',
#   'cinch',
#   'doddle',
#   'hame',
#   'harness',
#   'headgear',
#   'cap',
#   'balaclava',
#   'Balmoral',
#   'beret',
#   'biggin',
#   'biretta',
#   'calpac',
#   'cockscomb',
#   'fez',
#   'Glengarry',
#   'kalansuwa',
#   'kepi',
#   'mobcap',
#   'mortarboard',
#   'nightcap',
#   'pinner',
#   'skullcap',
#   'beanie',
#   'coif',
#   'Afro',
#   'bang',
#   'beehive',
#   'bob',
#   'bouffant',
#   'braid',
#   'pigtail',
#   'queue',
#   'breadline',
#   'chignon',
#   'haircut',
#   'mohawk',
#   'marcel',
#   'pageboy',
#   'pompadour',
#   'ponytail',
#   'roach',
#   'thatch',
#   'wave',
#   'billow',
#   'comber',
#   'lift',
#   'ripple',
#   'roller',
#   'surf',
#   'swash',
#   'swell',
#   'yarmulke',
#   'tam',
#   'hat',
#   'bearskin',
#   'boater',
#   'bonnet',
#   'sunbonnet',
#   'bicorn',
#   'tricorn',
#   'deerstalker',
#   'fedora',
#   'beaver',
#   'millinery',
#   'porkpie',
#   'sombrero',
#   "sou'wester",
#   'sunhat',
#   'titfer',
#   'toque',
#   'tyrolean',
#   'helmet',
#   'armet',
#   'basinet',
#   'casque',
#   'casquet',
#   'heaume',
#   'morion',
#   'pickelhaube',
#   'sallet',
#   'hood',
#   'bully',
#   'bullyboy',
#   'muscleman',
#   'skinhead',
#   'Ted',
#   'crown',
#   'tiara',
#   'kaffiyeh',
#   'miter',
#   'topknot',
#   'turban',
#   'wimple',
#   'martingale',
#   'apishamore',
#   'yoke',
#   'tucker',
#   'turnery',
#   'dainty',
#   'ambrosia',
#   'gelatin',
#   'marrow',
#   'savory',
#   'sweet',
#   'dish',
#   'bowl',
#   'fishbowl',
#   'jorum',
#   'mazer',
#   'casserole',
#   'coquille',
#   'argyll',
#   'ramekin',
#   'tureen',
#   'ingesta',
#   'kosher',
#   'meal',
#   'banquet',
#   'gaudy',
#   'bite',
#   'snakebite',
#   'breakfast',
#   'brunch',
#   'buffet',
#   'credenza',
#   'minibar',
#   'dinner',
#   'lunch',
#   'mess',
#   'picnic',
#   'potluck',
#   'refection',
#   'supper',
#   'Seder',
#   'water',
#   'bilge',
#   'dishwater',
#   'condensate',
#   'rain',
#   'downpour',
#   'drizzle',
#   'monsoon',
#   'rainstorm',
#   'thundershower',
#   'shower',
#   'limewater',
#   'meltwater',
#   'seawater',
#   'slush',
#   'yolk'],
#  'relative': ['agnate',
#   'ancestor',
#   'ancestress',
#   'forebear',
#   'grandparent',
#   'grandfather',
#   'grandma',
#   'nan',
#   'forefather',
#   'patriarch',
#   'foremother',
#   'progenitor',
#   'genitor',
#   'parent',
#   'father',
#   'dad',
#   'codger',
#   'pater',
#   'filicide',
#   'mother',
#   'ma',
#   'mater',
#   'primipara',
#   'puerpera',
#   'quadripara',
#   'quintipara',
#   'supermom',
#   'stepparent',
#   'stepfather',
#   'stepmother',
#   'cousin',
#   'descendant',
#   'child',
#   'bairn',
#   'buster',
#   'changeling',
#   'mongoloid',
#   'imp',
#   'leprechaun',
#   'sandman',
#   'kiddy',
#   'orphan',
#   'peanut',
#   'pickaninny',
#   'preschooler',
#   'silly',
#   'sprog',
#   'toddler',
#   'urchin',
#   'ragamuffin',
#   'gamine',
#   'waif',
#   'scion',
#   'enate',
#   'kin',
#   'affine',
#   'kinsman',
#   'brother',
#   'stepbrother',
#   'nephew',
#   'uncle',
#   'kinswoman',
#   'aunt',
#   'sister',
#   'niece',
#   'offspring',
#   'baby',
#   'cherub',
#   'foundling',
#   'godchild',
#   'goddaughter',
#   'godson',
#   'neonate',
#   'nursling',
#   'papoose',
#   'bastard',
#   'sibling',
#   'quadruplet',
#   'quintuplet',
#   'triplet',
#   'twin',
#   'spouse',
#   'bigamist',
#   'consort',
#   'helpmate',
#   'husband',
#   'benedick',
#   'cuckold',
#   'wittol',
#   'uxoricide',
#   'monogamist',
#   'newlywed',
#   'bride',
#   'groom',
#   'polygamist',
#   'polyandrist',
#   'polygynist',
#   'wife',
#   'poleax',
#   'housewife',
#   'marchioness',
#   'matron',
#   'mayoress',
#   'missus',
#   'sheika',
#   'signora',
#   'uxor',
#   'vicereine',
#   'viscountess'],
#  'shape': ['angularity',
#   'fold',
#   'kink',
#   'pleat',
#   'tuck',
#   'pucker',
#   'furcation',
#   'bifurcation',
#   'jog',
#   'zigzag',
#   'concavity',
#   'bowl',
#   'fishbowl',
#   'jorum',
#   'mazer',
#   'cup',
#   'beaker',
#   'chalice',
#   'demitasse',
#   'kylix',
#   'scyphus',
#   'teacup',
#   'depression',
#   'blues',
#   'boogie',
#   'dejection',
#   'funk',
#   'dumps',
#   'melancholia',
#   'melancholy',
#   'gloom',
#   'heavyheartedness',
#   'pensiveness',
#   'dome',
#   'indentation',
#   'cleft',
#   'notch',
#   'incisure',
#   'pit',
#   'divot',
#   'quicksand',
#   'sandpit',
#   'sawpit',
#   'recess',
#   'scoop',
#   'convexity',
#   'roundedness',
#   'oblateness',
#   'crookedness',
#   'curvature',
#   'dullness',
#   'oscitancy',
#   'lobularity',
#   'narrowing',
#   'coarctation',
#   'constriction',
#   'taper',
#   'roundness',
#   'sharpness',
#   'straightness',
#   'stratification',
#   'topography'],
#  'toy': ['ball',
#   'baseball',
#   'basketball',
#   'bowl',
#   'fishbowl',
#   'jorum',
#   'mazer',
#   'football',
#   'rugby',
#   'soccer',
#   'handball',
#   'jack',
#   'marble',
#   'racquetball',
#   'softball',
#   'volleyball',
#   'Wiffle',
#   'balloon',
#   'cockhorse',
#   'doll',
#   'golliwog',
#   'kachina',
#   'puppet',
#   'dollhouse',
#   'Frisbee',
#   'hobby',
#   'speleology',
#   'kaleidoscope',
#   'kite',
#   'Lego',
#   'Meccano',
#   'pinata',
#   'pinwheel',
#   'playhouse',
#   'popgun',
#   'rattle',
#   'sandbox',
#   'seesaw',
#   'slide',
#   'slingshot',
#   'swing',
#   'teddy',
#   'top',
#   'capital',
#   'stock',
#   'float',
#   'crown'],
#  'beverage': ['alcohol',
#   'aperitif',
#   'brew',
#   'beer',
#   'ale',
#   'bitter',
#   'Burton',
#   'porter',
#   'redcap',
#   'skycap',
#   'stout',
#   'Guinness',
#   'Weissbier',
#   'Weizenbier',
#   'Weizenbock',
#   'lager',
#   'suds',
#   'cassiri',
#   'kvass',
#   'mead',
#   'hooch',
#   'pruno',
#   'kava',
#   'koumiss',
#   'liqueur',
#   'absinth',
#   'amaretto',
#   'anisette',
#   'benedictine',
#   'Chartreuse',
#   'Kahlua',
#   'Drambuie',
#   'Galliano',
#   'kummel',
#   'maraschino',
#   'curacao',
#   'pastis',
#   'Pernod',
#   'ratafia',
#   'sambuca',
#   'liquor',
#   'aquavit',
#   'arrack',
#   'bitters',
#   'brandy',
#   'applejack',
#   'Armagnac',
#   'Calvados',
#   'Cognac',
#   'grappa',
#   'kirsch',
#   'marc',
#   'slivovitz',
#   'firewater',
#   'gin',
#   'geneva',
#   'lacing',
#   'mescal',
#   'ouzo',
#   'rum',
#   'demerara',
#   'grog',
#   'schnapps',
#   'tequila',
#   'vodka',
#   'whiskey',
#   'bourbon',
#   'moonshine',
#   'Irish',
#   'rye',
#   'Scotch',
#   'cocktail',
#   'bullshot',
#   'daiquiri',
#   'gimlet',
#   'grasshopper',
#   'katydid',
#   'locust',
#   'manhattan',
#   'margarita',
#   'martini',
#   'Sazerac',
#   'screwdriver',
#   'sidecar',
#   'sour',
#   'stinger',
#   'flip',
#   'reconsideration',
#   'highball',
#   'cobbler',
#   'bootmaker',
#   'collins',
#   'julep',
#   'sling',
#   'zombie',
#   'mimosa',
#   'punch',
#   'counterpunch',
#   'haymaker',
#   'hook',
#   'jab',
#   'rickey',
#   'spritzer',
#   'swizzle',
#   'nipa',
#   'perry',
#   'pulque',
#   'rotgut',
#   'sake',
#   'behalf',
#   'slug',
#   'dumdum',
#   'wine',
#   'Bordeaux',
#   'Burgundy',
#   'Dubonnet',
#   'Madeira',
#   'Marsala',
#   'muscat',
#   'port',
#   'entrepot',
#   'outport',
#   'seaport',
#   'sherry',
#   'Amontillado',
#   'Manzanilla',
#   'generic',
#   'macon',
#   'bishop',
#   'archbishop',
#   'metropolitan',
#   'cardinal',
#   'dean',
#   'diocesan',
#   'eparch',
#   'exarch',
#   'negus',
#   'plonk',
#   'Beaujolais',
#   'Cabernet',
#   'Chianti',
#   'claret',
#   'Medoc',
#   'Merlot',
#   'Rioja',
#   'zinfandel',
#   'retsina',
#   'champagne',
#   'Tokay',
#   'varietal',
#   'vermouth',
#   'vintage',
#   'Chablis',
#   'Chardonnay',
#   'Montrachet',
#   'Moselle',
#   'Muscadet',
#   'liebfraumilch',
#   'Riesling',
#   'sack',
#   'Sauterne',
#   'Soave',
#   'Verdicchio',
#   'Vouvray',
#   'Yquem',
#   'cider',
#   'cocoa',
#   'coffee',
#   'cappuccino',
#   'chicory',
#   'Postum',
#   'espresso',
#   'mocha',
#   'cooler',
#   'seltzer',
#   'fizz',
#   'lemonade',
#   'limeade',
#   'orangeade',
#   'must',
#   'nectar',
#   'hydromel',
#   'mate',
#   'milk',
#   'buttermilk',
#   'mixer',
#   'oenomel',
#   'potion',
#   'elixir',
#   'philter',
#   'refresher',
#   'smoothie',
#   'cola',
#   'phosphate',
#   'pop',
#   'sarsaparilla',
#   'tonic',
#   'tea',
#   'cuppa',
#   'tisane'],
#  'bird': ['hummingbird',
#   'thornbill',
#   'swift',
#   'gallinule',
#   'moorhen',
#   'seabird',
#   'auk',
#   'auklet',
#   'guillemot',
#   'murre',
#   'razorbill',
#   'jaeger',
#   'skua',
#   'larid',
#   'gull',
#   'tern',
#   'skimmer',
#   'loon',
#   'albatross',
#   'petrel',
#   'fulmar',
#   'shearwater',
#   'cormorant',
#   'gannet',
#   'booby',
#   'solan',
#   'pelican',
#   'snakebird',
#   'grebe',
#   'dabchick',
#   'puffin',
#   'penguin',
#   'Adelie',
#   'swan',
#   'cob',
#   'coscoroba',
#   'cygnet',
#   'pen',
#   'ballpoint',
#   'quill',
#   'Sharpie',
#   'goffer',
#   'trumpeter',
#   'bugler',
#   'whooper',
#   'bustard',
#   'chunga',
#   'courlan',
#   'crane',
#   'flamingo',
#   'heron',
#   'ibis',
#   'limpkin',
#   'ortygan',
#   'rail',
#   'bar',
#   'barrelhouse',
#   'speakeasy',
#   'taffrail',
#   'shoebill',
#   'shorebird',
#   'avocet',
#   'courser',
#   'curlew',
#   'godwit',
#   'oystercatcher',
#   'phalarope',
#   'plover',
#   'dotterel',
#   'killdeer',
#   'lapwing',
#   'turnstone',
#   'pratincole',
#   'sandpiper',
#   'greenshank',
#   'knot',
#   'redshank',
#   'ruff',
#   'sanderling',
#   'tattler',
#   'yellowlegs',
#   'snipe',
#   'dowitcher',
#   'greyback',
#   'jacksnipe',
#   'stilt',
#   'spoonbill',
#   'stork',
#   'jabiru',
#   'marabou',
#   'openbill',
#   'saddlebill',
#   'waterfowl',
#   'duck',
#   'bufflehead',
#   'canvasback',
#   'drake',
#   'duckling',
#   'goldeneye',
#   'mallard',
#   'pintail',
#   'pochard',
#   'redhead',
#   'scaup',
#   'eider',
#   'merganser',
#   'goosander',
#   'smew',
#   'scoter',
#   'sheldrake',
#   'shoveler',
#   'teal',
#   'cyan',
#   'widgeon',
#   'goose',
#   'brant',
#   'gander',
#   'gosling',
#   'greylag',
#   'honker',
#   'screamer',
#   'crier',
#   'bawler',
#   'blubberer',
#   'archaeopteryx',
#   'archaeornis',
#   'nomad',
#   'Bedouin',
#   'Bushman',
#   'Hun',
#   'Saracen',
#   'Scythian',
#   'vagrant',
#   'beachcomber',
#   'sundowner',
#   'tramp',
#   'dosser',
#   'Accipitriformes',
#   'eagle',
#   'eaglet',
#   'ringtail',
#   'harpy',
#   'hawk',
#   'buteonine',
#   'buzzard',
#   'eyas',
#   'falcon',
#   'caracara',
#   'carancha',
#   'gyrfalcon',
#   'hobby',
#   'speleology',
#   'kestrel',
#   'peregrine',
#   'goshawk',
#   'harrier',
#   'kite',
#   'osprey',
#   'redtail',
#   'owl',
#   'owlet',
#   'vulture',
#   'Aegypiidae',
#   'frogmouth',
#   'goatsucker',
#   'nighthawk',
#   'poorwill',
#   'whippoorwill',
#   'oilbird',
#   'carinate',
#   'cock',
#   'hoopoe',
#   'hornbill',
#   'kingfisher',
#   'kookaburra',
#   'motmot',
#   'roller',
#   'tody',
#   'cuckoo',
#   'touraco',
#   'dickeybird',
#   'chachalaca',
#   'dodo',
#   'pigeon',
#   'dove',
#   'turtledove',
#   'squab',
#   'sandgrouse',
#   'solitaire',
#   'curassow',
#   'bantam',
#   'chicken',
#   'broiler',
#   'capon',
#   'fryer',
#   'hen',
#   'cackler',
#   'layer',
#   'backing',
#   'blanket',
#   'afghan',
#   'mackinaw',
#   'manta',
#   'course',
#   'propaedeutic',
#   'seminar',
#   'workshop',
#   'bindery',
#   'bookbindery',
#   'brickyard',
#   'pottery',
#   'agateware',
#   'lusterware',
#   'Wedgwood',
#   'saddlery',
#   'bit',
#   'caparison',
#   'bard',
#   'horsecloth',
#   'cinch',
#   'doddle',
#   'hame',
#   'harness',
#   'headgear',
#   'cap',
#   'balaclava',
#   'Balmoral',
#   'beret',
#   'biggin',
#   'biretta',
#   'calpac',
#   'cockscomb',
#   'fez',
#   'Glengarry',
#   'kalansuwa',
#   'kepi',
#   'mobcap',
#   'mortarboard',
#   'nightcap',
#   'pinner',
#   'skullcap',
#   'beanie',
#   'coif',
#   'Afro',
#   'bang',
#   'beehive',
#   'bob',
#   'bouffant',
#   'braid',
#   'pigtail',
#   'queue',
#   'breadline',
#   'chignon',
#   'haircut',
#   'mohawk',
#   'marcel',
#   'pageboy',
#   'pompadour',
#   'ponytail',
#   'roach',
#   'thatch',
#   'wave',
#   'billow',
#   'comber',
#   'lift',
#   'ripple',
#   'yarmulke',
#   'tam',
#   'hat',
#   'bearskin',
#   'boater',
#   'bonnet',
#   'sunbonnet',
#   'bicorn',
#   'tricorn',
#   'deerstalker',
#   'fedora',
#   'beaver',
#   'millinery',
#   'porkpie',
#   'sombrero',
#   "sou'wester",
#   'sunhat',
#   'titfer',
#   'toque',
#   'tyrolean',
#   'helmet',
#   'armet',
#   'basinet',
#   'casque',
#   'casquet',
#   'heaume',
#   'morion',
#   'pickelhaube',
#   'sallet',
#   'hood',
#   'bully',
#   'bullyboy',
#   'muscleman',
#   'skinhead',
#   'Ted',
#   'crown',
#   'tiara',
#   'kaffiyeh',
#   'miter',
#   'topknot',
#   'turban',
#   'wimple',
#   'martingale',
#   'apishamore',
#   'yoke',
#   'tucker',
#   'turnery',
#   'cushion',
#   'interlayer',
#   'pullet',
#   'roaster',
#   'spatchcock',
#   'cochin',
#   'Cornish',
#   'Dorking',
#   'turkey',
#   'grouse',
#   'phasianid',
#   'partridge',
#   'pheasant',
#   'afropavo',
#   'argus',
#   'monal',
#   'peafowl',
#   'peachick',
#   'peacock',
#   'peahen',
#   'tragopan',
#   'quail',
#   'tinamou',
#   'guan',
#   'hoatzin',
#   'megapode',
#   'maleo'],
#  'building': ['abattoir',
#   'tenement',
#   'architecture',
#   'aviary',
#   'bathhouse',
#   'center',
#   'hub',
#   'midfield',
#   'midstream',
#   'seat',
#   'perch',
#   'roost',
#   'henroost',
#   'chapterhouse',
#   'clubhouse',
# ...
#   'halitosis',
#   'inhalation',
#   'gasp',
#   'puff',
#   'chinook',
#   'crosswind',
#   'doldrums',
#   'draft',
#   'acceptance',
#   'fatalism',
#   'recognition',
#   'check',
#   'giro',
#   'kite',
#   'overdraft',
#   'redraft',
#   'levanter',
#   'fohn',
#   'gale',
#   'gust',
#   'bluster',
#   'harmattan',
#   'headwind',
#   'khamsin',
#   'monsoon'],
#  'organ': ['muscle',
#   'agonist',
#   'antihero',
#   'antagonist',
#   'dueler',
#   'enemy',
#   'Luddite',
#   'withstander',
#   'levator',
#   'pronator',
#   'rectus',
#   'abdominal',
#   'abductor',
#   'crimp',
#   'kink',
#   'pleat',
#   'tuck',
#   'pucker',
#   'shanghaier',
#   'adductor',
#   'biceps',
#   'calf',
#   'dogie',
#   'maverick',
#   'deltoid',
#   'depressor',
#   'quadriceps',
#   'masseter',
#   'platysma',
#   'gastrocnemius',
#   'gluteus',
#   'intercostal',
#   'pectoral',
#   'peroneus',
#   'psoas',
#   'rhomboid',
#   'sartorius',
#   'scalenus',
#   'serratus',
#   'soleus',
#   'splenius',
#   'sternocleidomastoid',
#   'teres',
#   'tibialis',
#   'trapezius',
#   'triceps',
#   'myometrium',
#   'sphincter',
#   'supinator',
#   'tensor',
#   'ctene',
#   'effector',
#   'osmoreceptor',
#   'clitoris',
#   'penis',
#   'cock',
#   'micropenis',
#   'precordium',
#   'foot',
#   'flatfoot',
#   'gland',
#   'gonad',
#   'ovary',
#   'ovotestis',
#   'testis',
#   'cobblers',
#   'pituitary',
#   'breast',
#   'bosom',
#   'dug',
#   'udder',
#   'pancreas',
#   'kidney',
#   'heart',
#   'hindgut',
#   'intestine',
#   'colon',
#   'megacolon',
#   'duodenum',
#   'ileum',
#   'jejunum',
#   'liver',
#   'gill',
#   'lung',
#   'stomach',
#   'abomasum',
#   'craw',
#   'psalterium',
#   'reticulum',
#   'rumen',
#   'viscera',
#   'lens',
#   'anastigmat',
#   'condenser',
#   'electrolytic',
#   'trimmer',
#   'contact',
#   'brush',
#   'brake',
#   'airbrake',
#   'canebrake',
#   'spinney',
#   'underbrush',
#   'groundcover',
#   'pearlwort',
#   'rupturewort',
#   'whitlowwort',
#   'placement',
#   'alignment',
#   'Allies',
#   'columniation',
#   'composition',
#   'fenestration',
#   'formation',
#   'backfield',
#   'center',
#   'hub',
#   'midfield',
#   'midstream',
#   'seat',
#   'perch',
#   'roost',
#   'henroost',
#   'flank',
#   'flight',
#   'head',
#   'attic',
#   'cockloft',
#   'hayloft',
#   'bullethead',
#   'line',
#   'chorus',
#   'diagonal',
#   'linemen',
#   'lineup',
#   'rank',
#   'row',
#   'serration',
#   'terrace',
#   'suntrap',
#   'misalignment',
#   'proportion',
#   'content',
#   'percentage',
#   'rate',
#   'acceleration',
#   'pickup',
#   'technical',
#   'precipitation',
#   'birthrate',
#   'deathrate',
#   'deceleration',
#   'flow',
#   'airflow',
#   'backflow',
#   'regurgitation',
#   'current',
#   'juice',
#   'gravy',
#   'discharge',
#   'elves',
#   'jet',
#   'fanjet',
#   'jetliner',
#   'jumbojet',
#   'twinjet',
#   'lightning',
#   'thunderbolt',
#   'sprites',
#   'spike',
#   'explosion',
#   'airburst',
#   'backfire',
#   'backblast',
#   'blast',
#   'blowback',
#   'fragmentation',
#   'inflation',
#   'reflation',
#   'stagflation',
#   'drip',
#   'dripping',
#   'ebb',
#   'emission',
#   'flush',
#   'flux',
#   'fountain',
#   'freshet',
#   'overflow',
#   'effusion',
#   'cry',
#   'bellow',
#   'boo',
#   'catcall',
#   'clamor',
#   'halloo',
#   'hoot',
#   'hosanna',
#   'noise',
#   'bang',
#   'banging',
#   'bark',
#   'canella',
#   'cascara',
#   'cinchona',
#   'cinnamon',
#   'cork',
#   'magnolia',
#   'mezereum',
#   'phellem',
#   'tanbark',
#   'tapa',
#   'blare',
#   'boom',
#   'chatter',
#   'prate',
#   'scream',
#   'whoop',
#   'yelling',
#   'yodel',
#   'rush',
#   'dash',
#   'scamper',
#   'seepage',
#   'exudation',
#   'gum',
#   'latex',
#   'rubber',
#   'scale',
#   'index',
#   'ramification',
#   'bifurcation',
#   'divarication',
#   'fibrillation',
#   'trifurcation',
#   'spacing',
#   'tandem',
#   'sunglass',
#   'eyepiece',
#   'meniscus',
#   'monocle',
#   'objective',
#   'business',
#   'agency',
#   'police',
#   'Europol',
#   'gendarmerie',
#   "Mutawa'een",
#   'posse',
#   'Schutzstaffel',
#   'Gestapo',
#   'organ',
#   'brokerage',
#   'carrier',
#   'chain',
#   'catena',
#   'firm',
#   'corporation',
#   'conglomerate',
#   'dealer',
#   'barterer',
#   'bibliopole',
#   'cheesemonger',
#   'costermonger',
#   'cutler',
#   'draper',
#   'linendraper',
#   'fence',
#   'backstop',
#   'hedge',
#   'windbreak',
#   'fiberboard',
#   'Masonite',
#   'plasterboard',
#   'Sheetrock',
#   'wall',
#   'weir',
#   'fishmonger',
#   'ironmonger',
#   'mercer',
#   'seedsman',
#   'slopseller',
#   'stockjobber',
#   'publisher',
#   'magazine',
#   'pulp',
#   'slick',
#   'newspaper',
#   'daily',
#   'gazette',
#   'tabloid',
#   'franchise',
#   'manufacturer',
#   'armorer',
#   'bottler',
#   'partnership',
#   'copartnership',
#   'processor',
#   'shipbuilder',
#   'underperformer',
#   'grail',
#   'point',
#   'attractor',
#   'intercept',
#   'intersection',
#   'metacenter',
#   'vertex',
#   'thing',
#   'organelle',
#   'centriole',
#   'cilium',
#   'lysosome',
#   'mitochondrion',
#   'sarcosome',
#   'nucleolus',
#   'nucleus',
#   'pronucleus',
#   'ribosome',
#   'ovipositor',
#   'primordium',
#   'genitalia',
#   'cunt',
#   'minge',
#   'vulva',
#   'pudendum',
#   'nipple',
#   'baroreceptor',
#   'chemoreceptor',
#   'nose',
#   'beak',
#   'conk',
#   'proboscis',
#   'snout',
#   'tastebud',
#   'ear',
#   'exteroceptor',
#   'eye',
#   'peeper',
#   'ommatidium',
#   'interoceptor',
#   'thermoreceptor',
#   'siphon',
#   'articulator',
#   'speaker',
#   'alliterator',
#   'caller',
#   'chatterer',
#   'conversationalist',
#   'deipnosophist',
#   'interlocutor',
#   'dictator',
#   'drawler',
#   'driveller',
#   'ejaculator',
#   'growler',
#   'inquirer',
#   'examiner',
#   'inquisitor',
#   'interviewer',
#   'pollster',
#   'lecturer',
#   'lisper',
#   'mentioner',
#   'motormouth',
#   'mutterer',
#   'narrator',
#   'anecdotist',
#   'fabulist',
#   'griot',
#   'orator',
#   'elocutionist',
#   'eulogist',
#   'haranguer',
#   'spellbinder',
#   'prattler',
#   'ranter',
#   'reciter',
#   'stammerer',
#   'stentor',
#   'venter',
#   'vociferator',
#   'voicer',
#   'wailer',
#   'whisperer',
#   'witness',
#   'attester',
#   'testifier',
#   'subvocalizer',
#   'glottis',
#   'larynx',
#   'stinger',
#   'sucker',
#   'tongue',
#   'wing',
#   'ala',
#   'forewing',
#   'halter',
#   'pennon',
#   'pennoncel'],
#  'language': ['Antido',
#   'Arulo',
#   'Esperantido',
#   'Esperanto',
#   'Europan',
#   'Ido',
#   'Interlingua',
#   'Latinesce',
#   'Latino',
#   'spic',
#   'transmigrante',
#   'Lingualumina',
#   'Monario',
#   'Novial',
#   'Occidental',
#   'Optez',
#   'Pasigraphy',
#   'pidgin',
#   'ALGOL',
#   'FORTRAN',
#   'BASIC',
#   'C',
#   'STP',
#   'COBOL',
#   'LISP',
#   'Java',
#   'Pascal',
#   'Prolog',
#   'Ro',
#   'Romanal',
#   'Solresol',
#   'Volapuk',
#   'barrage',
#   'substrate',
#   'metalanguage',
#   'Afroasiatic',
#   'Berber',
#   'Almoravid',
#   'Riff',
#   'Chad',
#   'Cushitic',
#   'Somali',
#   'Egyptian',
#   'Cairene',
#   'Copt',
#   'Nubian',
#   'Theban',
#   'Hamitic',
#   'Omotic',
#   'Semitic',
#   'Akkadian',
#   'Amharic',
#   'Arabic',
#   'Aramaic',
#   'Mandaean',
#   'Canaanitic',
#   'Canaanite',
#   'Hebrew',
#   'Phoenician',
#   'Ugaritic',
#   'Maltese',
#   'Amerind',
#   'Algonquian',
#   'Abnaki',
#   'Algonkian',
#   'Arapaho',
#   'Blackfoot',
#   'Cheyenne',
#   'Conoy',
#   'Cree',
#   'Delaware',
#   'Fox',
#   'Illinois',
#   'Kickapoo',
#   'Malecite',
#   'Massachuset',
#   'Menomini',
#   'Miami',
#   'Micmac',
#   'Mohican',
#   'Nanticoke',
#   'Ojibwa',
#   'Ottawa',
#   'Pamlico',
#   'Passamaquody',
#   'Penobscot',
#   'Potawatomi',
#   'Powhatan',
#   'Sauk',
#   'Shawnee',
#   'Wampanoag',
#   'Arawak',
#   'Atakapa',
#   'Athapaskan',
#   'Apache',
#   'Chipewyan',
#   'Hupa',
#   'Mattole',
#   'Navaho',
#   'Caddo',
#   'Arikara',
#   'Eyeish',
#   'Kichai',
#   'Pawnee',
#   'Wichita',
#   'Carib',
#   'Hokan',
#   'Chimariko',
#   'Esselen',
#   'Kulanapan',
#   'Pomo',
#   'Quoratean',
#   'Karok',
#   'Shastan',
#   'Achomawi',
#   'Atsugewi',
#   'Shasta',
#   'Yanan',
#   'Yahi',
#   'Yana',
#   'Yuman',
#   "Akwa'ala",
#   'Cochimi',
#   'Cocopa',
#   'Diegueno',
#   'Havasupai',
#   'Kamia',
#   'Kiliwa',
#   'Maricopa',
#   'Mohave',
#   'Walapai',
#   'Yavapai',
#   'Yuma',
#   'Iroquoian',
#   'Cayuga',
#   'Cherokee',
#   'Mohawk',
#   'Oneida',
#   'Onondaga',
#   'Seneca',
#   'Tuscarora',
#   'Maraco',
#   'Maya',
#   'Cakchiquel',
#   'Kekchi',
#   'Mam',
#   'Quiche',
#   'Yucatec',
#   'Mosan',
#   'Chemakuan',
#   'Chemakum',
#   'Salish',
#   'Skagit',
#   'Wakashan',
#   'Kwakiutl',
#   'Nootka',
#   'Muskhogean',
#   'Alabama',
#   'Choctaw',
#   'Hitchiti',
#   'Koasati',
#   'Muskogee',
#   'Seminole',
#   'Haida',
#   'Tlingit',
#   'Penutian',
#   'Chinookan',
#   'Copehan',
#   'Patwin',
#   'Wintun',
#   'Costanoan',
#   'Kalapooian',
#   'Kusan',
#   'Mariposan',
#   'Moquelumnan',
#   'Pujunan',
#   'Shahaptian',
#   'Takilman',
#   'Tsimshian',
#   'Quechua',
#   'Inca',
#   'Siouan',
#   'Biloxi',
#   'Catawba',
#   'Crow',
#   'Dakota',
#   'Dhegiha',
#   'Kansa',
#   'Omaha',
#   'Osage',
#   'Ponca',
#   'Quapaw',
#   'Hidatsa',
#   'Iowa',
#   'Missouri',
#   'Ofo',
#   'Oto',
#   'Santee',
#   'Teton',
#   'Brule',
#   'Hunkpapa',
#   'Miniconju',
#   'Oglala',
#   'Sihasapa',
#   'Tutelo',
#   'Winnebago',
#   'Tanoan',
#   'Kiowa',
#   'Guarani',
#   'Tupi',
#   'Aztecan',
#   'Cahita',
#   'Nahuatl',
#   'Aztec',
#   'Toltec',
#   'Pima',
#   'Shoshonean',
#   'Comanche',
#   'Hopi',
#   'Paiute',
#   'Shoshone',
#   'Ute',
#   'Tatahumara',
#   'Zapotec',
#   'Khmer',
#   'Mon',
#   'Whitmonday',
#   'Vietnamese',
#   'Munda',
#   'Austronesian',
#   'Nauruan',
#   'Polynesian',
#   'Fijian',
#   'Samoan',
#   'Tahitian',
#   'Tongan',
#   'Basque',
#   'Caucasian',
#   'Aryan',
#   'Circassian',
#   'Abkhaz',
#   'Elamite',
#   'Kassite',
#   'paleface',
#   'Semite',
#   'Arab',
#   'Bahraini',
#   'Bedouin',
#   'Omani',
#   'Palestinian',
#   'Qatari',
#   'Saracen',
#   'Saudi',
#   'Yemeni',
#   'Aramean',
#   'Assyrian',
#   'Babylonian',
#   'Sumerian',
#   'WASP',
#   'whitey',
#   'Chukchi',
#   'creole',
#   'Dravidian',
#   'Badaga',
#   'Gadaba',
#   'Gond',
#   'Kanarese',
#   'Kolam',
#   'Kota',
#   'Kui',
#   'Malto',
#   'Savara',
#   'Tamil',
#   'Telugu',
#   'Toda',
#   'Tulu',
#   'Elamitic',
#   'Aleut',
#   'Eskimo',
#   'Hmong'],
#  'mineral': ['amblygonite',
#   'amphibole',
#   'actinolite',
#   'anthophyllite',
#   'asbestos',
#   'chrysotile',
#   'tremolite',
#   'hornblende',
#   'nephrite',
#   'apatite',
#   'fluorapatite',
#   'aragonite',
#   'argentite',
#   'argyrodite',
#   'arsenopyrite',
#   'asphalt',
#   'augite',
#   'baddeleyite',
#   'bastnasite',
#   'bauxite',
#   'beryl',
#   'aquamarine',
#   'emerald',
#   'morganite',
#   'borax',
#   'bornite',
#   'carnallite',
#   'cassiterite',
#   'celestite',
#   'cerussite',
#   'chalcocite',
#   'chalcopyrite',
#   'chlorite',
#   'chromite',
#   'chrysoberyl',
#   'alexandrite',
#   'cinnabar',
#   'cobaltite',
#   'cordierite',
#   'corundom',
#   'alumina',
#   'alundum',
#   'ruby',
#   'sapphire',
#   'cristobalite',
#   'crocolite',
#   'cryolite',
#   'cuprite',
#   'dolomite',
#   'ocher',
#   'sienna',
#   'copper',
#   'umber',
#   'emery',
#   'erythrite',
#   'fergusonite',
#   'fluorite',
#   'gadolinite',
#   'galena',
#   'garnet',
#   'almandite',
#   'andradite',
#   'demantoid',
#   'carbuncle',
#   'pyrope',
#   'rhodolite',
#   'garnierite',
#   'germanite',
#   'gibbsite',
#   'glauconite',
#   'greenockite',
#   'gypsum',
#   'alabaster',
#   'gesso',
#   'halite',
#   'hausmannite',
#   'hemimorphite',
#   'ilmenite',
#   'jadeite',
#   'kainite',
#   'kaolinite',
#   'kernite',
#   'kieserite',
#   'kyanite',
#   'langbeinite',
#   'magnesite',
#   'malachite',
#   'azurite',
#   'maltha',
#   'manganite',
#   'meerschaum',
#   'mica',
#   'biotite',
#   'lepidomelane',
#   'lepidolite',
#   'muscovite',
#   'damourite',
#   'paragonite',
#   'phlogopite',
#   'zinnwaldite',
#   'millerite',
#   'molybdenite',
#   'monazite',
#   'nepheline',
#   'nephelinite',
#   'niobite',
#   'nitrocalcite',
#   'olivenite',
#   'olivine',
#   'chrysolite',
#   'peridot',
#   'opal',
#   'ore',
#   'chamosite',
#   'goethite',
#   'hematite',
#   'lepidocrocite',
#   'limonite',
#   'magnetite',
#   'ruddle',
#   'siderite',
#   'taconite',
#   'massicot',
#   'carnotite',
#   'uraninite',
#   'orpiment',
#   'osmiridium',
#   'pentlandite',
#   'periclase',
#   'pinite',
#   'pollucite',
#   'psilomelane',
#   'pyrite',
#   'pyrolusite',
#   'pyromorphite',
#   'pyrophyllite',
#   'pyroxene',
#   'pyrrhotite',
#   'quartz',
#   'realgar',
#   'rhodochrosite',
#   'rhodonite',
#   'rutile',
#   'samarskite',
#   'sapphirine',
#   'scheelite',
#   'smaltite',
#   'sodalite',
#   'spar',
#   'calcite',
#   'feldspar',
#   'moonstone',
#   'orthoclase',
#   'plagioclase',
#   'albite',
#   'anorthite',
#   'spinel',
#   'Ceylonite',
#   'almandine',
#   'balas',
#   'rubicelle',
#   'spodumene',
#   'hiddenite',
#   'kunzite',
#   'stannite',
#   'stibnite',
#   'strontianite',
#   'sylvanite',
#   'sylvite',
#   'talc',
#   'rensselaerite',
#   'soapstone',
#   'tantalite',
#   'thorite',
#   'thortveitite',
#   'topaz',
#   'tourmaline',
#   'schorl',
#   'tridymite',
#   'turquoise',
#   'vanadinite',
#   'vermiculite',
#   'vesuvianite',
#   'wolframite',
#   'wollastonite',
#   'wulfenite',
#   'wurtzite',
#   'xenotime',
#   'zeolite',
#   'chabazite',
#   'heulandite',
#   'natrolite',
#   'phillipsite',
#   'zinkenite',
#   'zircon',
#   'hyacinth',
#   'jargoon'],
#  'book': ['authority',
#   'command',
#   'behest',
#   'commandment',
#   'commission',
#   'board',
#   'cabinet',
#   'dresser',
#   'chiffonier',
#   'highboy',
#   'lowboy',
#   'Kashag',
#   'directorate',
#   'conservancy',
#   'jury',
#   'politburo',
#   'presidium',
#   'subcommittee',
#   'vestry',
#   'countermand',
#   'injunction',
#   'order',
#   'summons',
#   'word',
#   'anagram',
#   'antigram',
#   'anaphor',
#   'antonym',
#   'charade',
#   'classifier',
#   'cognate',
#   'headword',
#   'modifier',
#   'adjective',
#   'comparative',
#   'positive',
#   'pertainym',
#   'superlative',
#   'adverb',
#   'intensifier',
#   'noun',
#   'adnoun',
#   'gerund',
#   'verb',
#   'infinitive',
#   'participle',
#   'contraction',
#   'contracture',
#   'tetanus',
#   'vaginismus',
#   'deictic',
#   'derivative',
#   'curvature',
#   'diminutive',
#   'bawdry',
#   'scatology',
#   'disyllable',
#   'form',
#   'abbreviation',
#   'apocope',
#   'acronym',
#   'etymon',
#   'plural',
#   'root',
#   'briarroot',
#   'calamus',
#   'rattan',
#   'carrot',
#   'cassava',
#   'chicory',
#   'ginseng',
#   'horseradish',
#   'orrisroot',
#   'parsnip',
#   'pneumatophore',
#   'radish',
#   'rootlet',
#   'salsify',
#   'senega',
#   'taproot',
#   'taro',
#   'singular',
#   'conjunction',
#   'concomitance',
#   'contemporaneity',
#   'overlap',
#   'crossroads',
#   'interface',
#   'unison',
#   'determiner',
#   'particle',
#   'chylomicron',
#   'flyspeck',
#   'grain',
#   'granule',
#   'chondrule',
#   'microsome',
#   'plastid',
#   'chloroplast',
#   'chromoplast',
#   'grinding',
#   'Microtaggant',
#   'preposition',
#   'pronoun',
#   'head',
#   'attic',
#   'cockloft',
#   'hayloft',
#   'bullethead',
#   'imperium',
#   'lordship',
#   'muscle',
#   'agonist',
#   'antihero',
#   'antagonist',
#   'dueler',
#   'enemy',
#   'Luddite',
#   'withstander',
#   'levator',
#   'pronator',
#   'rectus',
#   'abdominal',
#   'abductor',
#   'crimp',
#   'kink',
#   'pleat',
#   'tuck',
#   'pucker',
#   'shanghaier',
#   'adductor',
#   'biceps',
#   'calf',
#   'dogie',
#   'maverick',
#   'deltoid',
#   'depressor',
#   'quadriceps',
#   'masseter',
#   'platysma',
#   'gastrocnemius',
#   'gluteus',
#   'intercostal',
#   'pectoral',
#   'peroneus',
#   'psoas',
#   'rhomboid',
#   'sartorius',
#   'scalenus',
#   'serratus',
#   'soleus',
#   'splenius',
#   'sternocleidomastoid',
#   'teres',
#   'tibialis',
#   'trapezius',
#   'triceps',
#   'myometrium',
#   'sphincter',
#   'supinator',
#   'tensor',
#   'sovereignty',
#   'bestiary',
#   'booklet',
#   'catalog',
#   'catechism',
#   'copybook',
#   'curiosa',
#   'formulary',
#   'playbook',
#   'breviary',
#   'missal',
#   'Psalter',
#   'annual',
#   'atlas',
#   'cookbook',
#   'directory',
#   'encyclopedia',
#   'handbook',
#   'bible',
#   'guidebook',
#   'roadbook',
#   'baedeker',
#   'manual',
#   'consuetudinary',
#   'grimoire',
#   'reckoner',
#   'adder',
#   'statistician',
#   'subtracter',
#   'wordbook',
#   'dictionary',
#   'gazetteer',
#   'glossary',
#   'onomasticon',
#   'thesaurus',
#   'vocabulary',
#   'songbook',
#   'hymnal',
#   'storybook',
#   'textbook',
#   'crammer',
#   'introduction',
#   'induction',
#   'coronation',
#   'inauguration',
#   'naturalization',
#   'primer',
#   'hornbook',
#   'speller',
#   'reader',
#   'bookworm',
#   'purist',
#   'tome',
#   'workbook',
#   'yearbook'],
#  'religion': ['apophatism',
#   'Bahaism',
#   'Brahmanism',
#   'Buddhism',
#   'Hinayana',
#   'Mahayana',
#   'Tantrism',
#   'Zen',
#   'cataphatism',
#   'Christianity',
#   'Adventism',
#   'Albigensianism',
#   'Catholicism',
#   'Romanism',
#   'Donatism',
#   'Protestantism',
#   'Anabaptism',
#   'Anglicanism',
#   'Arminianism',
#   'Calvinism',
#   'Congregationalism',
#   'evangelicalism',
#   'revivalism',
#   'fundamentalism',
#   'Lutheranism',
#   'Mennonitism',
#   'Methodism',
#   'Mormonism',
#   'pentecostalism',
#   'predestinarianism',
#   'Presbyterianism',
#   'Puritanism',
#   'Trinitarianism',
#   'Unitarianism',
#   'Wesleyanism',
#   'Tractarianism',
#   'cult',
#   'macumba',
#   'obeah',
#   'Rastafari',
#   'Rastafarian',
#   'voodoo',
#   'Wicca']}

# %% [markdown]
# Currently, the wordlists seem to get mixed up, there are a lot of professions in 'animal' for example. I believe the source of this issue lies within the wordlist building, as I convert synsets to lemmas and back to synsets and the original word sense is changed while doing this conversion. I should rewrite this to keep the original synset intact. But nevertheless, the issue of different levels remains, so I will see if ConceptNet is better suited.
